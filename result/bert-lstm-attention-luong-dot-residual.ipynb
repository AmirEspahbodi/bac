# %%
# %cd /kaggle/working
# !git clone https://github.com/AmirEspahbodi/bac.git
# Out:
# /kaggle/working
# fatal: destination path 'bac' already exists and is not an empty directory.

# %%
# !pip install bitsandbytes

# %%
# %cd /kaggle/working/bac
# !git pull
# !ls
# Out:
# /kaggle/working/bac
# Already up to date.
# datasets     poetry.lock     README.md	src
# inspiration  pyproject.toml  scripts	state.db

# %%
import os
import json
import matplotlib.pyplot as plt


def plot_history(result_load_path, NUM_EPOCHS):
    loss_train_hist = None
    loss_valid_hist = None
    acc_train_hist = None
    acc_valid_hist = None
    test_top_5_acc = None
    test_top_10_acc = None
    test_loss_final = None
    test_acc_top1_final = None
    test_mrr_final = None
        
    # Load the data from the JSON file
    try:
        with open(result_load_path, "r") as f:
            # json.load() reads the file and parses the JSON data into a Python dictionary
            loaded_results = json.load(f)
    
        # Unpack the dictionary values into your variables
        loss_train_hist = loaded_results.get("loss_train_hist")
        loss_valid_hist = loaded_results.get("loss_valid_hist")
        acc_train_hist = loaded_results.get("acc_train_hist")
        acc_valid_hist = loaded_results.get("acc_valid_hist")
        test_top_5_acc = loaded_results.get("test_top_5_acc")
        test_top_10_acc = loaded_results.get("test_top_10_acc")
        test_loss_final = loaded_results.get("test_loss_final")
        test_acc_top1_final = loaded_results.get("test_acc_top1_final")
        test_mrr_final = loaded_results.get("test_mrr_final")
    
    except FileNotFoundError:
        print(f"Error: The file at '{result_load_path}' was not found.")
    except json.JSONDecodeError:
        print(f"Error: The file at '{result_load_path}' is not a valid JSON file.")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")
    
    epochs_range = range(1, NUM_EPOCHS + 1)
    
    plt.figure(figsize=(14, 6))
    
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, loss_train_hist, "bo-", label="Training Loss")
    plt.plot(epochs_range, loss_valid_hist, "ro-", label="Validation Loss")
    plt.title("Training and Validation Loss")
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.legend()
    plt.grid(True)
    
    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, acc_train_hist, "bo-", label="Training Accuracy (Top-1)")
    plt.plot(epochs_range, acc_valid_hist, "ro-", label="Validation Accuracy (Top-1)")
    plt.title("Training and Validation Accuracy (Top-1)")
    plt.xlabel("Epochs")
    plt.ylabel("Accuracy")
    plt.legend()
    plt.grid(True)
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## GCC dataset

# %%
# !python -m src.run_lstm -e bert -d gcc -ne 7 -rsw 0 -a 1 -b 0 -r 1 -hs 256 -l 2 -nah 1 -lam dot
# Out:
# 2025-07-12 16:00:00.846525: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752336001.018571      85 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752336001.070472      85 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Shape after dropping NA assignees: (2103, 6)
# Number of unique assignees (classes): 82
# Warning: Some classes have fewer than 2 samples (min_samples_per_class=1). Stratification for train/test split might not be possible or effective.
# ✅ Loading pre-saved augmented dataset from 'datasets/augmented_train_dataset_2_GCC.csv'.
# tokenizer_config.json: 100%|██████████████████| 48.0/48.0 [00:00<00:00, 367kB/s]
# vocab.txt: 100%|█████████████████████████████| 232k/232k [00:00<00:00, 1.17MB/s]
# tokenizer.json: 100%|████████████████████████| 466k/466k [00:00<00:00, 1.17MB/s]
# config.json: 100%|█████████████████████████████| 570/570 [00:00<00:00, 2.94MB/s]
# Using device: cuda
# model.safetensors: 100%|██████████████████████| 440M/440M [00:02<00:00, 184MB/s]
# Generating Full Embeddings: 100%|█████████████| 276/276 [01:33<00:00,  2.96it/s]
# Generating Full Embeddings: 100%|███████████████| 14/14 [00:04<00:00,  3.12it/s]
# Generating Full Embeddings: 100%|███████████████| 27/27 [00:08<00:00,  3.14it/s]
#
# DataLoaders created successfully!
# Training batches: 276
# Validation batches: 14
# Test batches: 27
# using bert embeddings
#
# ------
# lstm model info:
# {'total_parameters': 1818322, 'trainable_parameters': 1818322, 'model_size_mb': 6.936347961425781, 'config': LSTMConfig(input_size=768, hidden_size=256, num_layers=2, num_classes=82, dropout=0.4, bidirectional=False, use_attention=True, attention_heads=1, attention_dropout=0.1, layer_norm=True, residual_connections=1, gradient_clipping=1.0, luong_attention_method='dot'), 'is_bidirectional': False, 'uses_attention': True, 'attention_heads': 1}
# ------
#
# OPTIMIZER=SGD, LR=0.1
# Epoch 0: 100%|███| 276/276 [00:19<00:00, 13.92batch/s, accuracy=11.7, loss=3.82]
# OPTIMIZER=SGD, LR=0.01
# Epoch 0: 100%|███| 276/276 [00:19<00:00, 14.49batch/s, accuracy=12.3, loss=3.85]
# OPTIMIZER=SGD, LR=0.001
# Epoch 0: 100%|███| 276/276 [00:19<00:00, 14.46batch/s, accuracy=10.2, loss=4.09]
# OPTIMIZER=SGD, LR=0.0001
# Epoch 0: 100%|████| 276/276 [00:19<00:00, 14.49batch/s, accuracy=4.1, loss=4.52]
# OPTIMIZER=Adam, LR=0.1
# Epoch 0: 100%|███| 276/276 [00:19<00:00, 14.32batch/s, accuracy=12.3, loss=4.19]
# OPTIMIZER=Adam, LR=0.01
# Epoch 0: 100%|███| 276/276 [00:19<00:00, 14.34batch/s, accuracy=12.3, loss=3.82]
# OPTIMIZER=Adam, LR=0.001
# Epoch 0: 100%|█████| 276/276 [00:19<00:00, 14.38batch/s, accuracy=13, loss=3.79]
# OPTIMIZER=Adam, LR=0.0001
# Epoch 0: 100%|███| 276/276 [00:18<00:00, 14.54batch/s, accuracy=17.2, loss=3.79]
# OPTIMIZER=Adamw, LR=0.1
# Epoch 0: 100%|███| 276/276 [00:19<00:00, 14.45batch/s, accuracy=11.5, loss=4.19]
# OPTIMIZER=Adamw, LR=0.01
# Epoch 0: 100%|████| 276/276 [00:19<00:00, 14.51batch/s, accuracy=12.5, loss=3.8]
# OPTIMIZER=Adamw, LR=0.001
# Epoch 0: 100%|███| 276/276 [00:19<00:00, 14.23batch/s, accuracy=13.6, loss=3.75]
# OPTIMIZER=Adamw, LR=0.0001
# Epoch 0: 100%|███| 276/276 [00:19<00:00, 14.46batch/s, accuracy=17.4, loss=3.79]
# <class 'torch.optim.adamw.AdamW'> 0.0001
#
# ✅ Start Training 7 epochs ...
# Epoch 1/7 | Current LR: 0.000100
# Epoch 1: 100%|████| 276/276 [00:19<00:00, 14.43batch/s, accuracy=17.3, loss=3.8]
# 	Train: Loss = 3.7970, Acc = 17.2898
# 	Valid: Loss = 3.4502, Acc = 25.5924
# 	✨ New best validation loss: 3.4502
# ------------------------------------------------------------
# Epoch 2/7 | Current LR: 0.000095
# Epoch 2: 100%|███| 276/276 [00:18<00:00, 14.59batch/s, accuracy=31.2, loss=3.25]
# 	Train: Loss = 3.2509, Acc = 31.2259
# 	Valid: Loss = 3.1365, Acc = 30.8057
# 	✨ New best validation loss: 3.1365
# ------------------------------------------------------------
# Epoch 3/7 | Current LR: 0.000081
# Epoch 3: 100%|███| 276/276 [00:19<00:00, 14.47batch/s, accuracy=38.3, loss=2.93]
# 	Train: Loss = 2.9333, Acc = 38.3413
# 	Valid: Loss = 2.9786, Acc = 39.3365
# 	✨ New best validation loss: 2.9786
# ------------------------------------------------------------
# Epoch 4/7 | Current LR: 0.000062
# Epoch 4: 100%|███| 276/276 [00:19<00:00, 14.52batch/s, accuracy=43.2, loss=2.71]
# 	Train: Loss = 2.7115, Acc = 43.1679
# 	Valid: Loss = 2.9464, Acc = 40.2844
# 	✨ New best validation loss: 2.9464
# ------------------------------------------------------------
# Epoch 5/7 | Current LR: 0.000039
# Epoch 5: 100%|███| 276/276 [00:19<00:00, 14.48batch/s, accuracy=48.7, loss=2.52]
# 	Train: Loss = 2.5173, Acc = 48.6517
# 	Valid: Loss = 2.9958, Acc = 38.8626
# 	Validation loss did not improve. Patience: 1/5
# ------------------------------------------------------------
# Epoch 6/7 | Current LR: 0.000020
# Epoch 6: 100%|████| 276/276 [00:18<00:00, 14.59batch/s, accuracy=51.8, loss=2.4]
# 	Train: Loss = 2.3984, Acc = 51.8015
# 	Valid: Loss = 2.8556, Acc = 39.3365
# 	✨ New best validation loss: 2.8556
# ------------------------------------------------------------
# Epoch 7/7 | Current LR: 0.000006
# Epoch 7: 100%|███| 276/276 [00:19<00:00, 14.48batch/s, accuracy=53.5, loss=2.34]
# 	Train: Loss = 2.3376, Acc = 53.5010
# 	Valid: Loss = 2.8616, Acc = 40.7583
# 	Validation loss did not improve. Patience: 1/5
# ------------------------------------------------------------
#
# ✅ Loaded best model based on validation accuracy for final testing. /kaggle/working/bac/.models/lstm_bert_model.pt
# Figure(1400x600)
#
# 🧪 Evaluating on Test Set...
#
# --- Test Set Results (Best Validation Model) ---
# 	Test Loss: 2.8544
# 	Test Accuracy (Top-1): 41.81%
# 	Test MRR: 0.5316
# {'loss_train_hist': [3.7969656465710075, 3.2508616196936457, 2.9332678279151088, 2.7115155186342155, 2.517342808885851, 2.398395239011101, 2.33759490735289], 'loss_valid_hist': [3.4501545258930753, 3.1364647150039673, 2.978632092475891, 2.9464384828295027, 2.9957779135022844, 2.8555766684668407, 2.861648048673357], 'acc_train_hist': [17.28982551552232, 31.225923408112394, 38.34126444595513, 43.16791298436438, 48.65171085429413, 51.801495581237255, 53.501019714479945], 'acc_valid_hist': [25.592417061611375, 30.805687203791468, 39.33649289099526, 40.28436018957346, 38.86255924170616, 39.33649289099526, 40.758293838862556], 'test_top_5_acc': 0.6365795724465558, 'test_top_10_acc': 0.7505938242280285, 'test_loss_final': 2.854386885960897, 'test_acc_top1_final': 41.80522565320665, 'test_mrr_final': 0.5315769753944742}

# %%
result_load_path = f"{os.getcwd()}/.result/lstm_bert_result.json"
plot_history(result_load_path, 7)

# %% [markdown]
# ## JDT dataset

# %%
# !python -m src.run_lstm -e bert -d jdt -ne 7 -rsw 0 -a 1 -b 0 -r 1 -hs 256 -l 2 -nah 1 -lam dot
# Out:
# 2025-07-12 16:08:34.025791: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752336514.048603     353 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752336514.055407     353 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Shape after dropping NA assignees: (1465, 5)
# Number of unique assignees (classes): 69
# Warning: Some classes have fewer than 2 samples (min_samples_per_class=1). Stratification for train/test split might not be possible or effective.
# ✅ Loading pre-saved augmented dataset from 'datasets/augmented_train_dataset_2_JDT.csv'.
# Using device: cuda
# Generating Full Embeddings: 100%|█████████████| 193/193 [01:03<00:00,  3.06it/s]
# Generating Full Embeddings: 100%|███████████████| 10/10 [00:03<00:00,  3.32it/s]
# Generating Full Embeddings: 100%|███████████████| 19/19 [00:06<00:00,  3.11it/s]
#
# DataLoaders created successfully!
# Training batches: 193
# Validation batches: 10
# Test batches: 19
# using bert embeddings
#
# ------
# lstm model info:
# {'total_parameters': 1816645, 'trainable_parameters': 1816645, 'model_size_mb': 6.929950714111328, 'config': LSTMConfig(input_size=768, hidden_size=256, num_layers=2, num_classes=69, dropout=0.4, bidirectional=False, use_attention=True, attention_heads=1, attention_dropout=0.1, layer_norm=True, residual_connections=1, gradient_clipping=1.0, luong_attention_method='dot'), 'is_bidirectional': False, 'uses_attention': True, 'attention_heads': 1}
# ------
#
# OPTIMIZER=SGD, LR=0.1
# Epoch 0: 100%|███| 193/193 [00:13<00:00, 14.09batch/s, accuracy=14.4, loss=3.53]
# OPTIMIZER=SGD, LR=0.01
# Epoch 0: 100%|███| 193/193 [00:13<00:00, 14.52batch/s, accuracy=14.1, loss=3.55]
# OPTIMIZER=SGD, LR=0.001
# Epoch 0: 100%|█████| 193/193 [00:13<00:00, 14.67batch/s, accuracy=10, loss=3.94]
# OPTIMIZER=SGD, LR=0.0001
# Epoch 0: 100%|████| 193/193 [00:13<00:00, 14.61batch/s, accuracy=3.12, loss=4.7]
# OPTIMIZER=Adam, LR=0.1
# Epoch 0: 100%|███| 193/193 [00:13<00:00, 14.43batch/s, accuracy=15.4, loss=4.68]
# OPTIMIZER=Adam, LR=0.01
# Epoch 0: 100%|████| 193/193 [00:13<00:00, 14.31batch/s, accuracy=14.6, loss=3.5]
# OPTIMIZER=Adam, LR=0.001
# Epoch 0: 100%|███| 193/193 [00:13<00:00, 14.36batch/s, accuracy=13.9, loss=3.52]
# OPTIMIZER=Adam, LR=0.0001
# Epoch 0: 100%|███| 193/193 [00:13<00:00, 14.45batch/s, accuracy=15.7, loss=3.61]
# OPTIMIZER=Adamw, LR=0.1
# Epoch 0: 100%|███| 193/193 [00:13<00:00, 14.46batch/s, accuracy=15.7, loss=4.02]
# OPTIMIZER=Adamw, LR=0.01
# Epoch 0: 100%|████| 193/193 [00:13<00:00, 14.39batch/s, accuracy=15.3, loss=3.5]
# OPTIMIZER=Adamw, LR=0.001
# Epoch 0: 100%|███| 193/193 [00:13<00:00, 14.27batch/s, accuracy=14.4, loss=3.49]
# OPTIMIZER=Adamw, LR=0.0001
# Epoch 0: 100%|█████| 193/193 [00:13<00:00, 14.38batch/s, accuracy=15, loss=3.62]
# <class 'torch.optim.adamw.AdamW'> 0.1
#
# ✅ Start Training 7 epochs ...
# Epoch 1/7 | Current LR: 0.100000
# Epoch 1: 100%|█████| 193/193 [00:13<00:00, 14.39batch/s, accuracy=16, loss=3.87]
# 	Train: Loss = 3.8656, Acc = 16.0000
# 	Valid: Loss = 3.2778, Acc = 14.9660
# 	✨ New best validation loss: 3.2778
# ------------------------------------------------------------
# Epoch 2/7 | Current LR: 0.095048
# Epoch 2: 100%|███| 193/193 [00:13<00:00, 14.29batch/s, accuracy=15.6, loss=3.29]
# 	Train: Loss = 3.2872, Acc = 15.6098
# 	Valid: Loss = 3.2645, Acc = 14.9660
# 	✨ New best validation loss: 3.2645
# ------------------------------------------------------------
# Epoch 3/7 | Current LR: 0.081175
# Epoch 3: 100%|███| 193/193 [00:13<00:00, 14.54batch/s, accuracy=16.3, loss=3.28]
# 	Train: Loss = 3.2774, Acc = 16.3252
# 	Valid: Loss = 3.2789, Acc = 14.9660
# 	Validation loss did not improve. Patience: 1/5
# ------------------------------------------------------------
# Epoch 4/7 | Current LR: 0.061126
# Epoch 4: 100%|███| 193/193 [00:13<00:00, 14.40batch/s, accuracy=16.4, loss=3.27]
# 	Train: Loss = 3.2699, Acc = 16.3902
# 	Valid: Loss = 3.2695, Acc = 14.9660
# 	Validation loss did not improve. Patience: 2/5
# ------------------------------------------------------------
# Epoch 5/7 | Current LR: 0.038875
# Epoch 5: 100%|█████| 193/193 [00:13<00:00, 14.47batch/s, accuracy=17, loss=3.27]
# 	Train: Loss = 3.2674, Acc = 16.9756
# 	Valid: Loss = 3.2686, Acc = 14.9660
# 	Validation loss did not improve. Patience: 3/5
# ------------------------------------------------------------
# Epoch 6/7 | Current LR: 0.018826
# Epoch 6: 100%|█████| 193/193 [00:13<00:00, 14.54batch/s, accuracy=17, loss=3.26]
# 	Train: Loss = 3.2570, Acc = 16.9756
# 	Valid: Loss = 3.2504, Acc = 14.9660
# 	✨ New best validation loss: 3.2504
# ------------------------------------------------------------
# Epoch 7/7 | Current LR: 0.004953
# Epoch 7: 100%|█████| 193/193 [00:13<00:00, 14.44batch/s, accuracy=17, loss=3.25]
# 	Train: Loss = 3.2502, Acc = 16.9756
# 	Valid: Loss = 3.2528, Acc = 14.9660
# 	Validation loss did not improve. Patience: 1/5
# ------------------------------------------------------------
#
# ✅ Loaded best model based on validation accuracy for final testing. /kaggle/working/bac/.models/lstm_bert_model.pt
# Figure(1400x600)
#
# 🧪 Evaluating on Test Set...
#
# --- Test Set Results (Best Validation Model) ---
# 	Test Loss: 3.3092
# 	Test Accuracy (Top-1): 14.68%
# 	Test MRR: 0.3276
# {'loss_train_hist': [3.865576474777775, 3.2872123322956304, 3.2773827246433713, 3.269892950749768, 3.2673740288136535, 3.2569827601081967, 3.2502244383559944], 'loss_valid_hist': [3.2778293609619142, 3.2645248413085937, 3.2788549184799196, 3.2694905281066893, 3.2685817003250124, 3.2503969192504885, 3.2528311252593993], 'acc_train_hist': [16.0, 15.609756097560975, 16.32520325203252, 16.390243902439025, 16.975609756097562, 16.975609756097562, 16.975609756097562], 'acc_valid_hist': [14.965986394557824, 14.965986394557824, 14.965986394557824, 14.965986394557824, 14.965986394557824, 14.965986394557824, 14.965986394557824], 'test_top_5_acc': 0.5733788395904437, 'test_top_10_acc': 0.7406143344709898, 'test_loss_final': 3.309231908697831, 'test_acc_top1_final': 14.675767918088738, 'test_mrr_final': 0.32761712883855626}

# %%
result_load_path = f"{os.getcwd()}/.result/lstm_bert_result.json"
plot_history(result_load_path, 7)
