# %%
# %cd /kaggle/working
# !git clone https://github.com/AmirEspahbodi/bac.git
# Out:
# /kaggle/working
# fatal: destination path 'bac' already exists and is not an empty directory.

# %%
# %cd /kaggle/working/bac
# !git pull
# !ls
# Out:
# /kaggle/working/bac
# Already up to date.
# datasets     poetry.lock     README.md	src
# inspiration  pyproject.toml  scripts	state.db

# %%
import os
import json
import matplotlib.pyplot as plt


def plot_history(result_load_path, NUM_EPOCHS):
    loss_train_hist = None
    loss_valid_hist = None
    acc_train_hist = None
    acc_valid_hist = None
    test_top_5_acc = None
    test_top_10_acc = None
    test_loss_final = None
    test_acc_top1_final = None
    test_mrr_final = None
        
    # Load the data from the JSON file
    try:
        with open(result_load_path, "r") as f:
            # json.load() reads the file and parses the JSON data into a Python dictionary
            loaded_results = json.load(f)
    
        # Unpack the dictionary values into your variables
        loss_train_hist = loaded_results.get("loss_train_hist")
        loss_valid_hist = loaded_results.get("loss_valid_hist")
        acc_train_hist = loaded_results.get("acc_train_hist")
        acc_valid_hist = loaded_results.get("acc_valid_hist")
        test_top_5_acc = loaded_results.get("test_top_5_acc")
        test_top_10_acc = loaded_results.get("test_top_10_acc")
        test_loss_final = loaded_results.get("test_loss_final")
        test_acc_top1_final = loaded_results.get("test_acc_top1_final")
        test_mrr_final = loaded_results.get("test_mrr_final")
    
    except FileNotFoundError:
        print(f"Error: The file at '{result_load_path}' was not found.")
    except json.JSONDecodeError:
        print(f"Error: The file at '{result_load_path}' is not a valid JSON file.")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")
    
    epochs_range = range(1, NUM_EPOCHS + 1)
    
    plt.figure(figsize=(14, 6))
    
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, loss_train_hist, "bo-", label="Training Loss")
    plt.plot(epochs_range, loss_valid_hist, "ro-", label="Validation Loss")
    plt.title("Training and Validation Loss")
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.legend()
    plt.grid(True)
    
    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, acc_train_hist, "bo-", label="Training Accuracy (Top-1)")
    plt.plot(epochs_range, acc_valid_hist, "ro-", label="Validation Accuracy (Top-1)")
    plt.title("Training and Validation Accuracy (Top-1)")
    plt.xlabel("Epochs")
    plt.ylabel("Accuracy")
    plt.legend()
    plt.grid(True)
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## GCC dataset

# %%
# !python -m src.run_lstm -e bert -d gcc -ne 7 -rsw 0 -a 1 -b 1 -r 0 -hs 256 -l 2 -nah 1 -lam concat
# Out:
# 2025-07-12 12:42:23.009296: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752324143.032389     615 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752324143.039345     615 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Shape after dropping NA assignees: (2103, 6)
# Number of unique assignees (classes): 82
# Warning: Some classes have fewer than 2 samples (min_samples_per_class=1). Stratification for train/test split might not be possible or effective.
# ✅ Loading pre-saved augmented dataset from 'datasets/augmented_train_dataset_2_GCC.csv'.
# Using device: cuda
# Generating Full Embeddings: 100%|█████████████| 276/276 [01:34<00:00,  2.93it/s]
# Generating Full Embeddings: 100%|███████████████| 14/14 [00:04<00:00,  3.13it/s]
# Generating Full Embeddings: 100%|███████████████| 27/27 [00:08<00:00,  3.10it/s]
#
# DataLoaders created successfully!
# Training batches: 276
# Validation batches: 14
# Test batches: 27
# using bert embeddings
#
# ------
# lstm model info:
# {'total_parameters': 4554322, 'trainable_parameters': 4554322, 'model_size_mb': 17.37335968017578, 'config': LSTMConfig(input_size=768, hidden_size=256, num_layers=2, num_classes=82, dropout=0.4, bidirectional=True, use_attention=True, attention_heads=1, attention_dropout=0.1, layer_norm=True, residual_connections=0, gradient_clipping=1.0, luong_attention_method='concat'), 'is_bidirectional': True, 'uses_attention': True, 'attention_heads': 1}
# ------
#
# OPTIMIZER=SGD, LR=0.1
# Epoch 0: 100%|███| 276/276 [00:31<00:00,  8.74batch/s, accuracy=11.8, loss=3.85]
# OPTIMIZER=SGD, LR=0.01
# Epoch 0: 100%|███| 276/276 [00:30<00:00,  8.93batch/s, accuracy=15.7, loss=3.79]
# OPTIMIZER=SGD, LR=0.001
# Epoch 0: 100%|█████| 276/276 [00:30<00:00,  8.94batch/s, accuracy=12, loss=4.05]
# OPTIMIZER=SGD, LR=0.0001
# Epoch 0: 100%|███| 276/276 [00:30<00:00,  8.97batch/s, accuracy=3.42, loss=4.69]
# OPTIMIZER=Adam, LR=0.1
# Epoch 0: 100%|███| 276/276 [00:31<00:00,  8.76batch/s, accuracy=10.9, loss=7.28]
# OPTIMIZER=Adam, LR=0.01
# Epoch 0: 100%|███| 276/276 [00:31<00:00,  8.70batch/s, accuracy=11.8, loss=3.87]
# OPTIMIZER=Adam, LR=0.001
# Epoch 0: 100%|███| 276/276 [00:31<00:00,  8.67batch/s, accuracy=15.5, loss=3.72]
# OPTIMIZER=Adam, LR=0.0001
# Epoch 0: 100%|███| 276/276 [00:31<00:00,  8.79batch/s, accuracy=23.7, loss=3.57]
# OPTIMIZER=Adamw, LR=0.1
# Epoch 0: 100%|███| 276/276 [00:31<00:00,  8.77batch/s, accuracy=11.6, loss=5.78]
# OPTIMIZER=Adamw, LR=0.01
# Epoch 0: 100%|███| 276/276 [00:31<00:00,  8.78batch/s, accuracy=11.7, loss=3.86]
# OPTIMIZER=Adamw, LR=0.001
# Epoch 0: 100%|███| 276/276 [00:31<00:00,  8.77batch/s, accuracy=14.6, loss=3.75]
# OPTIMIZER=Adamw, LR=0.0001
# Epoch 0: 100%|███| 276/276 [00:31<00:00,  8.86batch/s, accuracy=21.3, loss=3.62]
# <class 'torch.optim.adam.Adam'> 0.0001
#
# ✅ Start Training 7 epochs ...
# Epoch 1/7 | Current LR: 0.000100
# Epoch 1: 100%|███| 276/276 [00:31<00:00,  8.84batch/s, accuracy=24.1, loss=3.57]
# 	Train: Loss = 3.5695, Acc = 24.1106
# 	Valid: Loss = 3.1390, Acc = 35.0711
# 	✨ New best validation loss: 3.1390
# ------------------------------------------------------------
# Epoch 2/7 | Current LR: 0.000095
# Epoch 2: 100%|███| 276/276 [00:30<00:00,  8.92batch/s, accuracy=42.2, loss=2.82]
# 	Train: Loss = 2.8213, Acc = 42.1935
# 	Valid: Loss = 2.7655, Acc = 41.7062
# 	✨ New best validation loss: 2.7655
# ------------------------------------------------------------
# Epoch 3/7 | Current LR: 0.000081
# Epoch 3: 100%|███| 276/276 [00:31<00:00,  8.83batch/s, accuracy=53.6, loss=2.32]
# 	Train: Loss = 2.3240, Acc = 53.6143
# 	Valid: Loss = 2.7039, Acc = 43.1280
# 	✨ New best validation loss: 2.7039
# ------------------------------------------------------------
# Epoch 4/7 | Current LR: 0.000062
# Epoch 4: 100%|███| 276/276 [00:31<00:00,  8.89batch/s, accuracy=64.1, loss=1.96]
# 	Train: Loss = 1.9601, Acc = 64.1061
# 	Valid: Loss = 2.5933, Acc = 49.7630
# 	✨ New best validation loss: 2.5933
# ------------------------------------------------------------
# Epoch 5/7 | Current LR: 0.000039
# Epoch 5: 100%|███| 276/276 [00:31<00:00,  8.78batch/s, accuracy=72.4, loss=1.71]
# 	Train: Loss = 1.7114, Acc = 72.3544
# 	Valid: Loss = 2.6641, Acc = 50.2370
# 	Validation loss did not improve. Patience: 1/5
# ------------------------------------------------------------
# Epoch 6/7 | Current LR: 0.000020
# Epoch 6: 100%|███| 276/276 [00:31<00:00,  8.82batch/s, accuracy=78.8, loss=1.53]
# 	Train: Loss = 1.5332, Acc = 78.8353
# 	Valid: Loss = 2.5858, Acc = 49.7630
# 	✨ New best validation loss: 2.5858
# ------------------------------------------------------------
# Epoch 7/7 | Current LR: 0.000006
# Epoch 7: 100%|███| 276/276 [00:31<00:00,  8.85batch/s, accuracy=81.6, loss=1.47]
# 	Train: Loss = 1.4668, Acc = 81.6451
# 	Valid: Loss = 2.5657, Acc = 49.7630
# 	✨ New best validation loss: 2.5657
# ------------------------------------------------------------
#
# ✅ Loaded best model based on validation accuracy for final testing. /kaggle/working/bac/.models/lstm_bert_model.pt
# Figure(1400x600)
#
# 🧪 Evaluating on Test Set...
#
# --- Test Set Results (Best Validation Model) ---
# 	Test Loss: 2.4598
# 	Test Accuracy (Top-1): 52.73%
# 	Test MRR: 0.6415
# {'loss_train_hist': [3.569543611312258, 2.8212563119072844, 2.324035770651223, 1.9601433372152024, 1.7113817990690037, 1.5331681124542071, 1.4667839299941408], 'loss_valid_hist': [3.1389695405960083, 2.7654566764831543, 2.7039417028427124, 2.5933475153786794, 2.6640693119594028, 2.5857528703553334, 2.565742611885071], 'acc_train_hist': [24.110582370269658, 42.1935191479719, 53.614321323362795, 64.10605030591434, 72.35440743258555, 78.83525946068434, 81.64513936097893], 'acc_valid_hist': [35.07109004739336, 41.70616113744076, 43.127962085308056, 49.76303317535545, 50.23696682464455, 49.76303317535545, 49.76303317535545], 'test_top_5_acc': 0.7695961995249406, 'test_top_10_acc': 0.850356294536817, 'test_loss_final': 2.45983209433379, 'test_acc_top1_final': 52.73159144893112, 'test_mrr_final': 0.641492902998538}

# %%
result_load_path = f"{os.getcwd()}/.result/lstm_bert_result.json"
plot_history(result_load_path, 7)

# %% [markdown]
# ## JDT dataset

# %%
# !python -m src.run_lstm -e bert -d jdt -ne 7 -rsw 0 -a 1 -b 1 -r 0 -hs 256 -l 2 -nah 1 -lam concat
# Out:
# 2025-07-12 12:54:37.963211: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752324877.985644     864 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752324877.992515     864 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Shape after dropping NA assignees: (1465, 5)
# Number of unique assignees (classes): 69
# Warning: Some classes have fewer than 2 samples (min_samples_per_class=1). Stratification for train/test split might not be possible or effective.
# ✅ Loading pre-saved augmented dataset from 'datasets/augmented_train_dataset_2_JDT.csv'.
# Using device: cuda
# Generating Full Embeddings: 100%|█████████████| 193/193 [01:05<00:00,  2.96it/s]
# Generating Full Embeddings: 100%|███████████████| 10/10 [00:02<00:00,  3.35it/s]
# Generating Full Embeddings: 100%|███████████████| 19/19 [00:06<00:00,  3.05it/s]
#
# DataLoaders created successfully!
# Training batches: 193
# Validation batches: 10
# Test batches: 19
# using bert embeddings
#
# ------
# lstm model info:
# {'total_parameters': 4550981, 'trainable_parameters': 4550981, 'model_size_mb': 17.360614776611328, 'config': LSTMConfig(input_size=768, hidden_size=256, num_layers=2, num_classes=69, dropout=0.4, bidirectional=True, use_attention=True, attention_heads=1, attention_dropout=0.1, layer_norm=True, residual_connections=0, gradient_clipping=1.0, luong_attention_method='concat'), 'is_bidirectional': True, 'uses_attention': True, 'attention_heads': 1}
# ------
#
# OPTIMIZER=SGD, LR=0.1
# Epoch 0: 100%|███| 193/193 [00:21<00:00,  8.78batch/s, accuracy=14.9, loss=3.64]
# OPTIMIZER=SGD, LR=0.01
# Epoch 0: 100%|████| 193/193 [00:21<00:00,  8.94batch/s, accuracy=16.3, loss=3.5]
# OPTIMIZER=SGD, LR=0.001
# Epoch 0: 100%|████| 193/193 [00:21<00:00,  8.95batch/s, accuracy=13.7, loss=3.8]
# OPTIMIZER=SGD, LR=0.0001
# Epoch 0: 100%|███| 193/193 [00:21<00:00,  8.87batch/s, accuracy=5.37, loss=4.53]
# OPTIMIZER=Adam, LR=0.1
# Epoch 0: 100%|███| 193/193 [00:22<00:00,  8.77batch/s, accuracy=12.8, loss=10.5]
# OPTIMIZER=Adam, LR=0.01
# Epoch 0: 100%|███| 193/193 [00:21<00:00,  8.79batch/s, accuracy=14.2, loss=3.61]
# OPTIMIZER=Adam, LR=0.001
# Epoch 0: 100%|███| 193/193 [00:21<00:00,  8.79batch/s, accuracy=15.8, loss=3.47]
# OPTIMIZER=Adam, LR=0.0001
# Epoch 0: 100%|███| 193/193 [00:21<00:00,  8.87batch/s, accuracy=20.1, loss=3.43]
# OPTIMIZER=Adamw, LR=0.1
# Epoch 0: 100%|███| 193/193 [00:21<00:00,  8.80batch/s, accuracy=16.1, loss=6.36]
# OPTIMIZER=Adamw, LR=0.01
# Epoch 0: 100%|███| 193/193 [00:22<00:00,  8.76batch/s, accuracy=14.1, loss=3.59]
# OPTIMIZER=Adamw, LR=0.001
# Epoch 0: 100%|███| 193/193 [00:21<00:00,  8.80batch/s, accuracy=14.9, loss=3.46]
# OPTIMIZER=Adamw, LR=0.0001
# Epoch 0: 100%|█████| 193/193 [00:21<00:00,  8.91batch/s, accuracy=20, loss=3.41]
# <class 'torch.optim.adam.Adam'> 0.0001
#
# ✅ Start Training 7 epochs ...
# Epoch 1/7 | Current LR: 0.000100
# Epoch 1: 100%|███| 193/193 [00:21<00:00,  8.89batch/s, accuracy=20.1, loss=3.42]
# 	Train: Loss = 3.4248, Acc = 20.0650
# 	Valid: Loss = 3.0021, Acc = 26.5306
# 	✨ New best validation loss: 3.0021
# ------------------------------------------------------------
# Epoch 2/7 | Current LR: 0.000095
# Epoch 2: 100%|███| 193/193 [00:21<00:00,  8.89batch/s, accuracy=33.8, loss=2.88]
# 	Train: Loss = 2.8842, Acc = 33.8211
# 	Valid: Loss = 2.7524, Acc = 36.7347
# 	✨ New best validation loss: 2.7524
# ------------------------------------------------------------
# Epoch 3/7 | Current LR: 0.000081
# Epoch 3: 100%|███| 193/193 [00:21<00:00,  8.98batch/s, accuracy=46.5, loss=2.45]
# 	Train: Loss = 2.4492, Acc = 46.5041
# 	Valid: Loss = 2.6773, Acc = 40.1361
# 	✨ New best validation loss: 2.6773
# ------------------------------------------------------------
# Epoch 4/7 | Current LR: 0.000062
# Epoch 4: 100%|███| 193/193 [00:21<00:00,  8.94batch/s, accuracy=57.9, loss=2.09]
# 	Train: Loss = 2.0908, Acc = 57.8862
# 	Valid: Loss = 2.6403, Acc = 43.5374
# 	✨ New best validation loss: 2.6403
# ------------------------------------------------------------
# Epoch 5/7 | Current LR: 0.000039
# Epoch 5: 100%|███| 193/193 [00:21<00:00,  8.86batch/s, accuracy=66.7, loss=1.81]
# 	Train: Loss = 1.8128, Acc = 66.6992
# 	Valid: Loss = 2.7913, Acc = 38.7755
# 	Validation loss did not improve. Patience: 1/5
# ------------------------------------------------------------
# Epoch 6/7 | Current LR: 0.000020
# Epoch 6: 100%|███| 193/193 [00:21<00:00,  8.95batch/s, accuracy=72.3, loss=1.65]
# 	Train: Loss = 1.6462, Acc = 72.2602
# 	Valid: Loss = 2.7597, Acc = 38.0952
# 	Validation loss did not improve. Patience: 2/5
# ------------------------------------------------------------
# Epoch 7/7 | Current LR: 0.000006
# Epoch 7: 100%|███| 193/193 [00:21<00:00,  8.86batch/s, accuracy=75.4, loss=1.57]
# 	Train: Loss = 1.5732, Acc = 75.3821
# 	Valid: Loss = 2.7872, Acc = 39.4558
# 	Validation loss did not improve. Patience: 3/5
# ------------------------------------------------------------
#
# ✅ Loaded best model based on validation accuracy for final testing. /kaggle/working/bac/.models/lstm_bert_model.pt
# Figure(1400x600)
#
# 🧪 Evaluating on Test Set...
#
# --- Test Set Results (Best Validation Model) ---
# 	Test Loss: 2.8128
# 	Test Accuracy (Top-1): 39.59%
# 	Test MRR: 0.5516
# {'loss_train_hist': [3.424776281099863, 2.8842004716705163, 2.449205711097915, 2.0908017492047244, 1.812813880530046, 1.646174166486671, 1.573243729191123], 'loss_valid_hist': [3.0021198987960815, 2.7523945212364196, 2.6773427009582518, 2.640277695655823, 2.791320562362671, 2.759719467163086, 2.787208390235901], 'acc_train_hist': [20.065040650406505, 33.82113821138211, 46.50406504065041, 57.886178861788615, 66.69918699186992, 72.26016260162602, 75.3821138211382], 'acc_valid_hist': [26.53061224489796, 36.734693877551024, 40.136054421768705, 43.53741496598639, 38.775510204081634, 38.095238095238095, 39.45578231292517], 'test_top_5_acc': 0.7201365187713311, 'test_top_10_acc': 0.8600682593856656, 'test_loss_final': 2.8127690114473043, 'test_acc_top1_final': 39.59044368600683, 'test_mrr_final': 0.5515940225358482}

# %%
result_load_path = f"{os.getcwd()}/.result/lstm_bert_result.json"
plot_history(result_load_path, 7)
