# %%
# %cd /kaggle/working
# !git clone https://github.com/AmirEspahbodi/bac.git
# Out:
# /kaggle/working
# fatal: destination path 'bac' already exists and is not an empty directory.

# %%
import os
from kaggle_secrets import UserSecretsClient
from huggingface_hub import login

# --- Hugging Face Authentication ---
try:
    user_secrets = UserSecretsClient()
    HUGGING_FACE_TOKEN = user_secrets.get_secret("HUGGING_FACE_TOKEN")
    # Ensure the token is set as an environment variable for transformers
    os.environ["HUGGING_FACE_HUB_TOKEN"] = HUGGING_FACE_TOKEN
    # Log in to Hugging Face Hub
    login(token=hf_token)
    print("✅ Successfully authenticated with Hugging Face.")
except Exception as e:
    print(f"⚠️ Could not authenticate with Hugging Face. Make sure the 'HUGGING_FACE_TOKEN' secret is set. Error: {e}")

# %%
# !pip install bitsandbytes

# %%
# %cd /kaggle/working/bac
# !git pull
# !ls
# Out:
# /kaggle/working/bac
# Already up to date.
# datasets     poetry.lock     README.md	src
# inspiration  pyproject.toml  scripts	state.db

# %%
import os
import json
import matplotlib.pyplot as plt


def plot_history(result_load_path, NUM_EPOCHS):
    loss_train_hist = None
    loss_valid_hist = None
    acc_train_hist = None
    acc_valid_hist = None
    test_top_5_acc = None
    test_top_10_acc = None
    test_loss_final = None
    test_acc_top1_final = None
    test_mrr_final = None
        
    # Load the data from the JSON file
    try:
        with open(result_load_path, "r") as f:
            # json.load() reads the file and parses the JSON data into a Python dictionary
            loaded_results = json.load(f)
    
        # Unpack the dictionary values into your variables
        loss_train_hist = loaded_results.get("loss_train_hist")
        loss_valid_hist = loaded_results.get("loss_valid_hist")
        acc_train_hist = loaded_results.get("acc_train_hist")
        acc_valid_hist = loaded_results.get("acc_valid_hist")
        test_top_5_acc = loaded_results.get("test_top_5_acc")
        test_top_10_acc = loaded_results.get("test_top_10_acc")
        test_loss_final = loaded_results.get("test_loss_final")
        test_acc_top1_final = loaded_results.get("test_acc_top1_final")
        test_mrr_final = loaded_results.get("test_mrr_final")
    
    except FileNotFoundError:
        print(f"Error: The file at '{result_load_path}' was not found.")
    except json.JSONDecodeError:
        print(f"Error: The file at '{result_load_path}' is not a valid JSON file.")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")
    
    epochs_range = range(1, NUM_EPOCHS + 1)
    
    plt.figure(figsize=(14, 6))
    
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, loss_train_hist, "bo-", label="Training Loss")
    plt.plot(epochs_range, loss_valid_hist, "ro-", label="Validation Loss")
    plt.title("Training and Validation Loss")
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.legend()
    plt.grid(True)
    
    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, acc_train_hist, "bo-", label="Training Accuracy (Top-1)")
    plt.plot(epochs_range, acc_valid_hist, "ro-", label="Validation Accuracy (Top-1)")
    plt.title("Training and Validation Accuracy (Top-1)")
    plt.xlabel("Epochs")
    plt.ylabel("Accuracy")
    plt.legend()
    plt.grid(True)
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## GCC dataset

# %%
# !python -m src.run_lstm -e bert -d gcc -ne 7 -rsw 0 -a 1 -b 0 -r 1 -hs 256 -l 2 -nah 8 -lam concat
# Out:
# 2025-07-12 14:12:38.320203: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752329558.343726    1125 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752329558.351072    1125 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Shape after dropping NA assignees: (2103, 6)
# Number of unique assignees (classes): 82
# Warning: Some classes have fewer than 2 samples (min_samples_per_class=1). Stratification for train/test split might not be possible or effective.
# ✅ Loading pre-saved augmented dataset from 'datasets/augmented_train_dataset_2_GCC.csv'.
# Using device: cuda
# Generating Full Embeddings: 100%|█████████████| 276/276 [01:32<00:00,  2.99it/s]
# Generating Full Embeddings: 100%|███████████████| 14/14 [00:04<00:00,  3.15it/s]
# Generating Full Embeddings: 100%|███████████████| 27/27 [00:08<00:00,  3.12it/s]
#
# DataLoaders created successfully!
# Training batches: 276
# Validation batches: 14
# Test batches: 27
# using bert embeddings
#
# ------
# lstm model info:
# {'total_parameters': 2081490, 'trainable_parameters': 2081490, 'model_size_mb': 7.940254211425781, 'config': LSTMConfig(input_size=768, hidden_size=256, num_layers=2, num_classes=82, dropout=0.4, bidirectional=False, use_attention=True, attention_heads=8, attention_dropout=0.1, layer_norm=True, residual_connections=1, gradient_clipping=1.0, luong_attention_method='concat'), 'is_bidirectional': False, 'uses_attention': True, 'attention_heads': 8}
# ------
#
# OPTIMIZER=SGD, LR=0.1
# Epoch 0: 100%|███| 276/276 [00:19<00:00, 13.84batch/s, accuracy=11.5, loss=3.79]
# OPTIMIZER=SGD, LR=0.01
# Epoch 0: 100%|███| 276/276 [00:19<00:00, 14.35batch/s, accuracy=12.6, loss=3.84]
# OPTIMIZER=SGD, LR=0.001
# Epoch 0: 100%|███| 276/276 [00:19<00:00, 14.33batch/s, accuracy=11.2, loss=4.07]
# OPTIMIZER=SGD, LR=0.0001
# Epoch 0: 100%|███| 276/276 [00:19<00:00, 14.33batch/s, accuracy=5.71, loss=4.45]
# OPTIMIZER=Adam, LR=0.1
# Epoch 0: 100%|███| 276/276 [00:19<00:00, 13.94batch/s, accuracy=12.1, loss=6.22]
# OPTIMIZER=Adam, LR=0.01
# Epoch 0: 100%|███| 276/276 [00:19<00:00, 14.05batch/s, accuracy=11.2, loss=3.81]
# OPTIMIZER=Adam, LR=0.001
# Epoch 0: 100%|███| 276/276 [00:19<00:00, 14.13batch/s, accuracy=11.3, loss=3.83]
# OPTIMIZER=Adam, LR=0.0001
# Epoch 0: 100%|███| 276/276 [00:19<00:00, 14.13batch/s, accuracy=19.2, loss=3.75]
# OPTIMIZER=Adamw, LR=0.1
# Epoch 0: 100%|███| 276/276 [00:19<00:00, 14.15batch/s, accuracy=12.4, loss=4.54]
# OPTIMIZER=Adamw, LR=0.01
# Epoch 0: 100%|███| 276/276 [00:19<00:00, 13.99batch/s, accuracy=11.5, loss=3.82]
# OPTIMIZER=Adamw, LR=0.001
# Epoch 0: 100%|█████| 276/276 [00:19<00:00, 13.97batch/s, accuracy=12, loss=3.78]
# OPTIMIZER=Adamw, LR=0.0001
# Epoch 0: 100%|███| 276/276 [00:19<00:00, 14.17batch/s, accuracy=19.4, loss=3.74]
# <class 'torch.optim.adamw.AdamW'> 0.0001
#
# ✅ Start Training 7 epochs ...
# Epoch 1/7 | Current LR: 0.000100
# Epoch 1: 100%|███| 276/276 [00:19<00:00, 14.31batch/s, accuracy=18.4, loss=3.76]
# 	Train: Loss = 3.7568, Acc = 18.4228
# 	Valid: Loss = 3.3458, Acc = 27.4882
# 	✨ New best validation loss: 3.3458
# ------------------------------------------------------------
# Epoch 2/7 | Current LR: 0.000095
# Epoch 2: 100%|███| 276/276 [00:19<00:00, 14.11batch/s, accuracy=33.2, loss=3.18]
# 	Train: Loss = 3.1841, Acc = 33.2427
# 	Valid: Loss = 3.0129, Acc = 36.4929
# 	✨ New best validation loss: 3.0129
# ------------------------------------------------------------
# Epoch 3/7 | Current LR: 0.000081
# Epoch 3: 100%|█████| 276/276 [00:19<00:00, 14.15batch/s, accuracy=40, loss=2.87]
# 	Train: Loss = 2.8673, Acc = 39.9728
# 	Valid: Loss = 2.9514, Acc = 36.0190
# 	✨ New best validation loss: 2.9514
# ------------------------------------------------------------
# Epoch 4/7 | Current LR: 0.000062
# Epoch 4: 100%|███| 276/276 [00:19<00:00, 14.18batch/s, accuracy=45.7, loss=2.62]
# 	Train: Loss = 2.6150, Acc = 45.7059
# 	Valid: Loss = 2.8799, Acc = 41.2322
# 	✨ New best validation loss: 2.8799
# ------------------------------------------------------------
# Epoch 5/7 | Current LR: 0.000039
# Epoch 5: 100%|████| 276/276 [00:19<00:00, 14.25batch/s, accuracy=51.3, loss=2.4]
# 	Train: Loss = 2.4009, Acc = 51.3483
# 	Valid: Loss = 2.8126, Acc = 45.9716
# 	✨ New best validation loss: 2.8126
# ------------------------------------------------------------
# Epoch 6/7 | Current LR: 0.000020
# Epoch 6: 100%|███| 276/276 [00:19<00:00, 14.20batch/s, accuracy=54.8, loss=2.26]
# 	Train: Loss = 2.2636, Acc = 54.8380
# 	Valid: Loss = 2.8023, Acc = 47.3934
# 	✨ New best validation loss: 2.8023
# ------------------------------------------------------------
# Epoch 7/7 | Current LR: 0.000006
# Epoch 7: 100%|███| 276/276 [00:19<00:00, 14.20batch/s, accuracy=57.7, loss=2.18]
# 	Train: Loss = 2.1826, Acc = 57.7158
# 	Valid: Loss = 2.7875, Acc = 48.3412
# 	✨ New best validation loss: 2.7875
# ------------------------------------------------------------
#
# ✅ Loaded best model based on validation accuracy for final testing. /kaggle/working/bac/.models/lstm_bert_model.pt
# Figure(1400x600)
#
# 🧪 Evaluating on Test Set...
#
# --- Test Set Results (Best Validation Model) ---
# 	Test Loss: 2.7640
# 	Test Accuracy (Top-1): 42.28%
# 	Test MRR: 0.5406
# {'loss_train_hist': [3.7567707628443623, 3.1840516570685566, 2.8672952336677606, 2.615008463462194, 2.400866844083952, 2.263550444789555, 2.1825585209805034], 'loss_valid_hist': [3.345844558307103, 3.012934718813215, 2.95144328049251, 2.879944239343916, 2.8126284735543385, 2.802322336605617, 2.7875096797943115], 'acc_train_hist': [18.422841604350783, 33.242692046227056, 39.97280761386812, 45.70586902334013, 51.34828914570587, 54.83797869929753, 57.71583956492182], 'acc_valid_hist': [27.488151658767773, 36.492890995260666, 36.018957345971565, 41.23222748815166, 45.97156398104266, 47.39336492890995, 48.34123222748815], 'test_top_5_acc': 0.6745843230403801, 'test_top_10_acc': 0.7767220902612827, 'test_loss_final': 2.763959875813237, 'test_acc_top1_final': 42.280285035629454, 'test_mrr_final': 0.5406407381889778}

# %%
result_load_path = f"{os.getcwd()}/.result/lstm_bert_result.json"
plot_history(result_load_path, 7)

# %% [markdown]
# ## JDT dataset

# %%
# !python -m src.run_lstm -e bert -d jdt -ne 7 -rsw 0 -a 1 -b 0 -r 1 -hs 256 -l 2 -nah 8 -lam concat
# Out:
# 2025-07-12 14:21:02.968891: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752330062.990776    1374 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752330062.997892    1374 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Shape after dropping NA assignees: (1465, 5)
# Number of unique assignees (classes): 69
# Warning: Some classes have fewer than 2 samples (min_samples_per_class=1). Stratification for train/test split might not be possible or effective.
# ✅ Loading pre-saved augmented dataset from 'datasets/augmented_train_dataset_2_JDT.csv'.
# Using device: cuda
# Generating Full Embeddings: 100%|█████████████| 193/193 [01:03<00:00,  3.06it/s]
# Generating Full Embeddings: 100%|███████████████| 10/10 [00:02<00:00,  3.38it/s]
# Generating Full Embeddings: 100%|███████████████| 19/19 [00:06<00:00,  3.12it/s]
#
# DataLoaders created successfully!
# Training batches: 193
# Validation batches: 10
# Test batches: 19
# using bert embeddings
#
# ------
# lstm model info:
# {'total_parameters': 2079813, 'trainable_parameters': 2079813, 'model_size_mb': 7.933856964111328, 'config': LSTMConfig(input_size=768, hidden_size=256, num_layers=2, num_classes=69, dropout=0.4, bidirectional=False, use_attention=True, attention_heads=8, attention_dropout=0.1, layer_norm=True, residual_connections=1, gradient_clipping=1.0, luong_attention_method='concat'), 'is_bidirectional': False, 'uses_attention': True, 'attention_heads': 8}
# ------
#
# OPTIMIZER=SGD, LR=0.1
# Epoch 0: 100%|███| 193/193 [00:13<00:00, 13.79batch/s, accuracy=13.9, loss=3.58]
# OPTIMIZER=SGD, LR=0.01
# Epoch 0: 100%|████| 193/193 [00:13<00:00, 14.34batch/s, accuracy=14.5, loss=3.6]
# OPTIMIZER=SGD, LR=0.001
# Epoch 0: 100%|███| 193/193 [00:13<00:00, 14.23batch/s, accuracy=9.63, loss=3.94]
# OPTIMIZER=SGD, LR=0.0001
# Epoch 0: 100%|███| 193/193 [00:13<00:00, 14.16batch/s, accuracy=2.96, loss=4.52]
# OPTIMIZER=Adam, LR=0.1
# Epoch 0: 100%|███| 193/193 [00:13<00:00, 13.95batch/s, accuracy=15.1, loss=5.67]
# OPTIMIZER=Adam, LR=0.01
# Epoch 0: 100%|████| 193/193 [00:13<00:00, 13.99batch/s, accuracy=15.1, loss=3.5]
# OPTIMIZER=Adam, LR=0.001
# Epoch 0: 100%|███| 193/193 [00:13<00:00, 14.05batch/s, accuracy=15.9, loss=3.51]
# OPTIMIZER=Adam, LR=0.0001
# Epoch 0: 100%|███| 193/193 [00:13<00:00, 14.08batch/s, accuracy=15.5, loss=3.63]
# OPTIMIZER=Adamw, LR=0.1
# Epoch 0: 100%|███| 193/193 [00:13<00:00, 14.05batch/s, accuracy=14.6, loss=4.81]
# OPTIMIZER=Adamw, LR=0.01
# Epoch 0: 100%|███| 193/193 [00:13<00:00, 13.90batch/s, accuracy=14.8, loss=3.55]
# OPTIMIZER=Adamw, LR=0.001
# Epoch 0: 100%|███| 193/193 [00:13<00:00, 13.85batch/s, accuracy=13.7, loss=3.53]
# OPTIMIZER=Adamw, LR=0.0001
# Epoch 0: 100%|███| 193/193 [00:13<00:00, 14.15batch/s, accuracy=16.4, loss=3.63]
# <class 'torch.optim.adamw.AdamW'> 0.0001
#
# ✅ Start Training 7 epochs ...
# Epoch 1/7 | Current LR: 0.000100
# Epoch 1: 100%|███| 193/193 [00:13<00:00, 14.13batch/s, accuracy=16.3, loss=3.61]
# 	Train: Loss = 3.6136, Acc = 16.2927
# 	Valid: Loss = 3.2227, Acc = 20.4082
# 	✨ New best validation loss: 3.2227
# ------------------------------------------------------------
# Epoch 2/7 | Current LR: 0.000095
# Epoch 2: 100%|████| 193/193 [00:13<00:00, 14.10batch/s, accuracy=24.2, loss=3.2]
# 	Train: Loss = 3.2011, Acc = 24.1951
# 	Valid: Loss = 3.0477, Acc = 27.2109
# 	✨ New best validation loss: 3.0477
# ------------------------------------------------------------
# Epoch 3/7 | Current LR: 0.000081
# Epoch 3: 100%|███| 193/193 [00:13<00:00, 14.23batch/s, accuracy=35.1, loss=2.88]
# 	Train: Loss = 2.8839, Acc = 35.0569
# 	Valid: Loss = 3.1045, Acc = 23.8095
# 	Validation loss did not improve. Patience: 1/5
# ------------------------------------------------------------
# Epoch 4/7 | Current LR: 0.000062
# Epoch 4: 100%|███| 193/193 [00:13<00:00, 14.18batch/s, accuracy=40.3, loss=2.67]
# 	Train: Loss = 2.6689, Acc = 40.2927
# 	Valid: Loss = 3.0046, Acc = 29.2517
# 	✨ New best validation loss: 3.0046
# ------------------------------------------------------------
# Epoch 5/7 | Current LR: 0.000039
# Epoch 5: 100%|█████| 193/193 [00:13<00:00, 14.02batch/s, accuracy=46, loss=2.47]
# 	Train: Loss = 2.4664, Acc = 45.9837
# 	Valid: Loss = 3.0633, Acc = 29.9320
# 	Validation loss did not improve. Patience: 1/5
# ------------------------------------------------------------
# Epoch 6/7 | Current LR: 0.000020
# Epoch 6: 100%|█████| 193/193 [00:13<00:00, 14.16batch/s, accuracy=49, loss=2.35]
# 	Train: Loss = 2.3533, Acc = 49.0407
# 	Valid: Loss = 3.0264, Acc = 30.6122
# 	Validation loss did not improve. Patience: 2/5
# ------------------------------------------------------------
# Epoch 7/7 | Current LR: 0.000006
# Epoch 7: 100%|███| 193/193 [00:13<00:00, 14.17batch/s, accuracy=53.6, loss=2.23]
# 	Train: Loss = 2.2334, Acc = 53.5610
# 	Valid: Loss = 3.0445, Acc = 29.9320
# 	Validation loss did not improve. Patience: 3/5
# ------------------------------------------------------------
#
# ✅ Loaded best model based on validation accuracy for final testing. /kaggle/working/bac/.models/lstm_bert_model.pt
# Figure(1400x600)
#
# 🧪 Evaluating on Test Set...
#
# --- Test Set Results (Best Validation Model) ---
# 	Test Loss: 3.0208
# 	Test Accuracy (Top-1): 26.96%
# 	Test MRR: 0.4509
# {'loss_train_hist': [3.613630514688442, 3.201116003520748, 2.8839221025377975, 2.6688742662340865, 2.4663765059851612, 2.353333690623545, 2.2334208556407473], 'loss_valid_hist': [3.2227298974990846, 3.0477119207382204, 3.1044552326202393, 3.004584050178528, 3.063250494003296, 3.026398253440857, 3.044499373435974], 'acc_train_hist': [16.29268292682927, 24.195121951219512, 35.05691056910569, 40.292682926829265, 45.983739837398375, 49.040650406504064, 53.5609756097561], 'acc_valid_hist': [20.408163265306122, 27.210884353741495, 23.80952380952381, 29.25170068027211, 29.931972789115648, 30.612244897959183, 29.931972789115648], 'test_top_5_acc': 0.6996587030716723, 'test_top_10_acc': 0.8191126279863481, 'test_loss_final': 3.020843819568032, 'test_acc_top1_final': 26.962457337883958, 'test_mrr_final': 0.4509411272320947}

# %%
result_load_path = f"{os.getcwd()}/.result/lstm_bert_result.json"
plot_history(result_load_path, 7)
