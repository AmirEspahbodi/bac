# %%
# %cd /kaggle/working
# !git clone https://github.com/AmirEspahbodi/bac.git
# Out:
# /kaggle/working
# fatal: destination path 'bac' already exists and is not an empty directory.

# %%
# %cd /kaggle/working/bac
# !git pull
# !ls
# Out:
# /kaggle/working/bac
# Already up to date.
# datasets     poetry.lock     README.md	src
# inspiration  pyproject.toml  scripts	state.db

# %%
import os
import json
import matplotlib.pyplot as plt


def plot_history(result_load_path, NUM_EPOCHS):
    loss_train_hist = None
    loss_valid_hist = None
    acc_train_hist = None
    acc_valid_hist = None
    test_top_5_acc = None
    test_top_10_acc = None
    test_loss_final = None
    test_acc_top1_final = None
    test_mrr_final = None
        
    # Load the data from the JSON file
    try:
        with open(result_load_path, "r") as f:
            # json.load() reads the file and parses the JSON data into a Python dictionary
            loaded_results = json.load(f)
    
        # Unpack the dictionary values into your variables
        loss_train_hist = loaded_results.get("loss_train_hist")
        loss_valid_hist = loaded_results.get("loss_valid_hist")
        acc_train_hist = loaded_results.get("acc_train_hist")
        acc_valid_hist = loaded_results.get("acc_valid_hist")
        test_top_5_acc = loaded_results.get("test_top_5_acc")
        test_top_10_acc = loaded_results.get("test_top_10_acc")
        test_loss_final = loaded_results.get("test_loss_final")
        test_acc_top1_final = loaded_results.get("test_acc_top1_final")
        test_mrr_final = loaded_results.get("test_mrr_final")
    
    except FileNotFoundError:
        print(f"Error: The file at '{result_load_path}' was not found.")
    except json.JSONDecodeError:
        print(f"Error: The file at '{result_load_path}' is not a valid JSON file.")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")
    
    epochs_range = range(1, NUM_EPOCHS + 1)
    
    plt.figure(figsize=(14, 6))
    
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, loss_train_hist, "bo-", label="Training Loss")
    plt.plot(epochs_range, loss_valid_hist, "ro-", label="Validation Loss")
    plt.title("Training and Validation Loss")
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.legend()
    plt.grid(True)
    
    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, acc_train_hist, "bo-", label="Training Accuracy (Top-1)")
    plt.plot(epochs_range, acc_valid_hist, "ro-", label="Validation Accuracy (Top-1)")
    plt.title("Training and Validation Accuracy (Top-1)")
    plt.xlabel("Epochs")
    plt.ylabel("Accuracy")
    plt.legend()
    plt.grid(True)
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## GCC dataset

# %%
# !python -m src.run_lstm -e bert -d gcc -ne 7 -rsw 0 -a 1 -b 1 -r 0 -hs 256 -l 2 -nah 1 -lam general
# Out:
# 2025-07-12 12:18:40.540066: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752322720.732613      88 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752322720.788526      88 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Shape after dropping NA assignees: (2103, 6)
# Number of unique assignees (classes): 82
# Warning: Some classes have fewer than 2 samples (min_samples_per_class=1). Stratification for train/test split might not be possible or effective.
# ✅ Loading pre-saved augmented dataset from 'datasets/augmented_train_dataset_2_GCC.csv'.
# tokenizer_config.json: 100%|██████████████████| 48.0/48.0 [00:00<00:00, 384kB/s]
# vocab.txt: 100%|██████████████████████████████| 232k/232k [00:00<00:00, 663kB/s]
# tokenizer.json: 100%|████████████████████████| 466k/466k [00:00<00:00, 35.3MB/s]
# config.json: 100%|█████████████████████████████| 570/570 [00:00<00:00, 4.20MB/s]
# Using device: cuda
# model.safetensors: 100%|██████████████████████| 440M/440M [00:02<00:00, 188MB/s]
# Generating Full Embeddings: 100%|█████████████| 276/276 [01:34<00:00,  2.91it/s]
# Generating Full Embeddings: 100%|███████████████| 14/14 [00:04<00:00,  3.13it/s]
# Generating Full Embeddings: 100%|███████████████| 27/27 [00:08<00:00,  3.11it/s]
#
# DataLoaders created successfully!
# Training batches: 276
# Validation batches: 14
# Test batches: 27
# using bert embeddings
#
# ------
# lstm model info:
# {'total_parameters': 4291666, 'trainable_parameters': 4291666, 'model_size_mb': 16.37140655517578, 'config': LSTMConfig(input_size=768, hidden_size=256, num_layers=2, num_classes=82, dropout=0.4, bidirectional=True, use_attention=True, attention_heads=1, attention_dropout=0.1, layer_norm=True, residual_connections=0, gradient_clipping=1.0, luong_attention_method='general'), 'is_bidirectional': True, 'uses_attention': True, 'attention_heads': 1}
# ------
#
# OPTIMIZER=SGD, LR=0.1
# Epoch 0: 100%|███| 276/276 [00:30<00:00,  8.91batch/s, accuracy=11.7, loss=3.86]
# OPTIMIZER=SGD, LR=0.01
# Epoch 0: 100%|███| 276/276 [00:29<00:00,  9.24batch/s, accuracy=14.3, loss=3.81]
# OPTIMIZER=SGD, LR=0.001
# Epoch 0: 100%|███| 276/276 [00:29<00:00,  9.29batch/s, accuracy=10.9, loss=4.11]
# OPTIMIZER=SGD, LR=0.0001
# Epoch 0: 100%|███| 276/276 [00:29<00:00,  9.28batch/s, accuracy=1.61, loss=4.88]
# OPTIMIZER=Adam, LR=0.1
# Epoch 0: 100%|███| 276/276 [00:30<00:00,  9.07batch/s, accuracy=10.6, loss=7.61]
# OPTIMIZER=Adam, LR=0.01
# Epoch 0: 100%|███| 276/276 [00:30<00:00,  9.10batch/s, accuracy=11.1, loss=3.97]
# OPTIMIZER=Adam, LR=0.001
# Epoch 0: 100%|███| 276/276 [00:30<00:00,  8.98batch/s, accuracy=13.8, loss=3.75]
# OPTIMIZER=Adam, LR=0.0001
# Epoch 0: 100%|███| 276/276 [00:30<00:00,  9.18batch/s, accuracy=19.6, loss=3.69]
# OPTIMIZER=Adamw, LR=0.1
# Epoch 0: 100%|██████| 276/276 [00:30<00:00,  9.11batch/s, accuracy=11.8, loss=7]
# OPTIMIZER=Adamw, LR=0.01
# Epoch 0: 100%|███| 276/276 [00:30<00:00,  9.14batch/s, accuracy=12.3, loss=3.85]
# OPTIMIZER=Adamw, LR=0.001
# Epoch 0: 100%|███| 276/276 [00:30<00:00,  9.10batch/s, accuracy=14.8, loss=3.73]
# OPTIMIZER=Adamw, LR=0.0001
# Epoch 0: 100%|███| 276/276 [00:29<00:00,  9.24batch/s, accuracy=19.6, loss=3.69]
# <class 'torch.optim.adamw.AdamW'> 0.0001
#
# ✅ Start Training 7 epochs ...
# Epoch 1/7 | Current LR: 0.000100
# Epoch 1: 100%|████| 276/276 [00:30<00:00,  9.20batch/s, accuracy=19.4, loss=3.7]
# 	Train: Loss = 3.6960, Acc = 19.4199
# 	Valid: Loss = 3.3084, Acc = 27.0142
# 	✨ New best validation loss: 3.3084
# ------------------------------------------------------------
# Epoch 2/7 | Current LR: 0.000095
# Epoch 2: 100%|███| 276/276 [00:30<00:00,  9.18batch/s, accuracy=36.3, loss=3.01]
# 	Train: Loss = 3.0092, Acc = 36.3245
# 	Valid: Loss = 2.9188, Acc = 37.9147
# 	✨ New best validation loss: 2.9188
# ------------------------------------------------------------
# Epoch 3/7 | Current LR: 0.000081
# Epoch 3: 100%|████| 276/276 [00:30<00:00,  9.13batch/s, accuracy=46.3, loss=2.6]
# 	Train: Loss = 2.5983, Acc = 46.2950
# 	Valid: Loss = 2.8760, Acc = 42.6540
# 	✨ New best validation loss: 2.8760
# ------------------------------------------------------------
# Epoch 4/7 | Current LR: 0.000062
# Epoch 4: 100%|███| 276/276 [00:30<00:00,  9.18batch/s, accuracy=54.7, loss=2.26]
# 	Train: Loss = 2.2581, Acc = 54.7247
# 	Valid: Loss = 2.7359, Acc = 45.9716
# 	✨ New best validation loss: 2.7359
# ------------------------------------------------------------
# Epoch 5/7 | Current LR: 0.000039
# Epoch 5: 100%|███| 276/276 [00:30<00:00,  9.07batch/s, accuracy=64.1, loss=1.98]
# 	Train: Loss = 1.9764, Acc = 64.1287
# 	Valid: Loss = 2.6781, Acc = 43.6019
# 	✨ New best validation loss: 2.6781
# ------------------------------------------------------------
# Epoch 6/7 | Current LR: 0.000020
# Epoch 6: 100%|███| 276/276 [00:30<00:00,  9.14batch/s, accuracy=70.1, loss=1.78]
# 	Train: Loss = 1.7836, Acc = 70.1337
# 	Valid: Loss = 2.6331, Acc = 47.3934
# 	✨ New best validation loss: 2.6331
# ------------------------------------------------------------
# Epoch 7/7 | Current LR: 0.000006
# Epoch 7: 100%|████| 276/276 [00:30<00:00,  9.08batch/s, accuracy=72.7, loss=1.7]
# 	Train: Loss = 1.6982, Acc = 72.7170
# 	Valid: Loss = 2.6222, Acc = 45.9716
# 	✨ New best validation loss: 2.6222
# ------------------------------------------------------------
#
# ✅ Loaded best model based on validation accuracy for final testing. /kaggle/working/bac/.models/lstm_bert_model.pt
# Figure(1400x600)
#
# 🧪 Evaluating on Test Set...
#
# --- Test Set Results (Best Validation Model) ---
# 	Test Loss: 2.5899
# 	Test Accuracy (Top-1): 47.98%
# 	Test MRR: 0.6004
# {'loss_train_hist': [3.6960003747456316, 3.0092451822930486, 2.5982882954936097, 2.2581049216830213, 1.9763911327590113, 1.7836056191852128, 1.6982465196346892], 'loss_valid_hist': [3.3084308930805753, 2.9188103335244313, 2.876043830599104, 2.7359153713498796, 2.678059594971793, 2.6330805165427074, 2.6222376142229353], 'acc_train_hist': [19.41989576251983, 36.32449580784047, 46.29503738953093, 54.72467709041469, 64.12871062769091, 70.13369589848176, 72.71697258101065], 'acc_valid_hist': [27.01421800947867, 37.91469194312796, 42.654028436018955, 45.97156398104266, 43.60189573459716, 47.39336492890995, 45.97156398104266], 'test_top_5_acc': 0.7410926365795725, 'test_top_10_acc': 0.8123515439429929, 'test_loss_final': 2.5899155051619918, 'test_acc_top1_final': 47.980997624703086, 'test_mrr_final': 0.6003663726459328}

# %%
result_load_path = f"{os.getcwd()}/.result/lstm_bert_result.json"
plot_history(result_load_path, 7)

# %% [markdown]
# ## JDT dataset

# %%
# !python -m src.run_lstm -e bert -d jdt -ne 7 -rsw 0 -a 1 -b 1 -r 0 -hs 256 -l 2 -nah 1 -lam general
# Out:
# 2025-07-12 12:30:50.047846: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752323450.070637     354 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752323450.077824     354 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Shape after dropping NA assignees: (1465, 5)
# Number of unique assignees (classes): 69
# Warning: Some classes have fewer than 2 samples (min_samples_per_class=1). Stratification for train/test split might not be possible or effective.
# ✅ Loading pre-saved augmented dataset from 'datasets/augmented_train_dataset_2_JDT.csv'.
# Using device: cuda
# Generating Full Embeddings: 100%|█████████████| 193/193 [01:07<00:00,  2.88it/s]
# Generating Full Embeddings: 100%|███████████████| 10/10 [00:03<00:00,  3.33it/s]
# Generating Full Embeddings: 100%|███████████████| 19/19 [00:06<00:00,  3.09it/s]
#
# DataLoaders created successfully!
# Training batches: 193
# Validation batches: 10
# Test batches: 19
# using bert embeddings
#
# ------
# lstm model info:
# {'total_parameters': 4288325, 'trainable_parameters': 4288325, 'model_size_mb': 16.358661651611328, 'config': LSTMConfig(input_size=768, hidden_size=256, num_layers=2, num_classes=69, dropout=0.4, bidirectional=True, use_attention=True, attention_heads=1, attention_dropout=0.1, layer_norm=True, residual_connections=0, gradient_clipping=1.0, luong_attention_method='general'), 'is_bidirectional': True, 'uses_attention': True, 'attention_heads': 1}
# ------
#
# OPTIMIZER=SGD, LR=0.1
# Epoch 0: 100%|███| 193/193 [00:21<00:00,  9.03batch/s, accuracy=14.2, loss=3.62]
# OPTIMIZER=SGD, LR=0.01
# Epoch 0: 100%|████| 193/193 [00:21<00:00,  9.17batch/s, accuracy=14.6, loss=3.5]
# OPTIMIZER=SGD, LR=0.001
# Epoch 0: 100%|███| 193/193 [00:21<00:00,  9.17batch/s, accuracy=12.2, loss=3.79]
# OPTIMIZER=SGD, LR=0.0001
# Epoch 0: 100%|████| 193/193 [00:21<00:00,  9.17batch/s, accuracy=3.61, loss=4.4]
# OPTIMIZER=Adam, LR=0.1
# Epoch 0: 100%|███| 193/193 [00:21<00:00,  8.99batch/s, accuracy=13.2, loss=8.02]
# OPTIMIZER=Adam, LR=0.01
# Epoch 0: 100%|█████| 193/193 [00:21<00:00,  8.98batch/s, accuracy=14, loss=3.62]
# OPTIMIZER=Adam, LR=0.001
# Epoch 0: 100%|███| 193/193 [00:21<00:00,  9.01batch/s, accuracy=18.8, loss=3.41]
# OPTIMIZER=Adam, LR=0.0001
# Epoch 0: 100%|███| 193/193 [00:21<00:00,  9.12batch/s, accuracy=17.9, loss=3.45]
# OPTIMIZER=Adamw, LR=0.1
# Epoch 0: 100%|███| 193/193 [00:21<00:00,  9.02batch/s, accuracy=15.3, loss=6.58]
# OPTIMIZER=Adamw, LR=0.01
# Epoch 0: 100%|███| 193/193 [00:21<00:00,  9.04batch/s, accuracy=14.5, loss=3.59]
# OPTIMIZER=Adamw, LR=0.001
# Epoch 0: 100%|███| 193/193 [00:21<00:00,  9.02batch/s, accuracy=16.3, loss=3.45]
# OPTIMIZER=Adamw, LR=0.0001
# Epoch 0: 100%|███| 193/193 [00:21<00:00,  9.15batch/s, accuracy=18.3, loss=3.44]
# <class 'torch.optim.adam.Adam'> 0.001
#
# ✅ Start Training 7 epochs ...
# Epoch 1/7 | Current LR: 0.001000
# Epoch 1: 100%|███| 193/193 [00:21<00:00,  8.93batch/s, accuracy=16.7, loss=3.45]
# 	Train: Loss = 3.4501, Acc = 16.7480
# 	Valid: Loss = 3.1998, Acc = 21.7687
# 	✨ New best validation loss: 3.1998
# ------------------------------------------------------------
# Epoch 2/7 | Current LR: 0.000951
# Epoch 2: 100%|████| 193/193 [00:21<00:00,  9.06batch/s, accuracy=21.8, loss=3.2]
# 	Train: Loss = 3.2007, Acc = 21.7886
# 	Valid: Loss = 2.9786, Acc = 23.1293
# 	✨ New best validation loss: 2.9786
# ------------------------------------------------------------
# Epoch 3/7 | Current LR: 0.000812
# Epoch 3: 100%|███| 193/193 [00:21<00:00,  8.95batch/s, accuracy=28.9, loss=2.99]
# 	Train: Loss = 2.9876, Acc = 28.9106
# 	Valid: Loss = 2.8952, Acc = 27.8912
# 	✨ New best validation loss: 2.8952
# ------------------------------------------------------------
# Epoch 4/7 | Current LR: 0.000612
# Epoch 4: 100%|███| 193/193 [00:21<00:00,  8.92batch/s, accuracy=41.3, loss=2.67]
# 	Train: Loss = 2.6708, Acc = 41.2683
# 	Valid: Loss = 2.6562, Acc = 40.8163
# 	✨ New best validation loss: 2.6562
# ------------------------------------------------------------
# Epoch 5/7 | Current LR: 0.000389
# Epoch 5: 100%|███| 193/193 [00:21<00:00,  8.91batch/s, accuracy=48.7, loss=2.38]
# 	Train: Loss = 2.3805, Acc = 48.6829
# 	Valid: Loss = 2.6877, Acc = 38.0952
# 	Validation loss did not improve. Patience: 1/5
# ------------------------------------------------------------
# Epoch 6/7 | Current LR: 0.000189
# Epoch 6: 100%|███| 193/193 [00:21<00:00,  9.00batch/s, accuracy=56.8, loss=2.12]
# 	Train: Loss = 2.1211, Acc = 56.7805
# 	Valid: Loss = 2.7002, Acc = 42.1769
# 	Validation loss did not improve. Patience: 2/5
# ------------------------------------------------------------
# Epoch 7/7 | Current LR: 0.000050
# Epoch 7: 100%|████| 193/193 [00:21<00:00,  9.02batch/s, accuracy=63.9, loss=1.9]
# 	Train: Loss = 1.8969, Acc = 63.9350
# 	Valid: Loss = 2.7307, Acc = 38.7755
# 	Validation loss did not improve. Patience: 3/5
# ------------------------------------------------------------
#
# ✅ Loaded best model based on validation accuracy for final testing. /kaggle/working/bac/.models/lstm_bert_model.pt
# Figure(1400x600)
#
# 🧪 Evaluating on Test Set...
#
# --- Test Set Results (Best Validation Model) ---
# 	Test Loss: 2.8838
# 	Test Accuracy (Top-1): 33.79%
# 	Test MRR: 0.5010
# {'loss_train_hist': [3.4501363502265256, 3.200741550465322, 2.987623143072573, 2.670835344284927, 2.3804684840335746, 2.1211067648131614, 1.896948214021989], 'loss_valid_hist': [3.199798607826233, 2.978568363189697, 2.89519317150116, 2.6561779499053957, 2.68766713142395, 2.7002393126487734, 2.730662500858307], 'acc_train_hist': [16.747967479674795, 21.788617886178862, 28.910569105691057, 41.26829268292683, 48.68292682926829, 56.78048780487805, 63.9349593495935], 'acc_valid_hist': [21.768707482993197, 23.12925170068027, 27.891156462585034, 40.816326530612244, 38.095238095238095, 42.17687074829932, 38.775510204081634], 'test_top_5_acc': 0.689419795221843, 'test_top_10_acc': 0.8225255972696246, 'test_loss_final': 2.883757101862054, 'test_acc_top1_final': 33.78839590443686, 'test_mrr_final': 0.5010256998472209}

# %%
result_load_path = f"{os.getcwd()}/.result/lstm_bert_result.json"
plot_history(result_load_path, 7)
