# %%
# %cd /kaggle/working
# !git clone https://github.com/AmirEspahbodi/bac.git
# Out:
# /kaggle/working
# fatal: destination path 'bac' already exists and is not an empty directory.

# %%
# !pip install bitsandbytes

# %%
# %cd /kaggle/working/bac
# !git pull
# !ls
# Out:
# /kaggle/working/bac
# Already up to date.
# datasets     poetry.lock     README.md	src
# inspiration  pyproject.toml  scripts	state.db

# %%
import os
import json
import matplotlib.pyplot as plt


def plot_history(result_load_path, NUM_EPOCHS):
    loss_train_hist = None
    loss_valid_hist = None
    acc_train_hist = None
    acc_valid_hist = None
    test_top_5_acc = None
    test_top_10_acc = None
    test_loss_final = None
    test_acc_top1_final = None
    test_mrr_final = None
        
    # Load the data from the JSON file
    try:
        with open(result_load_path, "r") as f:
            # json.load() reads the file and parses the JSON data into a Python dictionary
            loaded_results = json.load(f)
    
        # Unpack the dictionary values into your variables
        loss_train_hist = loaded_results.get("loss_train_hist")
        loss_valid_hist = loaded_results.get("loss_valid_hist")
        acc_train_hist = loaded_results.get("acc_train_hist")
        acc_valid_hist = loaded_results.get("acc_valid_hist")
        test_top_5_acc = loaded_results.get("test_top_5_acc")
        test_top_10_acc = loaded_results.get("test_top_10_acc")
        test_loss_final = loaded_results.get("test_loss_final")
        test_acc_top1_final = loaded_results.get("test_acc_top1_final")
        test_mrr_final = loaded_results.get("test_mrr_final")
    
    except FileNotFoundError:
        print(f"Error: The file at '{result_load_path}' was not found.")
    except json.JSONDecodeError:
        print(f"Error: The file at '{result_load_path}' is not a valid JSON file.")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")
    
    epochs_range = range(1, NUM_EPOCHS + 1)
    
    plt.figure(figsize=(14, 6))
    
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, loss_train_hist, "bo-", label="Training Loss")
    plt.plot(epochs_range, loss_valid_hist, "ro-", label="Validation Loss")
    plt.title("Training and Validation Loss")
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.legend()
    plt.grid(True)
    
    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, acc_train_hist, "bo-", label="Training Accuracy (Top-1)")
    plt.plot(epochs_range, acc_valid_hist, "ro-", label="Validation Accuracy (Top-1)")
    plt.title("Training and Validation Accuracy (Top-1)")
    plt.xlabel("Epochs")
    plt.ylabel("Accuracy")
    plt.legend()
    plt.grid(True)
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## GCC dataset

# %%
# !python -m src.run_lstm -e bert -d gcc -ne 7 -rsw 0 -a 1 -b 0 -r 0 -hs 256 -l 2 -nah 1 -lam dot
# Out:
# 2025-07-12 15:38:11.648231: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752334691.671229     611 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752334691.678217     611 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Shape after dropping NA assignees: (2103, 6)
# Number of unique assignees (classes): 82
# Warning: Some classes have fewer than 2 samples (min_samples_per_class=1). Stratification for train/test split might not be possible or effective.
# ✅ Loading pre-saved augmented dataset from 'datasets/augmented_train_dataset_2_GCC.csv'.
# Using device: cuda
# Generating Full Embeddings: 100%|█████████████| 276/276 [01:33<00:00,  2.96it/s]
# Generating Full Embeddings: 100%|███████████████| 14/14 [00:04<00:00,  3.11it/s]
# Generating Full Embeddings: 100%|███████████████| 27/27 [00:08<00:00,  3.09it/s]
#
# DataLoaders created successfully!
# Training batches: 276
# Validation batches: 14
# Test batches: 27
# using bert embeddings
#
# ------
# lstm model info:
# {'total_parameters': 1818322, 'trainable_parameters': 1818322, 'model_size_mb': 6.936347961425781, 'config': LSTMConfig(input_size=768, hidden_size=256, num_layers=2, num_classes=82, dropout=0.4, bidirectional=False, use_attention=True, attention_heads=1, attention_dropout=0.1, layer_norm=True, residual_connections=0, gradient_clipping=1.0, luong_attention_method='dot'), 'is_bidirectional': False, 'uses_attention': True, 'attention_heads': 1}
# ------
#
# OPTIMIZER=SGD, LR=0.1
# Epoch 0: 100%|███| 276/276 [00:19<00:00, 13.94batch/s, accuracy=11.8, loss=3.83]
# OPTIMIZER=SGD, LR=0.01
# Epoch 0: 100%|███| 276/276 [00:19<00:00, 14.46batch/s, accuracy=13.6, loss=3.86]
# OPTIMIZER=SGD, LR=0.001
# Epoch 0: 100%|████| 276/276 [00:19<00:00, 14.41batch/s, accuracy=9.88, loss=4.2]
# OPTIMIZER=SGD, LR=0.0001
# Epoch 0: 100%|████| 276/276 [00:18<00:00, 14.53batch/s, accuracy=2.29, loss=4.7]
# OPTIMIZER=Adam, LR=0.1
# Epoch 0: 100%|████| 276/276 [00:19<00:00, 14.08batch/s, accuracy=12.9, loss=4.4]
# OPTIMIZER=Adam, LR=0.01
# Epoch 0: 100%|███| 276/276 [00:19<00:00, 14.21batch/s, accuracy=11.9, loss=3.84]
# OPTIMIZER=Adam, LR=0.001
# Epoch 0: 100%|███| 276/276 [00:19<00:00, 14.36batch/s, accuracy=14.8, loss=3.76]
# OPTIMIZER=Adam, LR=0.0001
# Epoch 0: 100%|███| 276/276 [00:19<00:00, 14.35batch/s, accuracy=18.1, loss=3.82]
# OPTIMIZER=Adamw, LR=0.1
# Epoch 0: 100%|████| 276/276 [00:19<00:00, 14.25batch/s, accuracy=11.9, loss=4.2]
# OPTIMIZER=Adamw, LR=0.01
# Epoch 0: 100%|███| 276/276 [00:19<00:00, 14.21batch/s, accuracy=12.4, loss=3.77]
# OPTIMIZER=Adamw, LR=0.001
# Epoch 0: 100%|████| 276/276 [00:19<00:00, 14.48batch/s, accuracy=13.2, loss=3.8]
# OPTIMIZER=Adamw, LR=0.0001
# Epoch 0: 100%|███| 276/276 [00:19<00:00, 14.50batch/s, accuracy=18.5, loss=3.85]
# <class 'torch.optim.adamw.AdamW'> 0.0001
#
# ✅ Start Training 7 epochs ...
# Epoch 1/7 | Current LR: 0.000100
# Epoch 1: 100%|███| 276/276 [00:18<00:00, 14.54batch/s, accuracy=18.7, loss=3.82]
# 	Train: Loss = 3.8171, Acc = 18.6721
# 	Valid: Loss = 3.4715, Acc = 28.9100
# 	✨ New best validation loss: 3.4715
# ------------------------------------------------------------
# Epoch 2/7 | Current LR: 0.000095
# Epoch 2: 100%|███| 276/276 [00:18<00:00, 14.66batch/s, accuracy=32.4, loss=3.27]
# 	Train: Loss = 3.2687, Acc = 32.4496
# 	Valid: Loss = 3.1873, Acc = 31.2796
# 	✨ New best validation loss: 3.1873
# ------------------------------------------------------------
# Epoch 3/7 | Current LR: 0.000081
# Epoch 3: 100%|███| 276/276 [00:19<00:00, 14.51batch/s, accuracy=37.5, loss=2.97]
# 	Train: Loss = 2.9653, Acc = 37.5028
# 	Valid: Loss = 3.1041, Acc = 33.6493
# 	✨ New best validation loss: 3.1041
# ------------------------------------------------------------
# Epoch 4/7 | Current LR: 0.000062
# Epoch 4: 100%|███| 276/276 [00:18<00:00, 14.66batch/s, accuracy=44.1, loss=2.71]
# 	Train: Loss = 2.7113, Acc = 44.1423
# 	Valid: Loss = 3.0041, Acc = 37.4408
# 	✨ New best validation loss: 3.0041
# ------------------------------------------------------------
# Epoch 5/7 | Current LR: 0.000039
# Epoch 5: 100%|███| 276/276 [00:18<00:00, 14.64batch/s, accuracy=48.3, loss=2.52]
# 	Train: Loss = 2.5209, Acc = 48.2891
# 	Valid: Loss = 2.9659, Acc = 38.3886
# 	✨ New best validation loss: 2.9659
# ------------------------------------------------------------
# Epoch 6/7 | Current LR: 0.000020
# Epoch 6: 100%|██████| 276/276 [00:18<00:00, 14.60batch/s, accuracy=52, loss=2.4]
# 	Train: Loss = 2.3966, Acc = 52.0281
# 	Valid: Loss = 2.9280, Acc = 39.3365
# 	✨ New best validation loss: 2.9280
# ------------------------------------------------------------
# Epoch 7/7 | Current LR: 0.000006
# Epoch 7: 100%|███| 276/276 [00:18<00:00, 14.56batch/s, accuracy=54.2, loss=2.31]
# 	Train: Loss = 2.3144, Acc = 54.1582
# 	Valid: Loss = 2.9057, Acc = 42.1801
# 	✨ New best validation loss: 2.9057
# ------------------------------------------------------------
#
# ✅ Loaded best model based on validation accuracy for final testing. /kaggle/working/bac/.models/lstm_bert_model.pt
# Figure(1400x600)
#
# 🧪 Evaluating on Test Set...
#
# --- Test Set Results (Best Validation Model) ---
# 	Test Loss: 2.8081
# 	Test Accuracy (Top-1): 41.33%
# 	Test MRR: 0.5364
# {'loss_train_hist': [3.817136672095976, 3.2686673739682073, 2.96528678484585, 2.7113284213819364, 2.520855553340221, 2.3966436623663143, 2.3144263124120408], 'loss_valid_hist': [3.4715393781661987, 3.1873170137405396, 3.1040546553475514, 3.004080125263759, 2.9659366607666016, 2.928023730005537, 2.9057315247399464], 'acc_train_hist': [18.67210514389304, 32.449580784047136, 37.50283254022207, 44.14230682075686, 48.289145705869025, 52.02809879900295, 54.15816904600045], 'acc_valid_hist': [28.90995260663507, 31.27962085308057, 33.649289099526065, 37.44075829383886, 38.388625592417064, 39.33649289099526, 42.18009478672986], 'test_top_5_acc': 0.684085510688836, 'test_top_10_acc': 0.7790973871733967, 'test_loss_final': 2.808073979836923, 'test_acc_top1_final': 41.33016627078385, 'test_mrr_final': 0.5364320650599382}

# %%
result_load_path = f"{os.getcwd()}/.result/lstm_bert_result.json"
plot_history(result_load_path, 7)

# %% [markdown]
# ## JDT dataset

# %%
# !python -m src.run_lstm -e bert -d jdt -ne 7 -rsw 0 -a 1 -b 0 -r 0 -hs 256 -l 2 -nah 1 -lam dot
# Out:
# 2025-07-12 15:46:30.232206: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752335190.254483     860 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752335190.261325     860 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Shape after dropping NA assignees: (1465, 5)
# Number of unique assignees (classes): 69
# Warning: Some classes have fewer than 2 samples (min_samples_per_class=1). Stratification for train/test split might not be possible or effective.
# ✅ Loading pre-saved augmented dataset from 'datasets/augmented_train_dataset_2_JDT.csv'.
# Using device: cuda
# Generating Full Embeddings: 100%|█████████████| 193/193 [01:03<00:00,  3.03it/s]
# Generating Full Embeddings: 100%|███████████████| 10/10 [00:02<00:00,  3.35it/s]
# Generating Full Embeddings: 100%|███████████████| 19/19 [00:06<00:00,  3.11it/s]
#
# DataLoaders created successfully!
# Training batches: 193
# Validation batches: 10
# Test batches: 19
# using bert embeddings
#
# ------
# lstm model info:
# {'total_parameters': 1816645, 'trainable_parameters': 1816645, 'model_size_mb': 6.929950714111328, 'config': LSTMConfig(input_size=768, hidden_size=256, num_layers=2, num_classes=69, dropout=0.4, bidirectional=False, use_attention=True, attention_heads=1, attention_dropout=0.1, layer_norm=True, residual_connections=0, gradient_clipping=1.0, luong_attention_method='dot'), 'is_bidirectional': False, 'uses_attention': True, 'attention_heads': 1}
# ------
#
# OPTIMIZER=SGD, LR=0.1
# Epoch 0: 100%|███| 193/193 [00:13<00:00, 14.25batch/s, accuracy=14.9, loss=3.59]
# OPTIMIZER=SGD, LR=0.01
# Epoch 0: 100%|████| 193/193 [00:13<00:00, 14.60batch/s, accuracy=16.2, loss=3.5]
# OPTIMIZER=SGD, LR=0.001
# Epoch 0: 100%|███| 193/193 [00:13<00:00, 14.73batch/s, accuracy=13.6, loss=3.75]
# OPTIMIZER=SGD, LR=0.0001
# Epoch 0: 100%|███| 193/193 [00:13<00:00, 14.67batch/s, accuracy=7.32, loss=4.29]
# OPTIMIZER=Adam, LR=0.1
# Epoch 0: 100%|███| 193/193 [00:13<00:00, 14.48batch/s, accuracy=15.2, loss=4.56]
# OPTIMIZER=Adam, LR=0.01
# Epoch 0: 100%|█████| 193/193 [00:13<00:00, 14.62batch/s, accuracy=14, loss=3.51]
# OPTIMIZER=Adam, LR=0.001
# Epoch 0: 100%|███| 193/193 [00:13<00:00, 14.68batch/s, accuracy=16.3, loss=3.46]
# OPTIMIZER=Adam, LR=0.0001
# Epoch 0: 100%|███| 193/193 [00:13<00:00, 14.71batch/s, accuracy=16.7, loss=3.53]
# OPTIMIZER=Adamw, LR=0.1
# Epoch 0: 100%|████| 193/193 [00:13<00:00, 14.46batch/s, accuracy=15.4, loss=4.5]
# OPTIMIZER=Adamw, LR=0.01
# Epoch 0: 100%|████| 193/193 [00:13<00:00, 14.41batch/s, accuracy=15.2, loss=3.5]
# OPTIMIZER=Adamw, LR=0.001
# Epoch 0: 100%|███| 193/193 [00:13<00:00, 14.62batch/s, accuracy=16.9, loss=3.44]
# OPTIMIZER=Adamw, LR=0.0001
# Epoch 0: 100%|█████| 193/193 [00:13<00:00, 14.57batch/s, accuracy=17, loss=3.53]
# <class 'torch.optim.adamw.AdamW'> 0.0001
#
# ✅ Start Training 7 epochs ...
# Epoch 1/7 | Current LR: 0.000100
# Epoch 1: 100%|████| 193/193 [00:13<00:00, 14.72batch/s, accuracy=17.4, loss=3.5]
# 	Train: Loss = 3.5027, Acc = 17.4309
# 	Valid: Loss = 3.2177, Acc = 21.7687
# 	✨ New best validation loss: 3.2177
# ------------------------------------------------------------
# Epoch 2/7 | Current LR: 0.000095
# Epoch 2: 100%|████| 193/193 [00:13<00:00, 14.65batch/s, accuracy=23.8, loss=3.2]
# 	Train: Loss = 3.2013, Acc = 23.8374
# 	Valid: Loss = 3.0781, Acc = 25.1701
# 	✨ New best validation loss: 3.0781
# ------------------------------------------------------------
# Epoch 3/7 | Current LR: 0.000081
# Epoch 3: 100%|███| 193/193 [00:13<00:00, 14.65batch/s, accuracy=31.2, loss=2.97]
# 	Train: Loss = 2.9707, Acc = 31.2195
# 	Valid: Loss = 3.0055, Acc = 28.5714
# 	✨ New best validation loss: 3.0055
# ------------------------------------------------------------
# Epoch 4/7 | Current LR: 0.000062
# Epoch 4: 100%|███| 193/193 [00:13<00:00, 14.75batch/s, accuracy=38.6, loss=2.73]
# 	Train: Loss = 2.7331, Acc = 38.5691
# 	Valid: Loss = 2.9452, Acc = 28.5714
# 	✨ New best validation loss: 2.9452
# ------------------------------------------------------------
# Epoch 5/7 | Current LR: 0.000039
# Epoch 5: 100%|█████| 193/193 [00:13<00:00, 14.66batch/s, accuracy=42, loss=2.57]
# 	Train: Loss = 2.5731, Acc = 42.0488
# 	Valid: Loss = 2.9835, Acc = 28.5714
# 	Validation loss did not improve. Patience: 1/5
# ------------------------------------------------------------
# Epoch 6/7 | Current LR: 0.000020
# Epoch 6: 100%|███| 193/193 [00:13<00:00, 14.72batch/s, accuracy=45.6, loss=2.45]
# 	Train: Loss = 2.4481, Acc = 45.5935
# 	Valid: Loss = 2.9633, Acc = 31.9728
# 	Validation loss did not improve. Patience: 2/5
# ------------------------------------------------------------
# Epoch 7/7 | Current LR: 0.000006
# Epoch 7: 100%|███| 193/193 [00:13<00:00, 14.56batch/s, accuracy=47.7, loss=2.39]
# 	Train: Loss = 2.3880, Acc = 47.6748
# 	Valid: Loss = 2.9858, Acc = 31.9728
# 	Validation loss did not improve. Patience: 3/5
# ------------------------------------------------------------
#
# ✅ Loaded best model based on validation accuracy for final testing. /kaggle/working/bac/.models/lstm_bert_model.pt
# Figure(1400x600)
#
# 🧪 Evaluating on Test Set...
#
# --- Test Set Results (Best Validation Model) ---
# 	Test Loss: 3.0328
# 	Test Accuracy (Top-1): 26.62%
# 	Test MRR: 0.4398
# {'loss_train_hist': [3.50273228556381, 3.201257915694479, 2.9707040552030572, 2.733119043043858, 2.573051970239748, 2.4480893426608543, 2.387954753297598], 'loss_valid_hist': [3.217719554901123, 3.0781071186065674, 3.005535912513733, 2.9452194452285765, 2.98350350856781, 2.9632572650909426, 2.98578884601593], 'acc_train_hist': [17.43089430894309, 23.83739837398374, 31.21951219512195, 38.56910569105691, 42.048780487804876, 45.59349593495935, 47.67479674796748], 'acc_valid_hist': [21.768707482993197, 25.170068027210885, 28.571428571428573, 28.571428571428573, 28.571428571428573, 31.972789115646258, 31.972789115646258], 'test_top_5_acc': 0.6655290102389079, 'test_top_10_acc': 0.8191126279863481, 'test_loss_final': 3.032844568553724, 'test_acc_top1_final': 26.621160409556314, 'test_mrr_final': 0.43975922285586716}

# %%
result_load_path = f"{os.getcwd()}/.result/lstm_bert_result.json"
plot_history(result_load_path, 7)
