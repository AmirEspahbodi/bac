# %%
# %cd /kaggle/working
# !git clone https://github.com/AmirEspahbodi/bac.git
# Out:
# /kaggle/working
# fatal: destination path 'bac' already exists and is not an empty directory.

# %%
# !pip install bitsandbytes

# %%
# %cd /kaggle/working/bac
# !git pull
# !ls
# Out:
# /kaggle/working/bac
# Already up to date.
# datasets     poetry.lock     README.md	src
# inspiration  pyproject.toml  scripts	state.db

# %%
import os
import json
import matplotlib.pyplot as plt


def plot_history(result_load_path, NUM_EPOCHS):
    loss_train_hist = None
    loss_valid_hist = None
    acc_train_hist = None
    acc_valid_hist = None
    test_top_5_acc = None
    test_top_10_acc = None
    test_loss_final = None
    test_acc_top1_final = None
    test_mrr_final = None
        
    # Load the data from the JSON file
    try:
        with open(result_load_path, "r") as f:
            # json.load() reads the file and parses the JSON data into a Python dictionary
            loaded_results = json.load(f)
    
        # Unpack the dictionary values into your variables
        loss_train_hist = loaded_results.get("loss_train_hist")
        loss_valid_hist = loaded_results.get("loss_valid_hist")
        acc_train_hist = loaded_results.get("acc_train_hist")
        acc_valid_hist = loaded_results.get("acc_valid_hist")
        test_top_5_acc = loaded_results.get("test_top_5_acc")
        test_top_10_acc = loaded_results.get("test_top_10_acc")
        test_loss_final = loaded_results.get("test_loss_final")
        test_acc_top1_final = loaded_results.get("test_acc_top1_final")
        test_mrr_final = loaded_results.get("test_mrr_final")
    
    except FileNotFoundError:
        print(f"Error: The file at '{result_load_path}' was not found.")
    except json.JSONDecodeError:
        print(f"Error: The file at '{result_load_path}' is not a valid JSON file.")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")
    
    epochs_range = range(1, NUM_EPOCHS + 1)
    
    plt.figure(figsize=(14, 6))
    
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, loss_train_hist, "bo-", label="Training Loss")
    plt.plot(epochs_range, loss_valid_hist, "ro-", label="Validation Loss")
    plt.title("Training and Validation Loss")
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.legend()
    plt.grid(True)
    
    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, acc_train_hist, "bo-", label="Training Accuracy (Top-1)")
    plt.plot(epochs_range, acc_valid_hist, "ro-", label="Validation Accuracy (Top-1)")
    plt.title("Training and Validation Accuracy (Top-1)")
    plt.xlabel("Epochs")
    plt.ylabel("Accuracy")
    plt.legend()
    plt.grid(True)
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## GCC dataset

# %%
# !python -m src.run_lstm -e bert -d gcc -ne 7 -rsw 0 -a 1 -b 0 -r 1 -hs 256 -l 2 -nah 1 -lam general
# Out:
# 2025-07-12 16:45:31.357034: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752338731.382366    1220 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752338731.389277    1220 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Shape after dropping NA assignees: (2103, 6)
# Number of unique assignees (classes): 82
# Warning: Some classes have fewer than 2 samples (min_samples_per_class=1). Stratification for train/test split might not be possible or effective.
# ✅ Loading pre-saved augmented dataset from 'datasets/augmented_train_dataset_2_GCC.csv'.
# Using device: cuda
# Generating Full Embeddings: 100%|█████████████| 276/276 [01:33<00:00,  2.96it/s]
# Generating Full Embeddings: 100%|███████████████| 14/14 [00:04<00:00,  3.10it/s]
# Generating Full Embeddings: 100%|███████████████| 27/27 [00:08<00:00,  3.05it/s]
#
# DataLoaders created successfully!
# Training batches: 276
# Validation batches: 14
# Test batches: 27
# using bert embeddings
#
# ------
# lstm model info:
# {'total_parameters': 1883858, 'trainable_parameters': 1883858, 'model_size_mb': 7.186347961425781, 'config': LSTMConfig(input_size=768, hidden_size=256, num_layers=2, num_classes=82, dropout=0.4, bidirectional=False, use_attention=True, attention_heads=1, attention_dropout=0.1, layer_norm=True, residual_connections=1, gradient_clipping=1.0, luong_attention_method='general'), 'is_bidirectional': False, 'uses_attention': True, 'attention_heads': 1}
# ------
#
# OPTIMIZER=SGD, LR=0.1
# Epoch 0: 100%|███| 276/276 [00:20<00:00, 13.75batch/s, accuracy=11.9, loss=3.82]
# OPTIMIZER=SGD, LR=0.01
# Epoch 0: 100%|███| 276/276 [00:19<00:00, 14.34batch/s, accuracy=12.4, loss=3.87]
# OPTIMIZER=SGD, LR=0.001
# Epoch 0: 100%|███| 276/276 [00:19<00:00, 14.37batch/s, accuracy=9.54, loss=4.19]
# OPTIMIZER=SGD, LR=0.0001
# Epoch 0: 100%|████| 276/276 [00:19<00:00, 14.32batch/s, accuracy=2.7, loss=4.64]
# OPTIMIZER=Adam, LR=0.1
# Epoch 0: 100%|███| 276/276 [00:19<00:00, 14.08batch/s, accuracy=11.5, loss=4.44]
# OPTIMIZER=Adam, LR=0.01
# Epoch 0: 100%|███| 276/276 [00:19<00:00, 14.11batch/s, accuracy=12.6, loss=3.78]
# OPTIMIZER=Adam, LR=0.001
# Epoch 0: 100%|████| 276/276 [00:19<00:00, 13.94batch/s, accuracy=13.1, loss=3.8]
# OPTIMIZER=Adam, LR=0.0001
# Epoch 0: 100%|███| 276/276 [00:19<00:00, 14.13batch/s, accuracy=17.1, loss=3.89]
# OPTIMIZER=Adamw, LR=0.1
# Epoch 0: 100%|███| 276/276 [00:19<00:00, 14.04batch/s, accuracy=11.9, loss=4.21]
# OPTIMIZER=Adamw, LR=0.01
# Epoch 0: 100%|████| 276/276 [00:19<00:00, 14.13batch/s, accuracy=12.3, loss=3.8]
# OPTIMIZER=Adamw, LR=0.001
# Epoch 0: 100%|███| 276/276 [00:19<00:00, 14.04batch/s, accuracy=13.8, loss=3.78]
# OPTIMIZER=Adamw, LR=0.0001
# Epoch 0: 100%|███| 276/276 [00:19<00:00, 14.26batch/s, accuracy=17.7, loss=3.86]
# <class 'torch.optim.adamw.AdamW'> 0.0001
#
# ✅ Start Training 7 epochs ...
# Epoch 1/7 | Current LR: 0.000100
# Epoch 1: 100%|███| 276/276 [00:19<00:00, 14.09batch/s, accuracy=17.7, loss=3.85]
# 	Train: Loss = 3.8542, Acc = 17.6977
# 	Valid: Loss = 3.4920, Acc = 23.6967
# 	✨ New best validation loss: 3.4920
# ------------------------------------------------------------
# Epoch 2/7 | Current LR: 0.000095
# Epoch 2: 100%|████| 276/276 [00:19<00:00, 14.16batch/s, accuracy=30.6, loss=3.3]
# 	Train: Loss = 3.3041, Acc = 30.6141
# 	Valid: Loss = 3.1279, Acc = 30.8057
# 	✨ New best validation loss: 3.1279
# ------------------------------------------------------------
# Epoch 3/7 | Current LR: 0.000081
# Epoch 3: 100%|███| 276/276 [00:19<00:00, 14.16batch/s, accuracy=38.3, loss=2.95]
# 	Train: Loss = 2.9526, Acc = 38.2733
# 	Valid: Loss = 2.9934, Acc = 39.8104
# 	✨ New best validation loss: 2.9934
# ------------------------------------------------------------
# Epoch 4/7 | Current LR: 0.000062
# Epoch 4: 100%|███| 276/276 [00:19<00:00, 14.20batch/s, accuracy=43.8, loss=2.72]
# 	Train: Loss = 2.7231, Acc = 43.7571
# 	Valid: Loss = 2.9129, Acc = 38.3886
# 	✨ New best validation loss: 2.9129
# ------------------------------------------------------------
# Epoch 5/7 | Current LR: 0.000039
# Epoch 5: 100%|███| 276/276 [00:19<00:00, 14.27batch/s, accuracy=48.3, loss=2.54]
# 	Train: Loss = 2.5404, Acc = 48.2665
# 	Valid: Loss = 2.8460, Acc = 43.1280
# 	✨ New best validation loss: 2.8460
# ------------------------------------------------------------
# Epoch 6/7 | Current LR: 0.000020
# Epoch 6: 100%|███| 276/276 [00:19<00:00, 14.24batch/s, accuracy=51.6, loss=2.42]
# 	Train: Loss = 2.4216, Acc = 51.5976
# 	Valid: Loss = 2.8641, Acc = 41.2322
# 	Validation loss did not improve. Patience: 1/5
# ------------------------------------------------------------
# Epoch 7/7 | Current LR: 0.000006
# Epoch 7: 100%|███| 276/276 [00:19<00:00, 14.14batch/s, accuracy=53.6, loss=2.34]
# 	Train: Loss = 2.3419, Acc = 53.6370
# 	Valid: Loss = 2.8343, Acc = 43.6019
# 	✨ New best validation loss: 2.8343
# ------------------------------------------------------------
#
# ✅ Loaded best model based on validation accuracy for final testing. /kaggle/working/bac/.models/lstm_bert_model.pt
# Figure(1400x600)
#
# 🧪 Evaluating on Test Set...
#
# --- Test Set Results (Best Validation Model) ---
# 	Test Loss: 2.8163
# 	Test Accuracy (Top-1): 43.47%
# 	Test MRR: 0.5457
# {'loss_train_hist': [3.854197405386662, 3.30412040758824, 2.9526273435440618, 2.7230987518593883, 2.540404278299083, 2.421619836402976, 2.341917559720468], 'loss_valid_hist': [3.4920120579855785, 3.1279221091951643, 2.9934247391564504, 2.912920985903059, 2.8459958348955428, 2.864080088479178, 2.8342719078063965], 'acc_train_hist': [17.697711307500565, 30.614094720145026, 38.27328348062542, 43.757081350555175, 48.266485384092455, 51.59755268524813, 53.63698164513936], 'acc_valid_hist': [23.696682464454977, 30.805687203791468, 39.81042654028436, 38.388625592417064, 43.127962085308056, 41.23222748815166, 43.60189573459716], 'test_top_5_acc': 0.66270783847981, 'test_top_10_acc': 0.7767220902612827, 'test_loss_final': 2.8162792082186097, 'test_acc_top1_final': 43.46793349168646, 'test_mrr_final': 0.5456850066529041}

# %%
result_load_path = f"{os.getcwd()}/.result/lstm_bert_result.json"
plot_history(result_load_path, 7)

# %% [markdown]
# ## JDT dataset

# %%
# !python -m src.run_lstm -e bert -d jdt -ne 7 -rsw 0 -a 1 -b 0 -r 1 -hs 256 -l 2 -nah 1 -lam general
# Out:
# 2025-07-12 16:53:59.106781: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752339239.129509    1469 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752339239.137083    1469 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Shape after dropping NA assignees: (1465, 5)
# Number of unique assignees (classes): 69
# Warning: Some classes have fewer than 2 samples (min_samples_per_class=1). Stratification for train/test split might not be possible or effective.
# ✅ Loading pre-saved augmented dataset from 'datasets/augmented_train_dataset_2_JDT.csv'.
# Using device: cuda
# Generating Full Embeddings: 100%|█████████████| 193/193 [01:03<00:00,  3.04it/s]
# Generating Full Embeddings: 100%|███████████████| 10/10 [00:02<00:00,  3.34it/s]
# Generating Full Embeddings: 100%|███████████████| 19/19 [00:06<00:00,  3.04it/s]
#
# DataLoaders created successfully!
# Training batches: 193
# Validation batches: 10
# Test batches: 19
# using bert embeddings
#
# ------
# lstm model info:
# {'total_parameters': 1882181, 'trainable_parameters': 1882181, 'model_size_mb': 7.179950714111328, 'config': LSTMConfig(input_size=768, hidden_size=256, num_layers=2, num_classes=69, dropout=0.4, bidirectional=False, use_attention=True, attention_heads=1, attention_dropout=0.1, layer_norm=True, residual_connections=1, gradient_clipping=1.0, luong_attention_method='general'), 'is_bidirectional': False, 'uses_attention': True, 'attention_heads': 1}
# ------
#
# OPTIMIZER=SGD, LR=0.1
# Epoch 0: 100%|███| 193/193 [00:13<00:00, 13.85batch/s, accuracy=14.8, loss=3.55]
# OPTIMIZER=SGD, LR=0.01
# Epoch 0: 100%|███| 193/193 [00:13<00:00, 14.36batch/s, accuracy=16.2, loss=3.54]
# OPTIMIZER=SGD, LR=0.001
# Epoch 0: 100%|███| 193/193 [00:13<00:00, 14.25batch/s, accuracy=12.4, loss=3.84]
# OPTIMIZER=SGD, LR=0.0001
# Epoch 0: 100%|███| 193/193 [00:13<00:00, 14.24batch/s, accuracy=4.91, loss=4.53]
# OPTIMIZER=Adam, LR=0.1
# Epoch 0: 100%|███| 193/193 [00:13<00:00, 14.15batch/s, accuracy=14.9, loss=4.68]
# OPTIMIZER=Adam, LR=0.01
# Epoch 0: 100%|██████| 193/193 [00:13<00:00, 14.10batch/s, accuracy=14, loss=3.5]
# OPTIMIZER=Adam, LR=0.001
# Epoch 0: 100%|███| 193/193 [00:13<00:00, 14.01batch/s, accuracy=17.7, loss=3.44]
# OPTIMIZER=Adam, LR=0.0001
# Epoch 0: 100%|███| 193/193 [00:13<00:00, 14.01batch/s, accuracy=16.5, loss=3.56]
# OPTIMIZER=Adamw, LR=0.1
# Epoch 0: 100%|███| 193/193 [00:13<00:00, 13.80batch/s, accuracy=15.7, loss=3.92]
# OPTIMIZER=Adamw, LR=0.01
# Epoch 0: 100%|████| 193/193 [00:13<00:00, 14.05batch/s, accuracy=15.1, loss=3.5]
# OPTIMIZER=Adamw, LR=0.001
# Epoch 0: 100%|█████| 193/193 [00:13<00:00, 14.03batch/s, accuracy=17, loss=3.45]
# OPTIMIZER=Adamw, LR=0.0001
# Epoch 0: 100%|███| 193/193 [00:13<00:00, 14.18batch/s, accuracy=16.6, loss=3.55]
# <class 'torch.optim.adam.Adam'> 0.001
#
# ✅ Start Training 7 epochs ...
# Epoch 1/7 | Current LR: 0.001000
# Epoch 1: 100%|███| 193/193 [00:13<00:00, 14.04batch/s, accuracy=16.2, loss=3.46]
# 	Train: Loss = 3.4571, Acc = 16.2276
# 	Valid: Loss = 3.2185, Acc = 21.0884
# 	✨ New best validation loss: 3.2185
# ------------------------------------------------------------
# Epoch 2/7 | Current LR: 0.000951
# Epoch 2: 100%|█████| 193/193 [00:13<00:00, 14.07batch/s, accuracy=22, loss=3.22]
# 	Train: Loss = 3.2200, Acc = 22.0163
# 	Valid: Loss = 3.0474, Acc = 25.8503
# 	✨ New best validation loss: 3.0474
# ------------------------------------------------------------
# Epoch 3/7 | Current LR: 0.000812
# Epoch 3: 100%|███| 193/193 [00:14<00:00, 13.75batch/s, accuracy=30.2, loss=3.01]
# 	Train: Loss = 3.0130, Acc = 30.1789
# 	Valid: Loss = 2.7887, Acc = 32.6531
# 	✨ New best validation loss: 2.7887
# ------------------------------------------------------------
# Epoch 4/7 | Current LR: 0.000612
# Epoch 4: 100%|███| 193/193 [00:13<00:00, 14.06batch/s, accuracy=39.1, loss=2.73]
# 	Train: Loss = 2.7269, Acc = 39.0894
# 	Valid: Loss = 2.6855, Acc = 37.4150
# 	✨ New best validation loss: 2.6855
# ------------------------------------------------------------
# Epoch 5/7 | Current LR: 0.000389
# Epoch 5: 100%|████| 193/193 [00:13<00:00, 13.95batch/s, accuracy=46.6, loss=2.5]
# 	Train: Loss = 2.5020, Acc = 46.6341
# 	Valid: Loss = 2.5694, Acc = 40.8163
# 	✨ New best validation loss: 2.5694
# ------------------------------------------------------------
# Epoch 6/7 | Current LR: 0.000189
# Epoch 6: 100%|███| 193/193 [00:13<00:00, 13.91batch/s, accuracy=49.9, loss=2.32]
# 	Train: Loss = 2.3172, Acc = 49.9187
# 	Valid: Loss = 2.6009, Acc = 40.1361
# 	Validation loss did not improve. Patience: 1/5
# ------------------------------------------------------------
# Epoch 7/7 | Current LR: 0.000050
# Epoch 7: 100%|██████| 193/193 [00:13<00:00, 14.14batch/s, accuracy=54, loss=2.2]
# 	Train: Loss = 2.1997, Acc = 54.0163
# 	Valid: Loss = 2.5938, Acc = 39.4558
# 	Validation loss did not improve. Patience: 2/5
# ------------------------------------------------------------
#
# ✅ Loaded best model based on validation accuracy for final testing. /kaggle/working/bac/.models/lstm_bert_model.pt
# Figure(1400x600)
#
# 🧪 Evaluating on Test Set...
#
# --- Test Set Results (Best Validation Model) ---
# 	Test Loss: 2.7090
# 	Test Accuracy (Top-1): 38.57%
# 	Test MRR: 0.5454
# {'loss_train_hist': [3.4570604630702517, 3.220038831542811, 3.0130486858941112, 2.726931989501795, 2.501966725359309, 2.317160565618406, 2.199682542697136], 'loss_valid_hist': [3.21845965385437, 3.047364592552185, 2.7887356519699096, 2.685488748550415, 2.5694416403770446, 2.6009155392646788, 2.593757390975952], 'acc_train_hist': [16.227642276422763, 22.016260162601625, 30.178861788617887, 39.08943089430894, 46.63414634146341, 49.91869918699187, 54.016260162601625], 'acc_valid_hist': [21.08843537414966, 25.85034013605442, 32.6530612244898, 37.414965986394556, 40.816326530612244, 40.136054421768705, 39.45578231292517], 'test_top_5_acc': 0.7610921501706485, 'test_top_10_acc': 0.8600682593856656, 'test_loss_final': 2.708967735892848, 'test_acc_top1_final': 38.56655290102389, 'test_mrr_final': 0.5454335989496795}

# %%
result_load_path = f"{os.getcwd()}/.result/lstm_bert_result.json"
plot_history(result_load_path, 7)
