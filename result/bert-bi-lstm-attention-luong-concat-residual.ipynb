# %%
# %cd /kaggle/working
# !git clone https://github.com/AmirEspahbodi/bac.git
# Out:
# /kaggle/working
# fatal: destination path 'bac' already exists and is not an empty directory.

# %%
# !pip install bitsandbytes

# %%
# %cd /kaggle/working/bac
# !git pull
# !ls
# Out:
# /kaggle/working/bac
# Already up to date.
# datasets     poetry.lock     README.md	src
# inspiration  pyproject.toml  scripts	state.db

# %%
import os
import json
import matplotlib.pyplot as plt


def plot_history(result_load_path, NUM_EPOCHS):
    loss_train_hist = None
    loss_valid_hist = None
    acc_train_hist = None
    acc_valid_hist = None
    test_top_5_acc = None
    test_top_10_acc = None
    test_loss_final = None
    test_acc_top1_final = None
    test_mrr_final = None
        
    # Load the data from the JSON file
    try:
        with open(result_load_path, "r") as f:
            # json.load() reads the file and parses the JSON data into a Python dictionary
            loaded_results = json.load(f)
    
        # Unpack the dictionary values into your variables
        loss_train_hist = loaded_results.get("loss_train_hist")
        loss_valid_hist = loaded_results.get("loss_valid_hist")
        acc_train_hist = loaded_results.get("acc_train_hist")
        acc_valid_hist = loaded_results.get("acc_valid_hist")
        test_top_5_acc = loaded_results.get("test_top_5_acc")
        test_top_10_acc = loaded_results.get("test_top_10_acc")
        test_loss_final = loaded_results.get("test_loss_final")
        test_acc_top1_final = loaded_results.get("test_acc_top1_final")
        test_mrr_final = loaded_results.get("test_mrr_final")
    
    except FileNotFoundError:
        print(f"Error: The file at '{result_load_path}' was not found.")
    except json.JSONDecodeError:
        print(f"Error: The file at '{result_load_path}' is not a valid JSON file.")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")
    
    epochs_range = range(1, NUM_EPOCHS + 1)
    
    plt.figure(figsize=(14, 6))
    
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, loss_train_hist, "bo-", label="Training Loss")
    plt.plot(epochs_range, loss_valid_hist, "ro-", label="Validation Loss")
    plt.title("Training and Validation Loss")
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.legend()
    plt.grid(True)
    
    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, acc_train_hist, "bo-", label="Training Accuracy (Top-1)")
    plt.plot(epochs_range, acc_valid_hist, "ro-", label="Validation Accuracy (Top-1)")
    plt.title("Training and Validation Accuracy (Top-1)")
    plt.xlabel("Epochs")
    plt.ylabel("Accuracy")
    plt.legend()
    plt.grid(True)
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## GCC dataset

# %%
# !python -m src.run_lstm -e bert -d gcc -ne 7 -rsw 0 -a 1 -b 1 -r 1 -hs 256 -l 2 -nah 1 -lam concat
# Out:
# 2025-07-12 12:42:20.643068: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752324140.666548    2182 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752324140.673454    2182 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Shape after dropping NA assignees: (2103, 6)
# Number of unique assignees (classes): 82
# Warning: Some classes have fewer than 2 samples (min_samples_per_class=1). Stratification for train/test split might not be possible or effective.
# ✅ Loading pre-saved augmented dataset from 'datasets/augmented_train_dataset_2_GCC.csv'.
# Using device: cuda
# Generating Full Embeddings: 100%|█████████████| 276/276 [01:32<00:00,  2.99it/s]
# Generating Full Embeddings: 100%|███████████████| 14/14 [00:04<00:00,  3.16it/s]
# Generating Full Embeddings: 100%|███████████████| 27/27 [00:08<00:00,  3.13it/s]
#
# DataLoaders created successfully!
# Training batches: 276
# Validation batches: 14
# Test batches: 27
# using bert embeddings
#
# ------
# lstm model info:
# {'total_parameters': 4554322, 'trainable_parameters': 4554322, 'model_size_mb': 17.37335968017578, 'config': LSTMConfig(input_size=768, hidden_size=256, num_layers=2, num_classes=82, dropout=0.4, bidirectional=True, use_attention=True, attention_heads=1, attention_dropout=0.1, layer_norm=True, residual_connections=1, gradient_clipping=1.0, luong_attention_method='concat'), 'is_bidirectional': True, 'uses_attention': True, 'attention_heads': 1}
# ------
#
# OPTIMIZER=SGD, LR=0.1
# Epoch 0: 100%|███| 276/276 [00:31<00:00,  8.64batch/s, accuracy=10.7, loss=3.88]
# OPTIMIZER=SGD, LR=0.01
# Epoch 0: 100%|████| 276/276 [00:31<00:00,  8.78batch/s, accuracy=13.5, loss=3.8]
# OPTIMIZER=SGD, LR=0.001
# Epoch 0: 100%|█████| 276/276 [00:31<00:00,  8.84batch/s, accuracy=11, loss=4.05]
# OPTIMIZER=SGD, LR=0.0001
# Epoch 0: 100%|███| 276/276 [00:30<00:00,  8.96batch/s, accuracy=5.28, loss=4.59]
# OPTIMIZER=Adam, LR=0.1
# Epoch 0: 100%|███| 276/276 [00:31<00:00,  8.84batch/s, accuracy=11.1, loss=7.26]
# OPTIMIZER=Adam, LR=0.01
# Epoch 0: 100%|███| 276/276 [00:31<00:00,  8.83batch/s, accuracy=11.6, loss=3.87]
# OPTIMIZER=Adam, LR=0.001
# Epoch 0: 100%|███| 276/276 [00:31<00:00,  8.80batch/s, accuracy=12.5, loss=3.78]
# OPTIMIZER=Adam, LR=0.0001
# Epoch 0: 100%|████| 276/276 [00:31<00:00,  8.84batch/s, accuracy=22.4, loss=3.6]
# OPTIMIZER=Adamw, LR=0.1
# Epoch 0: 100%|███| 276/276 [00:31<00:00,  8.82batch/s, accuracy=11.9, loss=6.91]
# OPTIMIZER=Adamw, LR=0.01
# Epoch 0: 100%|███| 276/276 [00:31<00:00,  8.77batch/s, accuracy=11.6, loss=3.87]
# OPTIMIZER=Adamw, LR=0.001
# Epoch 0: 100%|███| 276/276 [00:31<00:00,  8.74batch/s, accuracy=12.6, loss=3.75]
# OPTIMIZER=Adamw, LR=0.0001
# Epoch 0: 100%|████| 276/276 [00:31<00:00,  8.86batch/s, accuracy=21.7, loss=3.6]
# <class 'torch.optim.adam.Adam'> 0.0001
#
# ✅ Start Training 7 epochs ...
# Epoch 1/7 | Current LR: 0.000100
# Epoch 1: 100%|████| 276/276 [00:31<00:00,  8.87batch/s, accuracy=21.5, loss=3.6]
# 	Train: Loss = 3.6028, Acc = 21.4593
# 	Valid: Loss = 3.1041, Acc = 35.5450
# 	✨ New best validation loss: 3.1041
# ------------------------------------------------------------
# Epoch 2/7 | Current LR: 0.000095
# Epoch 2: 100%|███| 276/276 [00:31<00:00,  8.88batch/s, accuracy=41.6, loss=2.84]
# 	Train: Loss = 2.8408, Acc = 41.6497
# 	Valid: Loss = 2.9213, Acc = 38.8626
# 	✨ New best validation loss: 2.9213
# ------------------------------------------------------------
# Epoch 3/7 | Current LR: 0.000081
# Epoch 3: 100%|███| 276/276 [00:31<00:00,  8.89batch/s, accuracy=53.2, loss=2.37]
# 	Train: Loss = 2.3728, Acc = 53.1611
# 	Valid: Loss = 2.7517, Acc = 43.1280
# 	✨ New best validation loss: 2.7517
# ------------------------------------------------------------
# Epoch 4/7 | Current LR: 0.000062
# Epoch 4: 100%|███| 276/276 [00:30<00:00,  8.92batch/s, accuracy=62.9, loss=2.02]
# 	Train: Loss = 2.0202, Acc = 62.9277
# 	Valid: Loss = 2.7345, Acc = 45.4976
# 	✨ New best validation loss: 2.7345
# ------------------------------------------------------------
# Epoch 5/7 | Current LR: 0.000039
# Epoch 5: 100%|███| 276/276 [00:31<00:00,  8.85batch/s, accuracy=71.3, loss=1.75]
# 	Train: Loss = 1.7453, Acc = 71.2894
# 	Valid: Loss = 2.6915, Acc = 50.7109
# 	✨ New best validation loss: 2.6915
# ------------------------------------------------------------
# Epoch 6/7 | Current LR: 0.000020
# Epoch 6: 100%|████| 276/276 [00:31<00:00,  8.82batch/s, accuracy=75.6, loss=1.6]
# 	Train: Loss = 1.5992, Acc = 75.6402
# 	Valid: Loss = 2.6602, Acc = 51.6588
# 	✨ New best validation loss: 2.6602
# ------------------------------------------------------------
# Epoch 7/7 | Current LR: 0.000006
# Epoch 7: 100%|████| 276/276 [00:31<00:00,  8.90batch/s, accuracy=79.4, loss=1.5]
# 	Train: Loss = 1.5034, Acc = 79.4471
# 	Valid: Loss = 2.6662, Acc = 49.2891
# 	Validation loss did not improve. Patience: 1/5
# ------------------------------------------------------------
#
# ✅ Loaded best model based on validation accuracy for final testing. /kaggle/working/bac/.models/lstm_bert_model.pt
# Figure(1400x600)
#
# 🧪 Evaluating on Test Set...
#
# --- Test Set Results (Best Validation Model) ---
# 	Test Loss: 2.4832
# 	Test Accuracy (Top-1): 51.78%
# 	Test MRR: 0.6320
# {'loss_train_hist': [3.6027616227882495, 2.8407501133455746, 2.3728153157061427, 2.020220443390418, 1.7452623135801675, 1.5991946920968485, 1.5034427854461947], 'loss_valid_hist': [3.104118364197867, 2.921307155064174, 2.7517350060599193, 2.7344737904412404, 2.6914739268166676, 2.660182169505528, 2.6661753484180997], 'acc_train_hist': [21.459324722411058, 41.64967142533424, 53.16111488783141, 62.92771357353274, 71.28937230908679, 75.64015409018808, 79.44708814865172], 'acc_valid_hist': [35.54502369668246, 38.86255924170616, 43.127962085308056, 45.497630331753555, 50.71090047393365, 51.65876777251185, 49.28909952606635], 'test_top_5_acc': 0.7505938242280285, 'test_top_10_acc': 0.8266033254156769, 'test_loss_final': 2.4831551048490734, 'test_acc_top1_final': 51.78147268408551, 'test_mrr_final': 0.6320414206224014}

# %%
result_load_path = f"{os.getcwd()}/.result/lstm_bert_result.json"
plot_history(result_load_path, 7)

# %% [markdown]
# ## JDT dataset

# %%
# !python -m src.run_lstm -e bert -d jdt -ne 7 -rsw 0 -a 1 -b 1 -r 1 -hs 256 -l 2 -nah 1 -lam concat
# Out:
# 2025-07-12 12:54:31.398084: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752324871.421186    2431 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752324871.428076    2431 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Shape after dropping NA assignees: (1465, 5)
# Number of unique assignees (classes): 69
# Warning: Some classes have fewer than 2 samples (min_samples_per_class=1). Stratification for train/test split might not be possible or effective.
# ✅ Loading pre-saved augmented dataset from 'datasets/augmented_train_dataset_2_JDT.csv'.
# Using device: cuda
# Generating Full Embeddings: 100%|█████████████| 193/193 [01:03<00:00,  3.04it/s]
# Generating Full Embeddings: 100%|███████████████| 10/10 [00:02<00:00,  3.36it/s]
# Generating Full Embeddings: 100%|███████████████| 19/19 [00:06<00:00,  3.12it/s]
#
# DataLoaders created successfully!
# Training batches: 193
# Validation batches: 10
# Test batches: 19
# using bert embeddings
#
# ------
# lstm model info:
# {'total_parameters': 4550981, 'trainable_parameters': 4550981, 'model_size_mb': 17.360614776611328, 'config': LSTMConfig(input_size=768, hidden_size=256, num_layers=2, num_classes=69, dropout=0.4, bidirectional=True, use_attention=True, attention_heads=1, attention_dropout=0.1, layer_norm=True, residual_connections=1, gradient_clipping=1.0, luong_attention_method='concat'), 'is_bidirectional': True, 'uses_attention': True, 'attention_heads': 1}
# ------
#
# OPTIMIZER=SGD, LR=0.1
# Epoch 0: 100%|███| 193/193 [00:22<00:00,  8.72batch/s, accuracy=13.5, loss=3.64]
# OPTIMIZER=SGD, LR=0.01
# Epoch 0: 100%|███| 193/193 [00:21<00:00,  8.79batch/s, accuracy=15.9, loss=3.52]
# OPTIMIZER=SGD, LR=0.001
# Epoch 0: 100%|█████| 193/193 [00:21<00:00,  8.94batch/s, accuracy=12, loss=3.84]
# OPTIMIZER=SGD, LR=0.0001
# Epoch 0: 100%|████| 193/193 [00:21<00:00,  8.91batch/s, accuracy=4.75, loss=4.6]
# OPTIMIZER=Adam, LR=0.1
# Epoch 0: 100%|████| 193/193 [00:22<00:00,  8.75batch/s, accuracy=12.1, loss=7.6]
# OPTIMIZER=Adam, LR=0.01
# Epoch 0: 100%|███| 193/193 [00:22<00:00,  8.71batch/s, accuracy=13.4, loss=3.62]
# OPTIMIZER=Adam, LR=0.001
# Epoch 0: 100%|███| 193/193 [00:22<00:00,  8.70batch/s, accuracy=17.2, loss=3.42]
# OPTIMIZER=Adam, LR=0.0001
# Epoch 0: 100%|███| 193/193 [00:21<00:00,  8.83batch/s, accuracy=21.5, loss=3.36]
# OPTIMIZER=Adamw, LR=0.1
# Epoch 0: 100%|████| 193/193 [00:21<00:00,  8.79batch/s, accuracy=14.3, loss=5.8]
# OPTIMIZER=Adamw, LR=0.01
# Epoch 0: 100%|████| 193/193 [00:22<00:00,  8.75batch/s, accuracy=15.4, loss=3.6]
# OPTIMIZER=Adamw, LR=0.001
# Epoch 0: 100%|█████| 193/193 [00:21<00:00,  8.79batch/s, accuracy=17, loss=3.43]
# OPTIMIZER=Adamw, LR=0.0001
# Epoch 0: 100%|███| 193/193 [00:21<00:00,  8.89batch/s, accuracy=20.6, loss=3.39]
# <class 'torch.optim.adam.Adam'> 0.0001
#
# ✅ Start Training 7 epochs ...
# Epoch 1/7 | Current LR: 0.000100
# Epoch 1: 100%|███| 193/193 [00:21<00:00,  8.94batch/s, accuracy=22.3, loss=3.36]
# 	Train: Loss = 3.3625, Acc = 22.2764
# 	Valid: Loss = 2.9719, Acc = 29.9320
# 	✨ New best validation loss: 2.9719
# ------------------------------------------------------------
# Epoch 2/7 | Current LR: 0.000095
# Epoch 2: 100%|█████| 193/193 [00:21<00:00,  8.92batch/s, accuracy=40, loss=2.72]
# 	Train: Loss = 2.7221, Acc = 40.0000
# 	Valid: Loss = 2.6891, Acc = 39.4558
# 	✨ New best validation loss: 2.6891
# ------------------------------------------------------------
# Epoch 3/7 | Current LR: 0.000081
# Epoch 3: 100%|█████| 193/193 [00:21<00:00,  8.89batch/s, accuracy=50, loss=2.34]
# 	Train: Loss = 2.3386, Acc = 50.0163
# 	Valid: Loss = 2.6831, Acc = 37.4150
# 	✨ New best validation loss: 2.6831
# ------------------------------------------------------------
# Epoch 4/7 | Current LR: 0.000062
# Epoch 4: 100%|█████| 193/193 [00:21<00:00,  8.92batch/s, accuracy=59, loss=2.02]
# 	Train: Loss = 2.0222, Acc = 58.9919
# 	Valid: Loss = 2.7068, Acc = 39.4558
# 	Validation loss did not improve. Patience: 1/5
# ------------------------------------------------------------
# Epoch 5/7 | Current LR: 0.000039
# Epoch 5: 100%|█████| 193/193 [00:21<00:00,  8.99batch/s, accuracy=67, loss=1.76]
# 	Train: Loss = 1.7593, Acc = 66.9919
# 	Valid: Loss = 2.6846, Acc = 39.4558
# 	Validation loss did not improve. Patience: 2/5
# ------------------------------------------------------------
# Epoch 6/7 | Current LR: 0.000020
# Epoch 6: 100%|███| 193/193 [00:21<00:00,  8.87batch/s, accuracy=75.1, loss=1.58]
# 	Train: Loss = 1.5836, Acc = 75.0894
# 	Valid: Loss = 2.7327, Acc = 42.1769
# 	Validation loss did not improve. Patience: 3/5
# ------------------------------------------------------------
# Epoch 7/7 | Current LR: 0.000006
# Epoch 7: 100%|███| 193/193 [00:21<00:00,  8.91batch/s, accuracy=76.7, loss=1.53]
# 	Train: Loss = 1.5326, Acc = 76.6829
# 	Valid: Loss = 2.7501, Acc = 40.8163
# 	Validation loss did not improve. Patience: 4/5
# ------------------------------------------------------------
#
# ✅ Loaded best model based on validation accuracy for final testing. /kaggle/working/bac/.models/lstm_bert_model.pt
# Figure(1400x600)
#
# 🧪 Evaluating on Test Set...
#
# --- Test Set Results (Best Validation Model) ---
# 	Test Loss: 2.7843
# 	Test Accuracy (Top-1): 39.93%
# 	Test MRR: 0.5534
# {'loss_train_hist': [3.3624758769811125, 2.7221119762084647, 2.3385917541276604, 2.0222481668304284, 1.7592844481295256, 1.583639970097517, 1.5325505016998924], 'loss_valid_hist': [2.971934127807617, 2.6891334295272826, 2.683064317703247, 2.7067508697509766, 2.6846445322036745, 2.732665514945984, 2.750095534324646], 'acc_train_hist': [22.276422764227643, 40.0, 50.016260162601625, 58.99186991869919, 66.99186991869918, 75.08943089430895, 76.6829268292683], 'acc_valid_hist': [29.931972789115648, 39.45578231292517, 37.414965986394556, 39.45578231292517, 39.45578231292517, 42.17687074829932, 40.816326530612244], 'test_top_5_acc': 0.7337883959044369, 'test_top_10_acc': 0.8532423208191127, 'test_loss_final': 2.784341310199938, 'test_acc_top1_final': 39.93174061433447, 'test_mrr_final': 0.5534445175308119}

# %%
result_load_path = f"{os.getcwd()}/.result/lstm_bert_result.json"
plot_history(result_load_path, 7)
