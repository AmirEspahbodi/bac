# %%
# %cd /kaggle/working
# !git clone https://github.com/AmirEspahbodi/bac.git
# Out:
# /kaggle/working
# fatal: destination path 'bac' already exists and is not an empty directory.

# %%
import os
from kaggle_secrets import UserSecretsClient
from huggingface_hub import login

# --- Hugging Face Authentication ---
try:
    user_secrets = UserSecretsClient()
    HUGGING_FACE_TOKEN = user_secrets.get_secret("HUGGING_FACE_TOKEN")
    # Ensure the token is set as an environment variable for transformers
    os.environ["HUGGING_FACE_HUB_TOKEN"] = HUGGING_FACE_TOKEN
    # Log in to Hugging Face Hub
    login(token=hf_token)
    print("✅ Successfully authenticated with Hugging Face.")
except Exception as e:
    print(f"⚠️ Could not authenticate with Hugging Face. Make sure the 'HUGGING_FACE_TOKEN' secret is set. Error: {e}")

# %%
# !pip install bitsandbytes

# %%
# %cd /kaggle/working/bac
# !git pull
# !ls
# Out:
# /kaggle/working/bac
# Already up to date.
# datasets     poetry.lock     README.md	src
# inspiration  pyproject.toml  scripts	state.db

# %%
import os
import json
import matplotlib.pyplot as plt


def plot_history(result_load_path, NUM_EPOCHS):
    loss_train_hist = None
    loss_valid_hist = None
    acc_train_hist = None
    acc_valid_hist = None
    test_top_5_acc = None
    test_top_10_acc = None
    test_loss_final = None
    test_acc_top1_final = None
    test_mrr_final = None
        
    # Load the data from the JSON file
    try:
        with open(result_load_path, "r") as f:
            # json.load() reads the file and parses the JSON data into a Python dictionary
            loaded_results = json.load(f)
    
        # Unpack the dictionary values into your variables
        loss_train_hist = loaded_results.get("loss_train_hist")
        loss_valid_hist = loaded_results.get("loss_valid_hist")
        acc_train_hist = loaded_results.get("acc_train_hist")
        acc_valid_hist = loaded_results.get("acc_valid_hist")
        test_top_5_acc = loaded_results.get("test_top_5_acc")
        test_top_10_acc = loaded_results.get("test_top_10_acc")
        test_loss_final = loaded_results.get("test_loss_final")
        test_acc_top1_final = loaded_results.get("test_acc_top1_final")
        test_mrr_final = loaded_results.get("test_mrr_final")
    
    except FileNotFoundError:
        print(f"Error: The file at '{result_load_path}' was not found.")
    except json.JSONDecodeError:
        print(f"Error: The file at '{result_load_path}' is not a valid JSON file.")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")
    
    epochs_range = range(1, NUM_EPOCHS + 1)
    
    plt.figure(figsize=(14, 6))
    
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, loss_train_hist, "bo-", label="Training Loss")
    plt.plot(epochs_range, loss_valid_hist, "ro-", label="Validation Loss")
    plt.title("Training and Validation Loss")
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.legend()
    plt.grid(True)
    
    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, acc_train_hist, "bo-", label="Training Accuracy (Top-1)")
    plt.plot(epochs_range, acc_valid_hist, "ro-", label="Validation Accuracy (Top-1)")
    plt.title("Training and Validation Accuracy (Top-1)")
    plt.xlabel("Epochs")
    plt.ylabel("Accuracy")
    plt.legend()
    plt.grid(True)
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## GCC dataset

# %%
# !python -m src.run_mlp -e bert_cls -d gcc -ne 7 -rsw 0
# Out:
# 2025-07-13 19:55:10.497092: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752436510.520705     156 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752436510.527596     156 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Shape after dropping NA assignees: (2103, 6)
# Number of unique assignees (classes): 82
# Warning: Some classes have fewer than 2 samples (min_samples_per_class=1). Stratification for train/test split might not be possible or effective.
# ✅ Loading pre-saved augmented dataset from 'datasets/augmented_train_dataset_2_GCC.csv'.
# ✅ Using device: cuda
# 🚀 Loading pre-trained BERT model: 'bert-base-uncased'
# model.safetensors: 100%|██████████████████████| 440M/440M [00:01<00:00, 237MB/s]
#
# --- Starting Embedding Pre-computation ---
# Embedding train data:   0%|                            | 0/4413 [00:00<?, ?it/s]Token indices sequence length is longer than the specified maximum sequence length for this model (1022 > 512). Running this sequence through the model will result in indexing errors
# Embedding train data: 100%|█████████████████| 4413/4413 [02:09<00:00, 34.13it/s]
# Embedding validation data: 100%|██████████████| 211/211 [00:06<00:00, 31.00it/s]
# Embedding test data: 100%|████████████████████| 421/421 [00:12<00:00, 32.69it/s]
#
# ✅ Embedding pre-computation complete.
# ✅ DataLoaders created with batch size: 32
# bert_cls
# OPTIMIZER=SGD, LR=0.1
# Epoch 0: 100%|██| 138/138 [00:00<00:00, 141.04batch/s, accuracy=15.6, loss=4.01]
# OPTIMIZER=SGD, LR=0.01
# Epoch 0: 100%|████| 138/138 [00:00<00:00, 163.24batch/s, accuracy=19, loss=3.72]
# OPTIMIZER=SGD, LR=0.001
# Epoch 0: 100%|██| 138/138 [00:00<00:00, 162.76batch/s, accuracy=10.4, loss=4.34]
# OPTIMIZER=SGD, LR=0.0001
# Epoch 0: 100%|██| 138/138 [00:00<00:00, 160.17batch/s, accuracy=2.74, loss=5.12]
# OPTIMIZER=Adam, LR=0.1
# Epoch 0: 100%|██| 138/138 [00:01<00:00, 129.80batch/s, accuracy=5.05, loss=10.4]
# OPTIMIZER=Adam, LR=0.01
# Epoch 0: 100%|██| 138/138 [00:01<00:00, 129.76batch/s, accuracy=10.2, loss=4.52]
# OPTIMIZER=Adam, LR=0.001
# Epoch 0: 100%|███| 138/138 [00:01<00:00, 130.11batch/s, accuracy=19.8, loss=3.7]
# OPTIMIZER=Adam, LR=0.0001
# Epoch 0: 100%|██| 138/138 [00:01<00:00, 137.88batch/s, accuracy=26.2, loss=3.37]
# OPTIMIZER=Adamw, LR=0.1
# Epoch 0: 100%|██| 138/138 [00:00<00:00, 139.94batch/s, accuracy=4.46, loss=11.5]
# OPTIMIZER=Adamw, LR=0.01
# Epoch 0: 100%|██| 138/138 [00:00<00:00, 139.73batch/s, accuracy=9.09, loss=4.47]
# OPTIMIZER=Adamw, LR=0.001
# Epoch 0: 100%|██| 138/138 [00:00<00:00, 141.87batch/s, accuracy=21.7, loss=3.62]
# OPTIMIZER=Adamw, LR=0.0001
# Epoch 0: 100%|██| 138/138 [00:01<00:00, 138.00batch/s, accuracy=25.3, loss=3.37]
# <class 'torch.optim.adam.Adam'> 0.0001
#
# ✅ Start Training 7 epochs ...
# Epoch 1/7 | Current LR: 0.000100
# Epoch 1: 100%|██| 138/138 [00:00<00:00, 138.90batch/s, accuracy=25.8, loss=3.37]
# 	Train: Loss = 3.3732, Acc = 25.7874
# 	Valid: Loss = 3.2728, Acc = 30.8057
# 	✨ New best validation loss: 3.2728
# ------------------------------------------------------------
# Epoch 2/7 | Current LR: 0.000095
# Epoch 2: 100%|██| 138/138 [00:00<00:00, 138.35batch/s, accuracy=52.8, loss=2.29]
# 	Train: Loss = 2.2915, Acc = 52.7532
# 	Valid: Loss = 3.2245, Acc = 38.3886
# 	✨ New best validation loss: 3.2245
# ------------------------------------------------------------
# Epoch 3/7 | Current LR: 0.000081
# Epoch 3: 100%|████| 138/138 [00:01<00:00, 134.53batch/s, accuracy=82, loss=1.44]
# 	Train: Loss = 1.4420, Acc = 81.9624
# 	Valid: Loss = 3.3764, Acc = 38.8626
# 	Validation loss did not improve. Patience: 1/5
# ------------------------------------------------------------
# Epoch 4/7 | Current LR: 0.000062
# Epoch 4: 100%|██| 138/138 [00:01<00:00, 137.11batch/s, accuracy=95.2, loss=1.06]
# 	Train: Loss = 1.0576, Acc = 95.1734
# 	Valid: Loss = 3.3534, Acc = 39.8104
# 	Validation loss did not improve. Patience: 2/5
# ------------------------------------------------------------
# Epoch 5/7 | Current LR: 0.000039
# Epoch 5: 100%|███| 138/138 [00:00<00:00, 138.25batch/s, accuracy=99, loss=0.939]
# 	Train: Loss = 0.9388, Acc = 99.0029
# 	Valid: Loss = 3.2976, Acc = 41.2322
# 	Validation loss did not improve. Patience: 3/5
# ------------------------------------------------------------
# Epoch 6/7 | Current LR: 0.000020
# Epoch 6: 100%|█| 138/138 [00:00<00:00, 138.27batch/s, accuracy=99.8, loss=0.894]
# 	Train: Loss = 0.8937, Acc = 99.8414
# 	Valid: Loss = 3.2692, Acc = 42.1801
# 	Validation loss did not improve. Patience: 4/5
# ------------------------------------------------------------
# Epoch 7/7 | Current LR: 0.000006
# Epoch 7: 100%|██| 138/138 [00:00<00:00, 138.06batch/s, accuracy=100, loss=0.875]
# 	Train: Loss = 0.8747, Acc = 99.9773
# 	Valid: Loss = 3.2491, Acc = 42.1801
# 	Validation loss did not improve. Patience: 5/5
#
# 🛑 Early stopping triggered at epoch 7.
#
# ✅ Loaded best model based on validation accuracy for final testing. /kaggle/working/bac/.models/MLP_bert_cls_model.pt
# Figure(1400x600)
#
# 🧪 Evaluating on Test Set...
#
# --- Test Set Results (Best Validation Model) ---
# 	Test Loss: 3.1837
# 	Test Accuracy (Top-1): 41.09%
# 	Test MRR: 0.5080
# {'loss_train_hist': [3.373166084289551, 2.291468800841898, 1.44197750609854, 1.057636466147243, 0.9387947960176329, 0.8936662781929624, 0.8747493944306305], 'loss_valid_hist': [3.2727788516453336, 3.2244932651519775, 3.3764240741729736, 3.3533661706107005, 3.297612122126988, 3.26924797466823, 3.24909131867545], 'acc_train_hist': [25.78744618173578, 52.753229095853165, 81.9623838658509, 95.17335146159076, 99.00294584183095, 99.84137774756401, 99.97733967822343], 'acc_valid_hist': [30.805687203791468, 38.388625592417064, 38.86255924170616, 39.81042654028436, 41.23222748815166, 42.18009478672986, 42.18009478672986], 'test_top_5_acc': 0.5890736342042755, 'test_top_10_acc': 0.7363420427553444, 'test_loss_final': 3.183679461479187, 'test_acc_top1_final': 41.09263657957245, 'test_mrr_final': 0.5079844860847326}

# %%
result_load_path = f"{os.getcwd()}/.result/MLP_bert_cls_result.json"
plot_history(result_load_path, 7)

# %% [markdown]
# ## JDT dataset

# %%
# !python -m src.run_mlp -e bert_cls -d jdt -ne 6 -rsw 0
# Out:
# 2025-07-13 20:01:22.153567: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752436882.176377     206 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752436882.183154     206 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Shape after dropping NA assignees: (1465, 5)
# Number of unique assignees (classes): 69
# Warning: Some classes have fewer than 2 samples (min_samples_per_class=1). Stratification for train/test split might not be possible or effective.
# ✅ Loading pre-saved augmented dataset from 'datasets/augmented_train_dataset_2_JDT.csv'.
# ✅ Using device: cuda
# 🚀 Loading pre-trained BERT model: 'bert-base-uncased'
#
# --- Starting Embedding Pre-computation ---
# Embedding train data:   0%|                    | 8/3075 [00:00<01:33, 32.85it/s]Token indices sequence length is longer than the specified maximum sequence length for this model (877 > 512). Running this sequence through the model will result in indexing errors
# Embedding train data: 100%|█████████████████| 3075/3075 [01:12<00:00, 42.44it/s]
# Embedding validation data: 100%|██████████████| 147/147 [00:03<00:00, 41.89it/s]
# Embedding test data: 100%|████████████████████| 293/293 [00:08<00:00, 33.94it/s]
#
# ✅ Embedding pre-computation complete.
# ✅ DataLoaders created with batch size: 32
# bert_cls
# OPTIMIZER=SGD, LR=0.1
# Epoch 0: 100%|████| 97/97 [00:00<00:00, 131.58batch/s, accuracy=13.7, loss=3.82]
# OPTIMIZER=SGD, LR=0.01
# Epoch 0: 100%|████| 97/97 [00:00<00:00, 164.21batch/s, accuracy=18.3, loss=3.49]
# OPTIMIZER=SGD, LR=0.001
# Epoch 0: 100%|████| 97/97 [00:00<00:00, 163.37batch/s, accuracy=10.7, loss=4.16]
# OPTIMIZER=SGD, LR=0.0001
# Epoch 0: 100%|████| 97/97 [00:00<00:00, 166.30batch/s, accuracy=1.56, loss=5.17]
# OPTIMIZER=Adam, LR=0.1
# Epoch 0: 100%|████| 97/97 [00:00<00:00, 130.06batch/s, accuracy=6.89, loss=11.4]
# OPTIMIZER=Adam, LR=0.01
# Epoch 0: 100%|████| 97/97 [00:00<00:00, 137.44batch/s, accuracy=10.6, loss=4.57]
# OPTIMIZER=Adam, LR=0.001
# Epoch 0: 100%|█████| 97/97 [00:00<00:00, 137.07batch/s, accuracy=16.6, loss=3.6]
# OPTIMIZER=Adam, LR=0.0001
# Epoch 0: 100%|████| 97/97 [00:00<00:00, 137.31batch/s, accuracy=22.3, loss=3.23]
# OPTIMIZER=Adamw, LR=0.1
# Epoch 0: 100%|██████| 97/97 [00:00<00:00, 136.30batch/s, accuracy=4.72, loss=14]
# OPTIMIZER=Adamw, LR=0.01
# Epoch 0: 100%|████| 97/97 [00:00<00:00, 139.57batch/s, accuracy=10.2, loss=4.42]
# OPTIMIZER=Adamw, LR=0.001
# Epoch 0: 100%|████| 97/97 [00:00<00:00, 140.71batch/s, accuracy=18.5, loss=3.52]
# OPTIMIZER=Adamw, LR=0.0001
# Epoch 0: 100%|████| 97/97 [00:00<00:00, 139.57batch/s, accuracy=22.4, loss=3.25]
# <class 'torch.optim.adamw.AdamW'> 0.0001
#
# ✅ Start Training 6 epochs ...
# Epoch 1/6 | Current LR: 0.000100
# Epoch 1: 100%|████| 97/97 [00:00<00:00, 139.67batch/s, accuracy=23.8, loss=3.21]
# 	Train: Loss = 3.2133, Acc = 23.8049
# 	Valid: Loss = 3.1852, Acc = 25.1701
# 	✨ New best validation loss: 3.1852
# ------------------------------------------------------------
# Epoch 2/6 | Current LR: 0.000093
# Epoch 2: 100%|████| 97/97 [00:00<00:00, 128.76batch/s, accuracy=45.6, loss=2.34]
# 	Train: Loss = 2.3439, Acc = 45.6260
# 	Valid: Loss = 3.5376, Acc = 24.4898
# 	Validation loss did not improve. Patience: 1/5
# ------------------------------------------------------------
# Epoch 3/6 | Current LR: 0.000075
# Epoch 3: 100%|████| 97/97 [00:00<00:00, 137.16batch/s, accuracy=74.2, loss=1.58]
# 	Train: Loss = 1.5841, Acc = 74.1789
# 	Valid: Loss = 3.8235, Acc = 24.4898
# 	Validation loss did not improve. Patience: 2/5
# ------------------------------------------------------------
# Epoch 4/6 | Current LR: 0.000050
# Epoch 4: 100%|████| 97/97 [00:00<00:00, 140.79batch/s, accuracy=89.6, loss=1.19]
# 	Train: Loss = 1.1926, Acc = 89.6260
# 	Valid: Loss = 3.8467, Acc = 25.1701
# 	Validation loss did not improve. Patience: 3/5
# ------------------------------------------------------------
# Epoch 5/6 | Current LR: 0.000026
# Epoch 5: 100%|████| 97/97 [00:00<00:00, 142.91batch/s, accuracy=93.8, loss=1.05]
# 	Train: Loss = 1.0499, Acc = 93.7886
# 	Valid: Loss = 3.9697, Acc = 25.1701
# 	Validation loss did not improve. Patience: 4/5
# ------------------------------------------------------------
# Epoch 6/6 | Current LR: 0.000008
# Epoch 6: 100%|███| 97/97 [00:00<00:00, 141.91batch/s, accuracy=95.8, loss=0.997]
# 	Train: Loss = 0.9975, Acc = 95.8374
# 	Valid: Loss = 3.9500, Acc = 23.1293
# 	Validation loss did not improve. Patience: 5/5
#
# 🛑 Early stopping triggered at epoch 6.
#
# ✅ Loaded best model based on validation accuracy for final testing. /kaggle/working/bac/.models/MLP_bert_cls_model.pt
# Figure(1400x600)
#
# 🧪 Evaluating on Test Set...
#
# --- Test Set Results (Best Validation Model) ---
# 	Test Loss: 3.2224
# 	Test Accuracy (Top-1): 23.89%
# 	Test MRR: 0.4043
# {'loss_train_hist': [3.2133268203931986, 2.343948950472566, 1.584082997951311, 1.1926422954834615, 1.0498975398614234, 0.997459259229837], 'loss_valid_hist': [3.1852145195007324, 3.5375616550445557, 3.823524284362793, 3.846728229522705, 3.9697062492370607, 3.9499696254730225], 'acc_train_hist': [23.804878048780488, 45.6260162601626, 74.17886178861788, 89.6260162601626, 93.78861788617886, 95.83739837398375], 'acc_valid_hist': [25.170068027210885, 24.489795918367346, 24.489795918367346, 25.170068027210885, 25.170068027210885, 23.12925170068027], 'test_top_5_acc': 0.6143344709897611, 'test_top_10_acc': 0.78839590443686, 'test_loss_final': 3.22244815826416, 'test_acc_top1_final': 23.890784982935152, 'test_mrr_final': 0.40426264174449356}

# %%
result_load_path = f"{os.getcwd()}/.result/MLP_bert_cls_result.json"
plot_history(result_load_path, 6)
