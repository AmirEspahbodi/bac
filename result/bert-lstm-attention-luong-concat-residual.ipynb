# %%
# %cd /kaggle/working
# !git clone https://github.com/AmirEspahbodi/bac.git
# Out:
# /kaggle/working
# fatal: destination path 'bac' already exists and is not an empty directory.

# %%
import os
from kaggle_secrets import UserSecretsClient
from huggingface_hub import login

# --- Hugging Face Authentication ---
try:
    user_secrets = UserSecretsClient()
    HUGGING_FACE_TOKEN = user_secrets.get_secret("HUGGING_FACE_TOKEN")
    # Ensure the token is set as an environment variable for transformers
    os.environ["HUGGING_FACE_HUB_TOKEN"] = HUGGING_FACE_TOKEN
    # Log in to Hugging Face Hub
    login(token=hf_token)
    print("✅ Successfully authenticated with Hugging Face.")
except Exception as e:
    print(f"⚠️ Could not authenticate with Hugging Face. Make sure the 'HUGGING_FACE_TOKEN' secret is set. Error: {e}")

# %%
# !pip install bitsandbytes

# %%
# %cd /kaggle/working/bac
# !git pull
# !ls
# Out:
# /kaggle/working/bac
# Already up to date.
# datasets     poetry.lock     README.md	src
# inspiration  pyproject.toml  scripts	state.db

# %%
import os
import json
import matplotlib.pyplot as plt


def plot_history(result_load_path, NUM_EPOCHS):
    loss_train_hist = None
    loss_valid_hist = None
    acc_train_hist = None
    acc_valid_hist = None
    test_top_5_acc = None
    test_top_10_acc = None
    test_loss_final = None
    test_acc_top1_final = None
    test_mrr_final = None
        
    # Load the data from the JSON file
    try:
        with open(result_load_path, "r") as f:
            # json.load() reads the file and parses the JSON data into a Python dictionary
            loaded_results = json.load(f)
    
        # Unpack the dictionary values into your variables
        loss_train_hist = loaded_results.get("loss_train_hist")
        loss_valid_hist = loaded_results.get("loss_valid_hist")
        acc_train_hist = loaded_results.get("acc_train_hist")
        acc_valid_hist = loaded_results.get("acc_valid_hist")
        test_top_5_acc = loaded_results.get("test_top_5_acc")
        test_top_10_acc = loaded_results.get("test_top_10_acc")
        test_loss_final = loaded_results.get("test_loss_final")
        test_acc_top1_final = loaded_results.get("test_acc_top1_final")
        test_mrr_final = loaded_results.get("test_mrr_final")
    
    except FileNotFoundError:
        print(f"Error: The file at '{result_load_path}' was not found.")
    except json.JSONDecodeError:
        print(f"Error: The file at '{result_load_path}' is not a valid JSON file.")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")
    
    epochs_range = range(1, NUM_EPOCHS + 1)
    
    plt.figure(figsize=(14, 6))
    
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, loss_train_hist, "bo-", label="Training Loss")
    plt.plot(epochs_range, loss_valid_hist, "ro-", label="Validation Loss")
    plt.title("Training and Validation Loss")
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.legend()
    plt.grid(True)
    
    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, acc_train_hist, "bo-", label="Training Accuracy (Top-1)")
    plt.plot(epochs_range, acc_valid_hist, "ro-", label="Validation Accuracy (Top-1)")
    plt.title("Training and Validation Accuracy (Top-1)")
    plt.xlabel("Epochs")
    plt.ylabel("Accuracy")
    plt.legend()
    plt.grid(True)
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## GCC dataset

# %%
# !python -m src.run_lstm -e bert -d gcc -ne 7 -rsw 0 -a 1 -b 0 -r 1 -hs 256 -l 2 -nah 1 -lam concat
# Out:
# 2025-07-12 16:30:07.371394: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752337807.393351     710 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752337807.400625     710 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Shape after dropping NA assignees: (2103, 6)
# Number of unique assignees (classes): 82
# Warning: Some classes have fewer than 2 samples (min_samples_per_class=1). Stratification for train/test split might not be possible or effective.
# ✅ Loading pre-saved augmented dataset from 'datasets/augmented_train_dataset_2_GCC.csv'.
# Using device: cuda
# Generating Full Embeddings: 100%|█████████████| 276/276 [01:33<00:00,  2.96it/s]
# Generating Full Embeddings: 100%|███████████████| 14/14 [00:04<00:00,  3.12it/s]
# Generating Full Embeddings: 100%|███████████████| 27/27 [00:08<00:00,  3.13it/s]
#
# DataLoaders created successfully!
# Training batches: 276
# Validation batches: 14
# Test batches: 27
# using bert embeddings
#
# ------
# lstm model info:
# {'total_parameters': 1949650, 'trainable_parameters': 1949650, 'model_size_mb': 7.437324523925781, 'config': LSTMConfig(input_size=768, hidden_size=256, num_layers=2, num_classes=82, dropout=0.4, bidirectional=False, use_attention=True, attention_heads=1, attention_dropout=0.1, layer_norm=True, residual_connections=1, gradient_clipping=1.0, luong_attention_method='concat'), 'is_bidirectional': False, 'uses_attention': True, 'attention_heads': 1}
# ------
#
# OPTIMIZER=SGD, LR=0.1
# Epoch 0: 100%|████| 276/276 [00:19<00:00, 13.92batch/s, accuracy=12.2, loss=3.8]
# OPTIMIZER=SGD, LR=0.01
# Epoch 0: 100%|███| 276/276 [00:19<00:00, 14.44batch/s, accuracy=11.9, loss=3.86]
# OPTIMIZER=SGD, LR=0.001
# Epoch 0: 100%|███| 276/276 [00:19<00:00, 14.53batch/s, accuracy=10.2, loss=4.09]
# OPTIMIZER=SGD, LR=0.0001
# Epoch 0: 100%|███| 276/276 [00:19<00:00, 14.52batch/s, accuracy=4.87, loss=4.43]
# OPTIMIZER=Adam, LR=0.1
# Epoch 0: 100%|███| 276/276 [00:19<00:00, 14.07batch/s, accuracy=11.1, loss=4.71]
# OPTIMIZER=Adam, LR=0.01
# Epoch 0: 100%|███| 276/276 [00:19<00:00, 13.99batch/s, accuracy=12.5, loss=3.77]
# OPTIMIZER=Adam, LR=0.001
# Epoch 0: 100%|███| 276/276 [00:19<00:00, 13.99batch/s, accuracy=13.6, loss=3.74]
# OPTIMIZER=Adam, LR=0.0001
# Epoch 0: 100%|███| 276/276 [00:19<00:00, 14.03batch/s, accuracy=18.6, loss=3.77]
# OPTIMIZER=Adamw, LR=0.1
# Epoch 0: 100%|███| 276/276 [00:19<00:00, 13.94batch/s, accuracy=12.1, loss=4.11]
# OPTIMIZER=Adamw, LR=0.01
# Epoch 0: 100%|███| 276/276 [00:19<00:00, 14.01batch/s, accuracy=12.2, loss=3.79]
# OPTIMIZER=Adamw, LR=0.001
# Epoch 0: 100%|███| 276/276 [00:20<00:00, 13.76batch/s, accuracy=13.8, loss=3.76]
# OPTIMIZER=Adamw, LR=0.0001
# Epoch 0: 100%|███| 276/276 [00:19<00:00, 14.05batch/s, accuracy=17.6, loss=3.78]
# <class 'torch.optim.adam.Adam'> 0.0001
#
# ✅ Start Training 7 epochs ...
# Epoch 1/7 | Current LR: 0.000100
# Epoch 1: 100%|████| 276/276 [00:19<00:00, 14.11batch/s, accuracy=16.9, loss=3.8]
# 	Train: Loss = 3.7952, Acc = 16.9273
# 	Valid: Loss = 3.3737, Acc = 29.3839
# 	✨ New best validation loss: 3.3737
# ------------------------------------------------------------
# Epoch 2/7 | Current LR: 0.000095
# Epoch 2: 100%|███| 276/276 [00:19<00:00, 14.18batch/s, accuracy=35.1, loss=3.12]
# 	Train: Loss = 3.1229, Acc = 35.1235
# 	Valid: Loss = 3.0136, Acc = 38.3886
# 	✨ New best validation loss: 3.0136
# ------------------------------------------------------------
# Epoch 3/7 | Current LR: 0.000081
# Epoch 3: 100%|████| 276/276 [00:19<00:00, 14.11batch/s, accuracy=46.6, loss=2.7]
# 	Train: Loss = 2.6998, Acc = 46.5896
# 	Valid: Loss = 2.7953, Acc = 43.1280
# 	✨ New best validation loss: 2.7953
# ------------------------------------------------------------
# Epoch 4/7 | Current LR: 0.000062
# Epoch 4: 100%|███| 276/276 [00:19<00:00, 14.12batch/s, accuracy=52.4, loss=2.42]
# 	Train: Loss = 2.4180, Acc = 52.4360
# 	Valid: Loss = 2.7725, Acc = 46.9194
# 	✨ New best validation loss: 2.7725
# ------------------------------------------------------------
# Epoch 5/7 | Current LR: 0.000039
# Epoch 5: 100%|███| 276/276 [00:19<00:00, 14.21batch/s, accuracy=57.6, loss=2.24]
# 	Train: Loss = 2.2364, Acc = 57.6479
# 	Valid: Loss = 2.6907, Acc = 46.9194
# 	✨ New best validation loss: 2.6907
# ------------------------------------------------------------
# Epoch 6/7 | Current LR: 0.000020
# Epoch 6: 100%|████| 276/276 [00:19<00:00, 14.07batch/s, accuracy=61.4, loss=2.1]
# 	Train: Loss = 2.0975, Acc = 61.3868
# 	Valid: Loss = 2.6578, Acc = 47.3934
# 	✨ New best validation loss: 2.6578
# ------------------------------------------------------------
# Epoch 7/7 | Current LR: 0.000006
# Epoch 7: 100%|███| 276/276 [00:19<00:00, 14.06batch/s, accuracy=63.3, loss=2.03]
# 	Train: Loss = 2.0322, Acc = 63.3129
# 	Valid: Loss = 2.6684, Acc = 46.9194
# 	Validation loss did not improve. Patience: 1/5
# ------------------------------------------------------------
#
# ✅ Loaded best model based on validation accuracy for final testing. /kaggle/working/bac/.models/lstm_bert_model.pt
# Figure(1400x600)
#
# 🧪 Evaluating on Test Set...
#
# --- Test Set Results (Best Validation Model) ---
# 	Test Loss: 2.4935
# 	Test Accuracy (Top-1): 51.07%
# 	Test MRR: 0.6246
# {'loss_train_hist': [3.7952375990757043, 3.1229379116625027, 2.6997511356637096, 2.417982353248458, 2.236403708872588, 2.0974651704663816, 2.032231757606285], 'loss_valid_hist': [3.373728939465114, 3.013594423021589, 2.795251761163984, 2.772461414337158, 2.6907354252679005, 2.6578387362616405, 2.6684329169137135], 'acc_train_hist': [16.92726036709721, 35.123498753682306, 46.58962157262633, 52.43598459098119, 57.64785859959211, 61.386811692726035, 63.312939043734424], 'acc_valid_hist': [29.38388625592417, 38.388625592417064, 43.127962085308056, 46.91943127962085, 46.91943127962085, 47.39336492890995, 46.91943127962085], 'test_top_5_acc': 0.7505938242280285, 'test_top_10_acc': 0.8456057007125891, 'test_loss_final': 2.493530026188603, 'test_acc_top1_final': 51.06888361045131, 'test_mrr_final': 0.6246139674118092}

# %%
result_load_path = f"{os.getcwd()}/.result/lstm_bert_result.json"
plot_history(result_load_path, 7)

# %% [markdown]
# ## JDT dataset

# %%
# !python -m src.run_lstm -e bert -d jdt -ne 7 -rsw 0 -a 1 -b 0 -r 1 -hs 256 -l 2 -nah 1 -lam concat
# Out:
# 2025-07-12 16:38:35.237651: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752338315.260123     959 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752338315.266901     959 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Shape after dropping NA assignees: (1465, 5)
# Number of unique assignees (classes): 69
# Warning: Some classes have fewer than 2 samples (min_samples_per_class=1). Stratification for train/test split might not be possible or effective.
# ✅ Loading pre-saved augmented dataset from 'datasets/augmented_train_dataset_2_JDT.csv'.
# Using device: cuda
# Generating Full Embeddings: 100%|█████████████| 193/193 [01:03<00:00,  3.03it/s]
# Generating Full Embeddings: 100%|███████████████| 10/10 [00:03<00:00,  3.32it/s]
# Generating Full Embeddings: 100%|███████████████| 19/19 [00:06<00:00,  3.13it/s]
#
# DataLoaders created successfully!
# Training batches: 193
# Validation batches: 10
# Test batches: 19
# using bert embeddings
#
# ------
# lstm model info:
# {'total_parameters': 1947973, 'trainable_parameters': 1947973, 'model_size_mb': 7.430927276611328, 'config': LSTMConfig(input_size=768, hidden_size=256, num_layers=2, num_classes=69, dropout=0.4, bidirectional=False, use_attention=True, attention_heads=1, attention_dropout=0.1, layer_norm=True, residual_connections=1, gradient_clipping=1.0, luong_attention_method='concat'), 'is_bidirectional': False, 'uses_attention': True, 'attention_heads': 1}
# ------
#
# OPTIMIZER=SGD, LR=0.1
# Epoch 0: 100%|███| 193/193 [00:14<00:00, 13.65batch/s, accuracy=13.9, loss=3.59]
# OPTIMIZER=SGD, LR=0.01
# Epoch 0: 100%|███| 193/193 [00:13<00:00, 14.15batch/s, accuracy=14.9, loss=3.58]
# OPTIMIZER=SGD, LR=0.001
# Epoch 0: 100%|███| 193/193 [00:13<00:00, 14.15batch/s, accuracy=10.6, loss=3.95]
# OPTIMIZER=SGD, LR=0.0001
# Epoch 0: 100%|███| 193/193 [00:13<00:00, 14.14batch/s, accuracy=2.05, loss=4.58]
# OPTIMIZER=Adam, LR=0.1
# Epoch 0: 100%|███| 193/193 [00:13<00:00, 13.91batch/s, accuracy=14.4, loss=4.07]
# OPTIMIZER=Adam, LR=0.01
# Epoch 0: 100%|███| 193/193 [00:13<00:00, 13.99batch/s, accuracy=14.7, loss=3.53]
# OPTIMIZER=Adam, LR=0.001
# Epoch 0: 100%|███| 193/193 [00:13<00:00, 13.90batch/s, accuracy=15.5, loss=3.46]
# OPTIMIZER=Adam, LR=0.0001
# Epoch 0: 100%|███| 193/193 [00:13<00:00, 14.11batch/s, accuracy=16.4, loss=3.59]
# OPTIMIZER=Adamw, LR=0.1
# Epoch 0: 100%|███| 193/193 [00:13<00:00, 14.02batch/s, accuracy=16.1, loss=4.09]
# OPTIMIZER=Adamw, LR=0.01
# Epoch 0: 100%|██████| 193/193 [00:13<00:00, 14.02batch/s, accuracy=15, loss=3.5]
# OPTIMIZER=Adamw, LR=0.001
# Epoch 0: 100%|███| 193/193 [00:13<00:00, 13.97batch/s, accuracy=18.8, loss=3.44]
# OPTIMIZER=Adamw, LR=0.0001
# Epoch 0: 100%|███| 193/193 [00:13<00:00, 14.08batch/s, accuracy=16.7, loss=3.61]
# <class 'torch.optim.adamw.AdamW'> 0.001
#
# ✅ Start Training 7 epochs ...
# Epoch 1/7 | Current LR: 0.001000
# Epoch 1: 100%|████| 193/193 [00:13<00:00, 13.92batch/s, accuracy=18.1, loss=3.4]
# 	Train: Loss = 3.4048, Acc = 18.1463
# 	Valid: Loss = 2.9929, Acc = 29.9320
# 	✨ New best validation loss: 2.9929
# ------------------------------------------------------------
# Epoch 2/7 | Current LR: 0.000951
# Epoch 2: 100%|███| 193/193 [00:13<00:00, 13.95batch/s, accuracy=30.7, loss=3.03]
# 	Train: Loss = 3.0329, Acc = 30.7317
# 	Valid: Loss = 2.8271, Acc = 29.9320
# 	✨ New best validation loss: 2.8271
# ------------------------------------------------------------
# Epoch 3/7 | Current LR: 0.000812
# Epoch 3: 100%|███| 193/193 [00:13<00:00, 13.80batch/s, accuracy=36.5, loss=2.77]
# 	Train: Loss = 2.7729, Acc = 36.4553
# 	Valid: Loss = 2.7465, Acc = 36.0544
# 	✨ New best validation loss: 2.7465
# ------------------------------------------------------------
# Epoch 4/7 | Current LR: 0.000612
# Epoch 4: 100%|███| 193/193 [00:14<00:00, 13.72batch/s, accuracy=46.8, loss=2.49]
# 	Train: Loss = 2.4902, Acc = 46.7642
# 	Valid: Loss = 2.8128, Acc = 39.4558
# 	Validation loss did not improve. Patience: 1/5
# ------------------------------------------------------------
# Epoch 5/7 | Current LR: 0.000389
# Epoch 5: 100%|██████| 193/193 [00:14<00:00, 13.68batch/s, accuracy=55, loss=2.2]
# 	Train: Loss = 2.2035, Acc = 54.9593
# 	Valid: Loss = 2.8146, Acc = 35.3741
# 	Validation loss did not improve. Patience: 2/5
# ------------------------------------------------------------
# Epoch 6/7 | Current LR: 0.000189
# Epoch 6: 100%|███| 193/193 [00:13<00:00, 13.92batch/s, accuracy=62.3, loss=1.98]
# 	Train: Loss = 1.9790, Acc = 62.3089
# 	Valid: Loss = 2.9945, Acc = 34.0136
# 	Validation loss did not improve. Patience: 3/5
# ------------------------------------------------------------
# Epoch 7/7 | Current LR: 0.000050
# Epoch 7: 100%|███| 193/193 [00:14<00:00, 13.71batch/s, accuracy=67.6, loss=1.82]
# 	Train: Loss = 1.8183, Acc = 67.6423
# 	Valid: Loss = 2.9724, Acc = 36.0544
# 	Validation loss did not improve. Patience: 4/5
# ------------------------------------------------------------
#
# ✅ Loaded best model based on validation accuracy for final testing. /kaggle/working/bac/.models/lstm_bert_model.pt
# Figure(1400x600)
#
# 🧪 Evaluating on Test Set...
#
# --- Test Set Results (Best Validation Model) ---
# 	Test Loss: 2.9096
# 	Test Accuracy (Top-1): 34.47%
# 	Test MRR: 0.4978
# {'loss_train_hist': [3.404812699154869, 3.0329333179355284, 2.7728636931878916, 2.490234656655109, 2.203516504307485, 1.9789606147479517, 1.818331402818156], 'loss_valid_hist': [2.992899465560913, 2.8270652055740357, 2.7464512467384337, 2.812790775299072, 2.814600706100464, 2.9945417642593384, 2.972386598587036], 'acc_train_hist': [18.146341463414632, 30.73170731707317, 36.45528455284553, 46.764227642276424, 54.959349593495936, 62.3089430894309, 67.64227642276423], 'acc_valid_hist': [29.931972789115648, 29.931972789115648, 36.054421768707485, 39.45578231292517, 35.374149659863946, 34.01360544217687, 36.054421768707485], 'test_top_5_acc': 0.7133105802047781, 'test_top_10_acc': 0.8327645051194539, 'test_loss_final': 2.9096423952203048, 'test_acc_top1_final': 34.47098976109215, 'test_mrr_final': 0.4978237215002112}

# %%
result_load_path = f"{os.getcwd()}/.result/lstm_bert_result.json"
plot_history(result_load_path, 7)
