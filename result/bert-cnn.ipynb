# %%
# %cd /kaggle/working
# !git clone https://github.com/AmirEspahbodi/bac.git
# Out:
# /kaggle/working
# fatal: destination path 'bac' already exists and is not an empty directory.

# %%
# !pip install bitsandbytes

# %%
# %cd /kaggle/working/bac
# !git pull
# !ls
# Out:
# /kaggle/working/bac
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 4 (delta 3), reused 0 (delta 0), pack-reused 0 (from 0)
# Unpacking objects: 100% (4/4), 1.05 KiB | 536.00 KiB/s, done.
# From https://github.com/AmirEspahbodi/bac
#    fd3dc39..09775a1  main       -> origin/main
# Updating fd3dc39..09775a1
# Fast-forward
#  src/run_mlp.py | 14 +++++++-------
#  1 file changed, 7 insertions(+), 7 deletions(-)
# datasets     poetry.lock     README.md	src
# inspiration  pyproject.toml  scripts	state.db

# %%
import os
import json
import matplotlib.pyplot as plt


def plot_history(result_load_path, NUM_EPOCHS):
    loss_train_hist = None
    loss_valid_hist = None
    acc_train_hist = None
    acc_valid_hist = None
    test_top_5_acc = None
    test_top_10_acc = None
    test_loss_final = None
    test_acc_top1_final = None
    test_mrr_final = None
        
    # Load the data from the JSON file
    try:
        with open(result_load_path, "r") as f:
            # json.load() reads the file and parses the JSON data into a Python dictionary
            loaded_results = json.load(f)
    
        # Unpack the dictionary values into your variables
        loss_train_hist = loaded_results.get("loss_train_hist")
        loss_valid_hist = loaded_results.get("loss_valid_hist")
        acc_train_hist = loaded_results.get("acc_train_hist")
        acc_valid_hist = loaded_results.get("acc_valid_hist")
        test_top_5_acc = loaded_results.get("test_top_5_acc")
        test_top_10_acc = loaded_results.get("test_top_10_acc")
        test_loss_final = loaded_results.get("test_loss_final")
        test_acc_top1_final = loaded_results.get("test_acc_top1_final")
        test_mrr_final = loaded_results.get("test_mrr_final")
    
    except FileNotFoundError:
        print(f"Error: The file at '{result_load_path}' was not found.")
    except json.JSONDecodeError:
        print(f"Error: The file at '{result_load_path}' is not a valid JSON file.")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")
    
    epochs_range = range(1, NUM_EPOCHS + 1)
    
    plt.figure(figsize=(14, 6))
    
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, loss_train_hist, "bo-", label="Training Loss")
    plt.plot(epochs_range, loss_valid_hist, "ro-", label="Validation Loss")
    plt.title("Training and Validation Loss")
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.legend()
    plt.grid(True)
    
    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, acc_train_hist, "bo-", label="Training Accuracy (Top-1)")
    plt.plot(epochs_range, acc_valid_hist, "ro-", label="Validation Accuracy (Top-1)")
    plt.title("Training and Validation Accuracy (Top-1)")
    plt.xlabel("Epochs")
    plt.ylabel("Accuracy")
    plt.legend()
    plt.grid(True)
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## GCC dataset

# %%
# !python -m src.run_cnn -e bert -d gcc -ne 7 -rsw 0
# Out:
# 2025-07-13 21:14:19.877050: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752441259.901142     606 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752441259.907907     606 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Shape after dropping NA assignees: (2103, 6)
# Number of unique assignees (classes): 82
# Warning: Some classes have fewer than 2 samples (min_samples_per_class=1). Stratification for train/test split might not be possible or effective.
# ✅ Loading pre-saved augmented dataset from 'datasets/augmented_train_dataset_2_GCC.csv'.
# Using device: cuda
# Generating Full Embeddings: 100%|█████████████| 276/276 [01:33<00:00,  2.94it/s]
# Generating Full Embeddings: 100%|███████████████| 14/14 [00:04<00:00,  3.12it/s]
# Generating Full Embeddings: 100%|███████████████| 27/27 [00:08<00:00,  3.12it/s]
#
# DataLoaders created successfully!
# Training batches: 276
# Validation batches: 14
# Test batches: 27
# using bert embeddings
# OPTIMIZER=SGD, LR=0.1
# Epoch 0: 100%|███| 276/276 [00:10<00:00, 27.15batch/s, accuracy=24.2, loss=3.57]
# OPTIMIZER=SGD, LR=0.01
# Epoch 0: 100%|███| 276/276 [00:10<00:00, 27.21batch/s, accuracy=5.26, loss=4.45]
# OPTIMIZER=SGD, LR=0.001
# Epoch 0: 100%|████| 276/276 [00:10<00:00, 27.39batch/s, accuracy=1.5, loss=4.68]
# OPTIMIZER=SGD, LR=0.0001
# Epoch 0: 100%|████| 276/276 [00:09<00:00, 27.78batch/s, accuracy=1.63, loss=4.7]
# OPTIMIZER=Adam, LR=0.1
# Epoch 0: 100%|███| 276/276 [00:10<00:00, 26.81batch/s, accuracy=8.09, loss=4.47]
# OPTIMIZER=Adam, LR=0.01
# Epoch 0: 100%|███| 276/276 [00:10<00:00, 27.42batch/s, accuracy=26.9, loss=3.34]
# OPTIMIZER=Adam, LR=0.001
# Epoch 0: 100%|█████| 276/276 [00:09<00:00, 27.88batch/s, accuracy=27, loss=3.51]
# OPTIMIZER=Adam, LR=0.0001
# Epoch 0: 100%|███| 276/276 [00:10<00:00, 27.33batch/s, accuracy=5.71, loss=4.41]
# OPTIMIZER=Adamw, LR=0.1
# Epoch 0: 100%|███| 276/276 [00:09<00:00, 28.12batch/s, accuracy=9.54, loss=4.34]
# OPTIMIZER=Adamw, LR=0.01
# Epoch 0: 100%|███| 276/276 [00:09<00:00, 27.86batch/s, accuracy=29.3, loss=3.27]
# OPTIMIZER=Adamw, LR=0.001
# Epoch 0: 100%|███| 276/276 [00:09<00:00, 27.64batch/s, accuracy=26.5, loss=3.53]
# OPTIMIZER=Adamw, LR=0.0001
# Epoch 0: 100%|███| 276/276 [00:09<00:00, 27.76batch/s, accuracy=6.87, loss=4.39]
# <class 'torch.optim.adamw.AdamW'> 0.01
#
# ✅ Start Training 7 epochs ...
# Epoch 1/7 | Current LR: 0.010000
# Epoch 1: 100%|███| 276/276 [00:09<00:00, 27.80batch/s, accuracy=30.1, loss=3.26]
# 	Train: Loss = 3.2594, Acc = 30.0702
# 	Valid: Loss = 2.7581, Acc = 43.6019
# 	✨ New best validation loss: 2.7581
# ------------------------------------------------------------
# Epoch 2/7 | Current LR: 0.009505
# Epoch 2: 100%|█████| 276/276 [00:10<00:00, 27.48batch/s, accuracy=43, loss=2.69]
# 	Train: Loss = 2.6941, Acc = 43.0093
# 	Valid: Loss = 2.5662, Acc = 52.1327
# 	✨ New best validation loss: 2.5662
# ------------------------------------------------------------
# Epoch 3/7 | Current LR: 0.008118
# Epoch 3: 100%|███| 276/276 [00:09<00:00, 27.74batch/s, accuracy=51.3, loss=2.36]
# 	Train: Loss = 2.3582, Acc = 51.3483
# 	Valid: Loss = 2.4165, Acc = 53.0806
# 	✨ New best validation loss: 2.4165
# ------------------------------------------------------------
# Epoch 4/7 | Current LR: 0.006113
# Epoch 4: 100%|███| 276/276 [00:09<00:00, 27.92batch/s, accuracy=60.7, loss=2.08]
# 	Train: Loss = 2.0774, Acc = 60.6843
# 	Valid: Loss = 2.3798, Acc = 54.5024
# 	✨ New best validation loss: 2.3798
# ------------------------------------------------------------
# Epoch 5/7 | Current LR: 0.003888
# Epoch 5: 100%|███| 276/276 [00:09<00:00, 27.73batch/s, accuracy=68.8, loss=1.79]
# 	Train: Loss = 1.7948, Acc = 68.7967
# 	Valid: Loss = 2.3509, Acc = 54.5024
# 	✨ New best validation loss: 2.3509
# ------------------------------------------------------------
# Epoch 6/7 | Current LR: 0.001883
# Epoch 6: 100%|███| 276/276 [00:10<00:00, 27.35batch/s, accuracy=77.8, loss=1.58]
# 	Train: Loss = 1.5760, Acc = 77.7929
# 	Valid: Loss = 2.2788, Acc = 54.5024
# 	✨ New best validation loss: 2.2788
# ------------------------------------------------------------
# Epoch 7/7 | Current LR: 0.000496
# Epoch 7: 100%|███| 276/276 [00:09<00:00, 27.68batch/s, accuracy=82.8, loss=1.45]
# 	Train: Loss = 1.4462, Acc = 82.8235
# 	Valid: Loss = 2.2841, Acc = 54.0284
# 	Validation loss did not improve. Patience: 1/5
# ------------------------------------------------------------
#
# ✅ Loaded best model based on validation accuracy for final testing. /kaggle/working/bac/.models/cnn_bert_rsw0_model.pt
# Figure(1400x600)
#
# 🧪 Evaluating on Test Set...
#
# --- Test Set Results (Best Validation Model) ---
# 	Test Loss: 2.2631
# 	Test Accuracy (Top-1): 59.14%
# 	Test MRR: 0.6890
# {'loss_train_hist': [3.259438757879147, 2.6941189826398655, 2.3581840236117873, 2.0773807647435563, 1.7947597870792167, 1.5760282688382743, 1.4461578921131466], 'loss_valid_hist': [2.7580754927226474, 2.5662204708371843, 2.4165254150118147, 2.3797528317996433, 2.350914869989668, 2.2788231798580716, 2.28408613375255], 'acc_train_hist': [30.070246997507365, 43.009290731928395, 51.34828914570587, 60.68434171765239, 68.79673691366418, 77.79288465896215, 82.82347609336053], 'acc_valid_hist': [43.60189573459716, 52.132701421800945, 53.08056872037915, 54.502369668246445, 54.502369668246445, 54.502369668246445, 54.02843601895734], 'test_top_5_acc': 0.8028503562945368, 'test_top_10_acc': 0.8859857482185273, 'test_loss_final': 2.263130956225925, 'test_acc_top1_final': 59.14489311163896, 'test_mrr_final': 0.6890326111930352}

# %%
result_load_path = f"{os.getcwd()}/.result/cnn_bert_rsw0_result.json"
plot_history(result_load_path, 7)

# %% [markdown]
# ## JDT dataset

# %%
# !python -m src.run_cnn -e bert -d jdt -ne 7 -rsw 0
# Out:
# 2025-07-13 21:02:40.025276: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752440560.048913     355 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752440560.056065     355 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Shape after dropping NA assignees: (1465, 5)
# Number of unique assignees (classes): 69
# Warning: Some classes have fewer than 2 samples (min_samples_per_class=1). Stratification for train/test split might not be possible or effective.
# ✅ Loading pre-saved augmented dataset from 'datasets/augmented_train_dataset_2_JDT.csv'.
# Using device: cuda
# Generating Full Embeddings: 100%|█████████████| 193/193 [01:04<00:00,  3.00it/s]
# Generating Full Embeddings: 100%|███████████████| 10/10 [00:02<00:00,  3.34it/s]
# Generating Full Embeddings: 100%|███████████████| 19/19 [00:06<00:00,  3.04it/s]
#
# DataLoaders created successfully!
# Training batches: 193
# Validation batches: 10
# Test batches: 19
# using bert embeddings
# OPTIMIZER=SGD, LR=0.1
# Epoch 0: 100%|████| 193/193 [00:07<00:00, 25.99batch/s, accuracy=19.6, loss=3.6]
# OPTIMIZER=SGD, LR=0.01
# Epoch 0: 100%|███| 193/193 [00:06<00:00, 27.93batch/s, accuracy=5.89, loss=4.27]
# OPTIMIZER=SGD, LR=0.001
# Epoch 0: 100%|████| 193/193 [00:06<00:00, 27.83batch/s, accuracy=1.76, loss=4.5]
# OPTIMIZER=SGD, LR=0.0001
# Epoch 0: 100%|████| 193/193 [00:07<00:00, 26.82batch/s, accuracy=1.3, loss=4.53]
# OPTIMIZER=Adam, LR=0.1
# Epoch 0: 100%|███| 193/193 [00:06<00:00, 27.83batch/s, accuracy=12.6, loss=4.03]
# OPTIMIZER=Adam, LR=0.01
# Epoch 0: 100%|███| 193/193 [00:07<00:00, 27.05batch/s, accuracy=23.3, loss=3.24]
# OPTIMIZER=Adam, LR=0.001
# Epoch 0: 100%|███| 193/193 [00:07<00:00, 27.42batch/s, accuracy=22.3, loss=3.59]
# OPTIMIZER=Adam, LR=0.0001
# Epoch 0: 100%|███| 193/193 [00:06<00:00, 28.01batch/s, accuracy=6.73, loss=4.24]
# OPTIMIZER=Adamw, LR=0.1
# Epoch 0: 100%|███| 193/193 [00:07<00:00, 26.78batch/s, accuracy=13.4, loss=4.01]
# OPTIMIZER=Adamw, LR=0.01
# Epoch 0: 100%|████| 193/193 [00:07<00:00, 27.46batch/s, accuracy=23.3, loss=3.2]
# OPTIMIZER=Adamw, LR=0.001
# Epoch 0: 100%|███| 193/193 [00:07<00:00, 27.08batch/s, accuracy=20.3, loss=3.58]
# OPTIMIZER=Adamw, LR=0.0001
# Epoch 0: 100%|███| 193/193 [00:06<00:00, 27.85batch/s, accuracy=6.44, loss=4.25]
# <class 'torch.optim.adamw.AdamW'> 0.01
#
# ✅ Start Training 7 epochs ...
# Epoch 1/7 | Current LR: 0.010000
# Epoch 1: 100%|███| 193/193 [00:07<00:00, 27.16batch/s, accuracy=24.3, loss=3.22]
# 	Train: Loss = 3.2180, Acc = 24.2602
# 	Valid: Loss = 2.7108, Acc = 31.2925
# 	✨ New best validation loss: 2.7108
# ------------------------------------------------------------
# Epoch 2/7 | Current LR: 0.009505
# Epoch 2: 100%|███| 193/193 [00:06<00:00, 27.96batch/s, accuracy=38.2, loss=2.72]
# 	Train: Loss = 2.7197, Acc = 38.2114
# 	Valid: Loss = 2.6104, Acc = 34.0136
# 	✨ New best validation loss: 2.6104
# ------------------------------------------------------------
# Epoch 3/7 | Current LR: 0.008118
# Epoch 3: 100%|███| 193/193 [00:07<00:00, 26.84batch/s, accuracy=47.5, loss=2.42]
# 	Train: Loss = 2.4198, Acc = 47.5122
# 	Valid: Loss = 2.5841, Acc = 36.7347
# 	✨ New best validation loss: 2.5841
# ------------------------------------------------------------
# Epoch 4/7 | Current LR: 0.006113
# Epoch 4: 100%|██████| 193/193 [00:06<00:00, 27.87batch/s, accuracy=60.8, loss=2]
# 	Train: Loss = 2.0044, Acc = 60.7805
# 	Valid: Loss = 2.5632, Acc = 46.2585
# 	✨ New best validation loss: 2.5632
# ------------------------------------------------------------
# Epoch 5/7 | Current LR: 0.003888
# Epoch 5: 100%|█████| 193/193 [00:07<00:00, 27.53batch/s, accuracy=73, loss=1.67]
# 	Train: Loss = 1.6722, Acc = 73.0407
# 	Valid: Loss = 2.6635, Acc = 40.1361
# 	Validation loss did not improve. Patience: 1/5
# ------------------------------------------------------------
# Epoch 6/7 | Current LR: 0.001883
# Epoch 6: 100%|███| 193/193 [00:06<00:00, 27.83batch/s, accuracy=81.9, loss=1.43]
# 	Train: Loss = 1.4292, Acc = 81.9187
# 	Valid: Loss = 2.7268, Acc = 40.8163
# 	Validation loss did not improve. Patience: 2/5
# ------------------------------------------------------------
# Epoch 7/7 | Current LR: 0.000496
# Epoch 7: 100%|███| 193/193 [00:07<00:00, 27.38batch/s, accuracy=86.6, loss=1.31]
# 	Train: Loss = 1.3077, Acc = 86.6341
# 	Valid: Loss = 2.7449, Acc = 39.4558
# 	Validation loss did not improve. Patience: 3/5
# ------------------------------------------------------------
#
# ✅ Loaded best model based on validation accuracy for final testing. /kaggle/working/bac/.models/cnn_bert_rsw0_model.pt
# Figure(1400x600)
#
# 🧪 Evaluating on Test Set...
#
# --- Test Set Results (Best Validation Model) ---
# 	Test Loss: 2.7105
# 	Test Accuracy (Top-1): 38.57%
# 	Test MRR: 0.5546
# {'loss_train_hist': [3.2180333421637974, 2.7197461029408507, 2.4197948547224923, 2.004384483080454, 1.6721679725795213, 1.429222809218372, 1.3076567056883184], 'loss_valid_hist': [2.710780382156372, 2.6104083776474, 2.584149944782257, 2.563183903694153, 2.663538670539856, 2.7268096446990966, 2.744906783103943], 'acc_train_hist': [24.260162601626018, 38.21138211382114, 47.51219512195122, 60.78048780487805, 73.04065040650407, 81.91869918699187, 86.63414634146342], 'acc_valid_hist': [31.292517006802722, 34.01360544217687, 36.734693877551024, 46.25850340136054, 40.136054421768705, 40.816326530612244, 39.45578231292517], 'test_top_5_acc': 0.7713310580204779, 'test_top_10_acc': 0.8839590443686007, 'test_loss_final': 2.710549655713533, 'test_acc_top1_final': 38.56655290102389, 'test_mrr_final': 0.5545725309823748}

# %%
result_load_path = f"{os.getcwd()}/.result/cnn_bert_rsw0_result.json"
plot_history(result_load_path, 7)
