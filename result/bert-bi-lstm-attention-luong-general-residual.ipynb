# %%
# %cd /kaggle/working
# !git clone https://github.com/AmirEspahbodi/bac.git
# Out:
# /kaggle/working
# fatal: destination path 'bac' already exists and is not an empty directory.

# %%
import os
from kaggle_secrets import UserSecretsClient
from huggingface_hub import login

# --- Hugging Face Authentication ---
try:
    user_secrets = UserSecretsClient()
    HUGGING_FACE_TOKEN = user_secrets.get_secret("HUGGING_FACE_TOKEN")
    # Ensure the token is set as an environment variable for transformers
    os.environ["HUGGING_FACE_HUB_TOKEN"] = HUGGING_FACE_TOKEN
    # Log in to Hugging Face Hub
    login(token=hf_token)
    print("✅ Successfully authenticated with Hugging Face.")
except Exception as e:
    print(f"⚠️ Could not authenticate with Hugging Face. Make sure the 'HUGGING_FACE_TOKEN' secret is set. Error: {e}")

# %%
# !pip install bitsandbytes

# %%
# %cd /kaggle/working/bac
# !git pull
# !ls
# Out:
# /kaggle/working/bac
# Already up to date.
# datasets     poetry.lock     README.md	src
# inspiration  pyproject.toml  scripts	state.db

# %%
import os
import json
import matplotlib.pyplot as plt


def plot_history(result_load_path, NUM_EPOCHS):
    loss_train_hist = None
    loss_valid_hist = None
    acc_train_hist = None
    acc_valid_hist = None
    test_top_5_acc = None
    test_top_10_acc = None
    test_loss_final = None
    test_acc_top1_final = None
    test_mrr_final = None
        
    # Load the data from the JSON file
    try:
        with open(result_load_path, "r") as f:
            # json.load() reads the file and parses the JSON data into a Python dictionary
            loaded_results = json.load(f)
    
        # Unpack the dictionary values into your variables
        loss_train_hist = loaded_results.get("loss_train_hist")
        loss_valid_hist = loaded_results.get("loss_valid_hist")
        acc_train_hist = loaded_results.get("acc_train_hist")
        acc_valid_hist = loaded_results.get("acc_valid_hist")
        test_top_5_acc = loaded_results.get("test_top_5_acc")
        test_top_10_acc = loaded_results.get("test_top_10_acc")
        test_loss_final = loaded_results.get("test_loss_final")
        test_acc_top1_final = loaded_results.get("test_acc_top1_final")
        test_mrr_final = loaded_results.get("test_mrr_final")
    
    except FileNotFoundError:
        print(f"Error: The file at '{result_load_path}' was not found.")
    except json.JSONDecodeError:
        print(f"Error: The file at '{result_load_path}' is not a valid JSON file.")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")
    
    epochs_range = range(1, NUM_EPOCHS + 1)
    
    plt.figure(figsize=(14, 6))
    
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, loss_train_hist, "bo-", label="Training Loss")
    plt.plot(epochs_range, loss_valid_hist, "ro-", label="Validation Loss")
    plt.title("Training and Validation Loss")
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.legend()
    plt.grid(True)
    
    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, acc_train_hist, "bo-", label="Training Accuracy (Top-1)")
    plt.plot(epochs_range, acc_valid_hist, "ro-", label="Validation Accuracy (Top-1)")
    plt.title("Training and Validation Accuracy (Top-1)")
    plt.xlabel("Epochs")
    plt.ylabel("Accuracy")
    plt.legend()
    plt.grid(True)
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## GCC dataset

# %%
# !python -m src.run_lstm -e bert -d gcc -ne 7 -rsw 0 -a 1 -b 1 -r 1 -hs 256 -l 2 -nah 1 -lam general
# Out:
# 2025-07-12 12:12:43.186049: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752322363.208414    1672 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752322363.215153    1672 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Shape after dropping NA assignees: (2103, 6)
# Number of unique assignees (classes): 82
# Warning: Some classes have fewer than 2 samples (min_samples_per_class=1). Stratification for train/test split might not be possible or effective.
# ✅ Loading pre-saved augmented dataset from 'datasets/augmented_train_dataset_2_GCC.csv'.
# Using device: cuda
# Generating Full Embeddings: 100%|█████████████| 276/276 [01:32<00:00,  2.97it/s]
# Generating Full Embeddings: 100%|███████████████| 14/14 [00:04<00:00,  3.15it/s]
# Generating Full Embeddings: 100%|███████████████| 27/27 [00:08<00:00,  3.13it/s]
#
# DataLoaders created successfully!
# Training batches: 276
# Validation batches: 14
# Test batches: 27
# using bert embeddings
#
# ------
# lstm model info:
# {'total_parameters': 4291666, 'trainable_parameters': 4291666, 'model_size_mb': 16.37140655517578, 'config': LSTMConfig(input_size=768, hidden_size=256, num_layers=2, num_classes=82, dropout=0.4, bidirectional=True, use_attention=True, attention_heads=1, attention_dropout=0.1, layer_norm=True, residual_connections=1, gradient_clipping=1.0, luong_attention_method='general'), 'is_bidirectional': True, 'uses_attention': True, 'attention_heads': 1}
# ------
#
# OPTIMIZER=SGD, LR=0.1
# Epoch 0: 100%|███| 276/276 [00:30<00:00,  8.93batch/s, accuracy=11.8, loss=3.86]
# OPTIMIZER=SGD, LR=0.01
# Epoch 0: 100%|███| 276/276 [00:30<00:00,  9.16batch/s, accuracy=15.3, loss=3.83]
# OPTIMIZER=SGD, LR=0.001
# Epoch 0: 100%|███| 276/276 [00:29<00:00,  9.23batch/s, accuracy=11.2, loss=4.18]
# OPTIMIZER=SGD, LR=0.0001
# Epoch 0: 100%|██████| 276/276 [00:30<00:00,  9.19batch/s, accuracy=1.99, loss=5]
# OPTIMIZER=Adam, LR=0.1
# Epoch 0: 100%|███| 276/276 [00:30<00:00,  8.96batch/s, accuracy=10.4, loss=7.14]
# OPTIMIZER=Adam, LR=0.01
# Epoch 0: 100%|███| 276/276 [00:31<00:00,  8.90batch/s, accuracy=11.6, loss=3.91]
# OPTIMIZER=Adam, LR=0.001
# Epoch 0: 100%|███| 276/276 [00:30<00:00,  8.99batch/s, accuracy=13.4, loss=3.77]
# OPTIMIZER=Adam, LR=0.0001
# Epoch 0: 100%|███| 276/276 [00:30<00:00,  9.16batch/s, accuracy=20.6, loss=3.68]
# OPTIMIZER=Adamw, LR=0.1
# Epoch 0: 100%|███| 276/276 [00:30<00:00,  8.98batch/s, accuracy=12.7, loss=4.86]
# OPTIMIZER=Adamw, LR=0.01
# Epoch 0: 100%|███| 276/276 [00:30<00:00,  9.01batch/s, accuracy=11.5, loss=3.84]
# OPTIMIZER=Adamw, LR=0.001
# Epoch 0: 100%|███| 276/276 [00:30<00:00,  8.95batch/s, accuracy=13.6, loss=3.75]
# OPTIMIZER=Adamw, LR=0.0001
# Epoch 0: 100%|███| 276/276 [00:30<00:00,  9.03batch/s, accuracy=22.5, loss=3.65]
# <class 'torch.optim.adamw.AdamW'> 0.0001
#
# ✅ Start Training 7 epochs ...
# Epoch 1/7 | Current LR: 0.000100
# Epoch 1: 100%|███| 276/276 [00:30<00:00,  9.07batch/s, accuracy=20.3, loss=3.71]
# 	Train: Loss = 3.7077, Acc = 20.3263
# 	Valid: Loss = 3.2532, Acc = 30.3318
# 	✨ New best validation loss: 3.2532
# ------------------------------------------------------------
# Epoch 2/7 | Current LR: 0.000095
# Epoch 2: 100%|███| 276/276 [00:30<00:00,  9.10batch/s, accuracy=37.2, loss=2.97]
# 	Train: Loss = 2.9684, Acc = 37.1629
# 	Valid: Loss = 2.8715, Acc = 41.2322
# 	✨ New best validation loss: 2.8715
# ------------------------------------------------------------
# Epoch 3/7 | Current LR: 0.000081
# Epoch 3: 100%|███| 276/276 [00:30<00:00,  9.05batch/s, accuracy=47.4, loss=2.54]
# 	Train: Loss = 2.5430, Acc = 47.3601
# 	Valid: Loss = 2.7831, Acc = 43.6019
# 	✨ New best validation loss: 2.7831
# ------------------------------------------------------------
# Epoch 4/7 | Current LR: 0.000062
# Epoch 4: 100%|███| 276/276 [00:30<00:00,  9.10batch/s, accuracy=57.1, loss=2.19]
# 	Train: Loss = 2.1947, Acc = 57.0587
# 	Valid: Loss = 2.6873, Acc = 47.8673
# 	✨ New best validation loss: 2.6873
# ------------------------------------------------------------
# Epoch 5/7 | Current LR: 0.000039
# Epoch 5: 100%|███| 276/276 [00:30<00:00,  9.08batch/s, accuracy=64.9, loss=1.94]
# 	Train: Loss = 1.9415, Acc = 64.8992
# 	Valid: Loss = 2.6704, Acc = 46.9194
# 	✨ New best validation loss: 2.6704
# ------------------------------------------------------------
# Epoch 6/7 | Current LR: 0.000020
# Epoch 6: 100%|███| 276/276 [00:30<00:00,  9.02batch/s, accuracy=71.8, loss=1.75]
# 	Train: Loss = 1.7472, Acc = 71.8106
# 	Valid: Loss = 2.6473, Acc = 47.3934
# 	✨ New best validation loss: 2.6473
# ------------------------------------------------------------
# Epoch 7/7 | Current LR: 0.000006
# Epoch 7: 100%|███| 276/276 [00:30<00:00,  9.05batch/s, accuracy=75.2, loss=1.66]
# 	Train: Loss = 1.6553, Acc = 75.1643
# 	Valid: Loss = 2.6604, Acc = 47.3934
# 	Validation loss did not improve. Patience: 1/5
# ------------------------------------------------------------
#
# ✅ Loaded best model based on validation accuracy for final testing. /kaggle/working/bac/.models/lstm_bert_model.pt
# Figure(1400x600)
#
# 🧪 Evaluating on Test Set...
#
# --- Test Set Results (Best Validation Model) ---
# 	Test Loss: 2.5460
# 	Test Accuracy (Top-1): 51.07%
# 	Test MRR: 0.6182
# {'loss_train_hist': [3.707749773626742, 2.9684057857679282, 2.5429984871028126, 2.194687227408091, 1.9415391769962034, 1.747232327858607, 1.6552518817825594], 'loss_valid_hist': [3.253208807536534, 2.8715140989848544, 2.7830976247787476, 2.687293222972325, 2.670383027621678, 2.6473358869552612, 2.6604215587888445], 'acc_train_hist': [20.326308633582595, 37.16292771357353, 47.360072513029685, 57.058690233401315, 64.89916156809427, 71.81055970994788, 75.16428733288012], 'acc_valid_hist': [30.33175355450237, 41.23222748815166, 43.60189573459716, 47.867298578199055, 46.91943127962085, 47.39336492890995, 47.39336492890995], 'test_top_5_acc': 0.7315914489311164, 'test_top_10_acc': 0.828978622327791, 'test_loss_final': 2.5459563776298806, 'test_acc_top1_final': 51.06888361045131, 'test_mrr_final': 0.6181542315757989}

# %%
result_load_path = f"{os.getcwd()}/.result/lstm_bert_result.json"
plot_history(result_load_path, 7)

# %% [markdown]
# ## JDT dataset

# %%
# !python -m src.run_lstm -e bert -d jdt -ne 7 -rsw 0 -a 1 -b 1 -r 1 -hs 256 -l 2 -nah 1 -lam general
# Out:
# 2025-07-12 12:24:39.856933: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752323079.880082    1921 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752323079.886962    1921 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Shape after dropping NA assignees: (1465, 5)
# Number of unique assignees (classes): 69
# Warning: Some classes have fewer than 2 samples (min_samples_per_class=1). Stratification for train/test split might not be possible or effective.
# ✅ Loading pre-saved augmented dataset from 'datasets/augmented_train_dataset_2_JDT.csv'.
# Using device: cuda
# Generating Full Embeddings: 100%|█████████████| 193/193 [01:03<00:00,  3.05it/s]
# Generating Full Embeddings: 100%|███████████████| 10/10 [00:02<00:00,  3.38it/s]
# Generating Full Embeddings: 100%|███████████████| 19/19 [00:06<00:00,  3.10it/s]
#
# DataLoaders created successfully!
# Training batches: 193
# Validation batches: 10
# Test batches: 19
# using bert embeddings
#
# ------
# lstm model info:
# {'total_parameters': 4288325, 'trainable_parameters': 4288325, 'model_size_mb': 16.358661651611328, 'config': LSTMConfig(input_size=768, hidden_size=256, num_layers=2, num_classes=69, dropout=0.4, bidirectional=True, use_attention=True, attention_heads=1, attention_dropout=0.1, layer_norm=True, residual_connections=1, gradient_clipping=1.0, luong_attention_method='general'), 'is_bidirectional': True, 'uses_attention': True, 'attention_heads': 1}
# ------
#
# OPTIMIZER=SGD, LR=0.1
# Epoch 0: 100%|███| 193/193 [00:21<00:00,  8.88batch/s, accuracy=14.9, loss=3.64]
# OPTIMIZER=SGD, LR=0.01
# Epoch 0: 100%|███| 193/193 [00:21<00:00,  9.09batch/s, accuracy=16.9, loss=3.49]
# OPTIMIZER=SGD, LR=0.001
# Epoch 0: 100%|███| 193/193 [00:21<00:00,  9.06batch/s, accuracy=12.4, loss=3.82]
# OPTIMIZER=SGD, LR=0.0001
# Epoch 0: 100%|████| 193/193 [00:21<00:00,  9.10batch/s, accuracy=2.7, loss=4.59]
# OPTIMIZER=Adam, LR=0.1
# Epoch 0: 100%|█████| 193/193 [00:21<00:00,  8.95batch/s, accuracy=13.2, loss=11]
# OPTIMIZER=Adam, LR=0.01
# Epoch 0: 100%|███| 193/193 [00:21<00:00,  8.83batch/s, accuracy=14.5, loss=3.57]
# OPTIMIZER=Adam, LR=0.001
# Epoch 0: 100%|███| 193/193 [00:21<00:00,  8.91batch/s, accuracy=19.5, loss=3.39]
# OPTIMIZER=Adam, LR=0.0001
# Epoch 0: 100%|███| 193/193 [00:21<00:00,  9.02batch/s, accuracy=18.7, loss=3.42]
# OPTIMIZER=Adamw, LR=0.1
# Epoch 0: 100%|████| 193/193 [00:21<00:00,  8.88batch/s, accuracy=14.6, loss=6.2]
# OPTIMIZER=Adamw, LR=0.01
# Epoch 0: 100%|███| 193/193 [00:21<00:00,  8.91batch/s, accuracy=14.4, loss=3.62]
# OPTIMIZER=Adamw, LR=0.001
# Epoch 0: 100%|███| 193/193 [00:21<00:00,  8.91batch/s, accuracy=20.4, loss=3.36]
# OPTIMIZER=Adamw, LR=0.0001
# Epoch 0: 100%|███| 193/193 [00:21<00:00,  8.89batch/s, accuracy=18.6, loss=3.44]
# <class 'torch.optim.adamw.AdamW'> 0.001
#
# ✅ Start Training 7 epochs ...
# Epoch 1/7 | Current LR: 0.001000
# Epoch 1: 100%|████| 193/193 [00:21<00:00,  8.94batch/s, accuracy=19.6, loss=3.4]
# 	Train: Loss = 3.3987, Acc = 19.6423
# 	Valid: Loss = 3.0092, Acc = 29.2517
# 	✨ New best validation loss: 3.0092
# ------------------------------------------------------------
# Epoch 2/7 | Current LR: 0.000951
# Epoch 2: 100%|███| 193/193 [00:21<00:00,  8.92batch/s, accuracy=31.7, loss=2.97]
# 	Train: Loss = 2.9677, Acc = 31.7398
# 	Valid: Loss = 2.7615, Acc = 32.6531
# 	✨ New best validation loss: 2.7615
# ------------------------------------------------------------
# Epoch 3/7 | Current LR: 0.000812
# Epoch 3: 100%|███| 193/193 [00:21<00:00,  8.92batch/s, accuracy=37.6, loss=2.74]
# 	Train: Loss = 2.7373, Acc = 37.6260
# 	Valid: Loss = 2.6709, Acc = 36.0544
# 	✨ New best validation loss: 2.6709
# ------------------------------------------------------------
# Epoch 4/7 | Current LR: 0.000612
# Epoch 4: 100%|█████| 193/193 [00:21<00:00,  8.92batch/s, accuracy=45, loss=2.47]
# 	Train: Loss = 2.4663, Acc = 45.0407
# 	Valid: Loss = 2.7227, Acc = 36.7347
# 	Validation loss did not improve. Patience: 1/5
# ------------------------------------------------------------
# Epoch 5/7 | Current LR: 0.000389
# Epoch 5: 100%|███| 193/193 [00:21<00:00,  8.92batch/s, accuracy=54.8, loss=2.17]
# 	Train: Loss = 2.1669, Acc = 54.7967
# 	Valid: Loss = 2.7356, Acc = 36.0544
# 	Validation loss did not improve. Patience: 2/5
# ------------------------------------------------------------
# Epoch 6/7 | Current LR: 0.000189
# Epoch 6: 100%|███| 193/193 [00:21<00:00,  8.88batch/s, accuracy=64.9, loss=1.88]
# 	Train: Loss = 1.8824, Acc = 64.9106
# 	Valid: Loss = 2.8763, Acc = 38.7755
# 	Validation loss did not improve. Patience: 3/5
# ------------------------------------------------------------
# Epoch 7/7 | Current LR: 0.000050
# Epoch 7: 100%|████| 193/193 [00:21<00:00,  8.89batch/s, accuracy=71.4, loss=1.7]
# 	Train: Loss = 1.7005, Acc = 71.4146
# 	Valid: Loss = 2.9821, Acc = 38.0952
# 	Validation loss did not improve. Patience: 4/5
# ------------------------------------------------------------
#
# ✅ Loaded best model based on validation accuracy for final testing. /kaggle/working/bac/.models/lstm_bert_model.pt
# Figure(1400x600)
#
# 🧪 Evaluating on Test Set...
#
# --- Test Set Results (Best Validation Model) ---
# 	Test Loss: 2.9365
# 	Test Accuracy (Top-1): 31.40%
# 	Test MRR: 0.4781
# {'loss_train_hist': [3.398679372560175, 2.967723736491228, 2.7372807962289127, 2.4663267030617115, 2.166888576715104, 1.8823589364481714, 1.7004774259162072], 'loss_valid_hist': [3.009213662147522, 2.761497509479523, 2.670904207229614, 2.722705137729645, 2.7356117486953737, 2.8762789964675903, 2.9821335554122923], 'acc_train_hist': [19.642276422764226, 31.739837398373982, 37.6260162601626, 45.040650406504064, 54.796747967479675, 64.91056910569105, 71.41463414634147], 'acc_valid_hist': [29.25170068027211, 32.6530612244898, 36.054421768707485, 36.734693877551024, 36.054421768707485, 38.775510204081634, 38.095238095238095], 'test_top_5_acc': 0.6655290102389079, 'test_top_10_acc': 0.8225255972696246, 'test_loss_final': 2.9365329867915104, 'test_acc_top1_final': 31.399317406143346, 'test_mrr_final': 0.47814049458140384}

# %%
result_load_path = f"{os.getcwd()}/.result/lstm_bert_result.json"
plot_history(result_load_path, 7)
