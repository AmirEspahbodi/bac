# %%
# %cd /kaggle/working
# !git clone https://github.com/AmirEspahbodi/bac.git
# Out:
# /kaggle/working
# fatal: destination path 'bac' already exists and is not an empty directory.

# %%
# !pip install bitsandbytes

# %%
# %cd /kaggle/working/bac
# !git pull
# !ls
# Out:
# /kaggle/working/bac
# Already up to date.
# datasets     poetry.lock     README.md	src
# inspiration  pyproject.toml  scripts	state.db

# %%
import os
import json
import matplotlib.pyplot as plt


def plot_history(result_load_path, NUM_EPOCHS):
    loss_train_hist = None
    loss_valid_hist = None
    acc_train_hist = None
    acc_valid_hist = None
    test_top_5_acc = None
    test_top_10_acc = None
    test_loss_final = None
    test_acc_top1_final = None
    test_mrr_final = None
        
    # Load the data from the JSON file
    try:
        with open(result_load_path, "r") as f:
            # json.load() reads the file and parses the JSON data into a Python dictionary
            loaded_results = json.load(f)
    
        # Unpack the dictionary values into your variables
        loss_train_hist = loaded_results.get("loss_train_hist")
        loss_valid_hist = loaded_results.get("loss_valid_hist")
        acc_train_hist = loaded_results.get("acc_train_hist")
        acc_valid_hist = loaded_results.get("acc_valid_hist")
        test_top_5_acc = loaded_results.get("test_top_5_acc")
        test_top_10_acc = loaded_results.get("test_top_10_acc")
        test_loss_final = loaded_results.get("test_loss_final")
        test_acc_top1_final = loaded_results.get("test_acc_top1_final")
        test_mrr_final = loaded_results.get("test_mrr_final")
    
    except FileNotFoundError:
        print(f"Error: The file at '{result_load_path}' was not found.")
    except json.JSONDecodeError:
        print(f"Error: The file at '{result_load_path}' is not a valid JSON file.")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")
    
    epochs_range = range(1, NUM_EPOCHS + 1)
    
    plt.figure(figsize=(14, 6))
    
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, loss_train_hist, "bo-", label="Training Loss")
    plt.plot(epochs_range, loss_valid_hist, "ro-", label="Validation Loss")
    plt.title("Training and Validation Loss")
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.legend()
    plt.grid(True)
    
    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, acc_train_hist, "bo-", label="Training Accuracy (Top-1)")
    plt.plot(epochs_range, acc_valid_hist, "ro-", label="Validation Accuracy (Top-1)")
    plt.title("Training and Validation Accuracy (Top-1)")
    plt.xlabel("Epochs")
    plt.ylabel("Accuracy")
    plt.legend()
    plt.grid(True)
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## GCC dataset

# %%
# !python -m src.run_lstm -e bert -d gcc -ne 7 -rsw 0 -a 0 -b 0 -r 0 -hs 256 -l 2 -nah 1 -lam concat
# Out:
# 2025-07-12 17:03:00.553702: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752339780.584692    2669 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752339780.593795    2669 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Shape after dropping NA assignees: (2103, 6)
# Number of unique assignees (classes): 82
# Warning: Some classes have fewer than 2 samples (min_samples_per_class=1). Stratification for train/test split might not be possible or effective.
# ✅ Loading pre-saved augmented dataset from 'datasets/augmented_train_dataset_2_GCC.csv'.
# Using device: cuda
# Generating Full Embeddings: 100%|█████████████| 276/276 [01:33<00:00,  2.96it/s]
# Generating Full Embeddings: 100%|███████████████| 14/14 [00:04<00:00,  3.13it/s]
# Generating Full Embeddings: 100%|███████████████| 27/27 [00:08<00:00,  3.10it/s]
#
# DataLoaders created successfully!
# Training batches: 276
# Validation batches: 14
# Test batches: 27
# using bert embeddings
#
# ------
# lstm model info:
# {'total_parameters': 1818322, 'trainable_parameters': 1818322, 'model_size_mb': 6.936347961425781, 'config': LSTMConfig(input_size=768, hidden_size=256, num_layers=2, num_classes=82, dropout=0.4, bidirectional=False, use_attention=False, attention_heads=1, attention_dropout=0.1, layer_norm=True, residual_connections=0, gradient_clipping=1.0, luong_attention_method='concat'), 'is_bidirectional': False, 'uses_attention': False, 'attention_heads': 0}
# ------
#
# OPTIMIZER=SGD, LR=0.1
# Epoch 0: 100%|███| 276/276 [00:19<00:00, 14.17batch/s, accuracy=13.9, loss=3.68]
# OPTIMIZER=SGD, LR=0.01
# Epoch 0: 100%|███| 276/276 [00:19<00:00, 14.43batch/s, accuracy=12.4, loss=3.79]
# OPTIMIZER=SGD, LR=0.001
# Epoch 0: 100%|███| 276/276 [00:18<00:00, 14.57batch/s, accuracy=10.9, loss=4.26]
# OPTIMIZER=SGD, LR=0.0001
# Epoch 0: 100%|████| 276/276 [00:18<00:00, 14.56batch/s, accuracy=1.54, loss=4.4]
# OPTIMIZER=Adam, LR=0.1
# Epoch 0: 100%|███| 276/276 [00:19<00:00, 14.29batch/s, accuracy=11.2, loss=4.37]
# OPTIMIZER=Adam, LR=0.01
# Epoch 0: 100%|██████| 276/276 [00:19<00:00, 14.11batch/s, accuracy=12, loss=3.7]
# OPTIMIZER=Adam, LR=0.001
# Epoch 0: 100%|███| 276/276 [00:19<00:00, 14.14batch/s, accuracy=13.7, loss=3.69]
# OPTIMIZER=Adam, LR=0.0001
# Epoch 0: 100%|█████| 276/276 [00:19<00:00, 14.29batch/s, accuracy=12, loss=3.94]
# OPTIMIZER=Adamw, LR=0.1
# Epoch 0: 100%|███| 276/276 [00:19<00:00, 14.43batch/s, accuracy=11.7, loss=3.85]
# OPTIMIZER=Adamw, LR=0.01
# Epoch 0: 100%|████| 276/276 [00:19<00:00, 14.34batch/s, accuracy=12.7, loss=3.7]
# OPTIMIZER=Adamw, LR=0.001
# Epoch 0: 100%|███| 276/276 [00:19<00:00, 14.29batch/s, accuracy=14.3, loss=3.69]
# OPTIMIZER=Adamw, LR=0.0001
# Epoch 0: 100%|███| 276/276 [00:19<00:00, 14.07batch/s, accuracy=11.4, loss=3.91]
# <class 'torch.optim.adamw.AdamW'> 0.001
#
# ✅ Start Training 7 epochs ...
# Epoch 1/7 | Current LR: 0.001000
# Epoch 1: 100%|███| 276/276 [00:19<00:00, 14.15batch/s, accuracy=15.3, loss=3.69]
# 	Train: Loss = 3.6855, Acc = 15.3410
# 	Valid: Loss = 3.6246, Acc = 17.0616
# 	✨ New best validation loss: 3.6246
# ------------------------------------------------------------
# Epoch 2/7 | Current LR: 0.000951
# Epoch 2: 100%|█████| 276/276 [00:19<00:00, 14.05batch/s, accuracy=25, loss=3.35]
# 	Train: Loss = 3.3509, Acc = 24.9717
# 	Valid: Loss = 3.3901, Acc = 24.6445
# 	✨ New best validation loss: 3.3901
# ------------------------------------------------------------
# Epoch 3/7 | Current LR: 0.000812
# Epoch 3: 100%|███| 276/276 [00:19<00:00, 14.15batch/s, accuracy=33.9, loss=3.04]
# 	Train: Loss = 3.0408, Acc = 33.9225
# 	Valid: Loss = 3.2644, Acc = 27.0142
# 	✨ New best validation loss: 3.2644
# ------------------------------------------------------------
# Epoch 4/7 | Current LR: 0.000612
# Epoch 4: 100%|█████| 276/276 [00:19<00:00, 14.23batch/s, accuracy=41, loss=2.72]
# 	Train: Loss = 2.7199, Acc = 41.0152
# 	Valid: Loss = 3.3673, Acc = 28.4360
# 	Validation loss did not improve. Patience: 1/5
# ------------------------------------------------------------
# Epoch 5/7 | Current LR: 0.000389
# Epoch 5: 100%|█████| 276/276 [00:19<00:00, 14.13batch/s, accuracy=52, loss=2.34]
# 	Train: Loss = 2.3449, Acc = 52.0054
# 	Valid: Loss = 3.4577, Acc = 31.2796
# 	Validation loss did not improve. Patience: 2/5
# ------------------------------------------------------------
# Epoch 6/7 | Current LR: 0.000189
# Epoch 6: 100%|███| 276/276 [00:19<00:00, 14.28batch/s, accuracy=63.4, loss=1.98]
# 	Train: Loss = 1.9824, Acc = 63.3809
# 	Valid: Loss = 3.6308, Acc = 27.9621
# 	Validation loss did not improve. Patience: 3/5
# ------------------------------------------------------------
# Epoch 7/7 | Current LR: 0.000050
# Epoch 7: 100%|███| 276/276 [00:19<00:00, 14.19batch/s, accuracy=70.7, loss=1.77]
# 	Train: Loss = 1.7680, Acc = 70.7229
# 	Valid: Loss = 3.6164, Acc = 30.3318
# 	Validation loss did not improve. Patience: 4/5
# ------------------------------------------------------------
#
# ✅ Loaded best model based on validation accuracy for final testing. /kaggle/working/bac/.models/lstm_bert_model.pt
# Figure(1400x600)
#
# 🧪 Evaluating on Test Set...
#
# --- Test Set Results (Best Validation Model) ---
# 	Test Loss: 3.1542
# 	Test Accuracy (Top-1): 30.40%
# 	Test MRR: 0.4186
# {'loss_train_hist': [3.685541653978652, 3.350942525310793, 3.0407538578130198, 2.719864477713903, 2.3449491711630337, 1.982441113046978, 1.767997177614682], 'loss_valid_hist': [3.6246421677725658, 3.390077693121774, 3.264372910772051, 3.367335251399449, 3.4576672996793474, 3.63083587374006, 3.6164119243621826], 'acc_train_hist': [15.341037842737366, 24.971674597779288, 33.92250169952413, 41.0151824155903, 52.00543847722638, 63.38092000906413, 70.72286426467255], 'acc_valid_hist': [17.061611374407583, 24.644549763033176, 27.01421800947867, 28.436018957345972, 31.27962085308057, 27.96208530805687, 30.33175355450237], 'test_top_5_acc': 0.5320665083135392, 'test_top_10_acc': 0.665083135391924, 'test_loss_final': 3.1542386832060636, 'test_acc_top1_final': 30.40380047505938, 'test_mrr_final': 0.4185896137875951}

# %%
result_load_path = f"{os.getcwd()}/.result/lstm_bert_result.json"
plot_history(result_load_path, 7)

# %% [markdown]
# ## JDT dataset

# %%
# !python -m src.run_lstm -e bert -d jdt -ne 7 -rsw 0 -a 0 -b 0 -r 0 -hs 256 -l 2 -nah 1 -lam concat
# Out:
# 2025-07-12 17:11:23.864882: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752340283.888428    2920 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752340283.895204    2920 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Shape after dropping NA assignees: (1465, 5)
# Number of unique assignees (classes): 69
# Warning: Some classes have fewer than 2 samples (min_samples_per_class=1). Stratification for train/test split might not be possible or effective.
# ✅ Loading pre-saved augmented dataset from 'datasets/augmented_train_dataset_2_JDT.csv'.
# Using device: cuda
# Generating Full Embeddings: 100%|█████████████| 193/193 [01:03<00:00,  3.04it/s]
# Generating Full Embeddings: 100%|███████████████| 10/10 [00:02<00:00,  3.36it/s]
# Generating Full Embeddings: 100%|███████████████| 19/19 [00:06<00:00,  3.12it/s]
#
# DataLoaders created successfully!
# Training batches: 193
# Validation batches: 10
# Test batches: 19
# using bert embeddings
#
# ------
# lstm model info:
# {'total_parameters': 1816645, 'trainable_parameters': 1816645, 'model_size_mb': 6.929950714111328, 'config': LSTMConfig(input_size=768, hidden_size=256, num_layers=2, num_classes=69, dropout=0.4, bidirectional=False, use_attention=False, attention_heads=1, attention_dropout=0.1, layer_norm=True, residual_connections=0, gradient_clipping=1.0, luong_attention_method='concat'), 'is_bidirectional': False, 'uses_attention': False, 'attention_heads': 0}
# ------
#
# OPTIMIZER=SGD, LR=0.1
# Epoch 0: 100%|████| 193/193 [00:13<00:00, 14.24batch/s, accuracy=14.6, loss=3.4]
# OPTIMIZER=SGD, LR=0.01
# Epoch 0: 100%|███| 193/193 [00:13<00:00, 14.43batch/s, accuracy=15.2, loss=3.48]
# OPTIMIZER=SGD, LR=0.001
# Epoch 0: 100%|███| 193/193 [00:13<00:00, 14.36batch/s, accuracy=14.4, loss=4.03]
# OPTIMIZER=SGD, LR=0.0001
# Epoch 0: 100%|███| 193/193 [00:13<00:00, 14.59batch/s, accuracy=6.57, loss=4.21]
# OPTIMIZER=Adam, LR=0.1
# Epoch 0: 100%|███| 193/193 [00:13<00:00, 14.33batch/s, accuracy=14.6, loss=5.81]
# OPTIMIZER=Adam, LR=0.01
# Epoch 0: 100%|███| 193/193 [00:13<00:00, 14.05batch/s, accuracy=15.3, loss=3.38]
# OPTIMIZER=Adam, LR=0.001
# Epoch 0: 100%|███| 193/193 [00:13<00:00, 14.16batch/s, accuracy=17.1, loss=3.37]
# OPTIMIZER=Adam, LR=0.0001
# Epoch 0: 100%|███| 193/193 [00:13<00:00, 14.36batch/s, accuracy=14.1, loss=3.62]
# OPTIMIZER=Adamw, LR=0.1
# Epoch 0: 100%|███| 193/193 [00:13<00:00, 14.41batch/s, accuracy=15.8, loss=4.04]
# OPTIMIZER=Adamw, LR=0.01
# Epoch 0: 100%|█████| 193/193 [00:13<00:00, 14.40batch/s, accuracy=15, loss=3.39]
# OPTIMIZER=Adamw, LR=0.001
# Epoch 0: 100%|███| 193/193 [00:13<00:00, 14.11batch/s, accuracy=16.2, loss=3.39]
# OPTIMIZER=Adamw, LR=0.0001
# Epoch 0: 100%|███| 193/193 [00:13<00:00, 14.30batch/s, accuracy=13.7, loss=3.62]
# <class 'torch.optim.adam.Adam'> 0.001
#
# ✅ Start Training 7 epochs ...
# Epoch 1/7 | Current LR: 0.001000
# Epoch 1: 100%|█████| 193/193 [00:13<00:00, 14.04batch/s, accuracy=16, loss=3.39]
# 	Train: Loss = 3.3940, Acc = 16.0000
# 	Valid: Loss = 3.2143, Acc = 17.0068
# 	✨ New best validation loss: 3.2143
# ------------------------------------------------------------
# Epoch 2/7 | Current LR: 0.000951
# Epoch 2: 100%|███| 193/193 [00:13<00:00, 14.31batch/s, accuracy=21.1, loss=3.18]
# 	Train: Loss = 3.1757, Acc = 21.1382
# 	Valid: Loss = 3.2081, Acc = 14.9660
# 	✨ New best validation loss: 3.2081
# ------------------------------------------------------------
# Epoch 3/7 | Current LR: 0.000812
# Epoch 3: 100%|███| 193/193 [00:13<00:00, 14.22batch/s, accuracy=26.6, loss=2.99]
# 	Train: Loss = 2.9890, Acc = 26.6341
# 	Valid: Loss = 3.1721, Acc = 22.4490
# 	✨ New best validation loss: 3.1721
# ------------------------------------------------------------
# Epoch 4/7 | Current LR: 0.000612
# Epoch 4: 100%|███| 193/193 [00:13<00:00, 14.20batch/s, accuracy=34.1, loss=2.76]
# 	Train: Loss = 2.7574, Acc = 34.1463
# 	Valid: Loss = 3.2875, Acc = 25.1701
# 	Validation loss did not improve. Patience: 1/5
# ------------------------------------------------------------
# Epoch 5/7 | Current LR: 0.000389
# Epoch 5: 100%|████| 193/193 [00:13<00:00, 14.32batch/s, accuracy=42.2, loss=2.5]
# 	Train: Loss = 2.4955, Acc = 42.2114
# 	Valid: Loss = 3.4235, Acc = 18.3673
# 	Validation loss did not improve. Patience: 2/5
# ------------------------------------------------------------
# Epoch 6/7 | Current LR: 0.000189
# Epoch 6: 100%|████| 193/193 [00:13<00:00, 14.12batch/s, accuracy=53.7, loss=2.2]
# 	Train: Loss = 2.1960, Acc = 53.6911
# 	Valid: Loss = 3.5916, Acc = 22.4490
# 	Validation loss did not improve. Patience: 3/5
# ------------------------------------------------------------
# Epoch 7/7 | Current LR: 0.000050
# Epoch 7: 100%|███| 193/193 [00:13<00:00, 14.25batch/s, accuracy=62.1, loss=1.99]
# 	Train: Loss = 1.9898, Acc = 62.1463
# 	Valid: Loss = 3.6640, Acc = 19.0476
# 	Validation loss did not improve. Patience: 4/5
# ------------------------------------------------------------
#
# ✅ Loaded best model based on validation accuracy for final testing. /kaggle/working/bac/.models/lstm_bert_model.pt
# Figure(1400x600)
#
# 🧪 Evaluating on Test Set...
#
# --- Test Set Results (Best Validation Model) ---
# 	Test Loss: 3.2611
# 	Test Accuracy (Top-1): 20.48%
# 	Test MRR: 0.3739
# {'loss_train_hist': [3.394003522210788, 3.1757111537024145, 2.9889829615854846, 2.75738407169599, 2.495466528778867, 2.1960322473950953, 1.989776338320322], 'loss_valid_hist': [3.214290189743042, 3.2081409215927126, 3.1721319198608398, 3.287454628944397, 3.4235329389572144, 3.5915884017944335, 3.663995361328125], 'acc_train_hist': [16.0, 21.13821138211382, 26.634146341463413, 34.146341463414636, 42.21138211382114, 53.6910569105691, 62.146341463414636], 'acc_valid_hist': [17.006802721088434, 14.965986394557824, 22.448979591836736, 25.170068027210885, 18.367346938775512, 22.448979591836736, 19.047619047619047], 'test_top_5_acc': 0.5665529010238908, 'test_top_10_acc': 0.7952218430034129, 'test_loss_final': 3.2611156639299894, 'test_acc_top1_final': 20.477815699658702, 'test_mrr_final': 0.3738667071495872}

# %%
result_load_path = f"{os.getcwd()}/.result/lstm_bert_result.json"
plot_history(result_load_path, 7)
