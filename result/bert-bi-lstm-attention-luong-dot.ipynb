# %%
# %cd /kaggle/working
# !git clone https://github.com/AmirEspahbodi/bac.git
# Out:
# /kaggle/working
# fatal: destination path 'bac' already exists and is not an empty directory.

# %%
# !pip install bitsandbytes

# %%
# %cd /kaggle/working/bac
# !git pull
# !ls
# Out:
# /kaggle/working/bac
# Already up to date.
# datasets     poetry.lock     README.md	src
# inspiration  pyproject.toml  scripts	state.db

# %%
import os
import json
import matplotlib.pyplot as plt


def plot_history(result_load_path, NUM_EPOCHS):
    loss_train_hist = None
    loss_valid_hist = None
    acc_train_hist = None
    acc_valid_hist = None
    test_top_5_acc = None
    test_top_10_acc = None
    test_loss_final = None
    test_acc_top1_final = None
    test_mrr_final = None
        
    # Load the data from the JSON file
    try:
        with open(result_load_path, "r") as f:
            # json.load() reads the file and parses the JSON data into a Python dictionary
            loaded_results = json.load(f)
    
        # Unpack the dictionary values into your variables
        loss_train_hist = loaded_results.get("loss_train_hist")
        loss_valid_hist = loaded_results.get("loss_valid_hist")
        acc_train_hist = loaded_results.get("acc_train_hist")
        acc_valid_hist = loaded_results.get("acc_valid_hist")
        test_top_5_acc = loaded_results.get("test_top_5_acc")
        test_top_10_acc = loaded_results.get("test_top_10_acc")
        test_loss_final = loaded_results.get("test_loss_final")
        test_acc_top1_final = loaded_results.get("test_acc_top1_final")
        test_mrr_final = loaded_results.get("test_mrr_final")
    
    except FileNotFoundError:
        print(f"Error: The file at '{result_load_path}' was not found.")
    except json.JSONDecodeError:
        print(f"Error: The file at '{result_load_path}' is not a valid JSON file.")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")
    
    epochs_range = range(1, NUM_EPOCHS + 1)
    
    plt.figure(figsize=(14, 6))
    
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, loss_train_hist, "bo-", label="Training Loss")
    plt.plot(epochs_range, loss_valid_hist, "ro-", label="Validation Loss")
    plt.title("Training and Validation Loss")
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.legend()
    plt.grid(True)
    
    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, acc_train_hist, "bo-", label="Training Accuracy (Top-1)")
    plt.plot(epochs_range, acc_valid_hist, "ro-", label="Validation Accuracy (Top-1)")
    plt.title("Training and Validation Accuracy (Top-1)")
    plt.xlabel("Epochs")
    plt.ylabel("Accuracy")
    plt.legend()
    plt.grid(True)
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## GCC dataset

# %%
# !python -m src.run_lstm -e bert -d gcc -ne 7 -rsw 0 -a 1 -b 1 -r 0 -hs 256 -l 2 -nah 1 -lam dot
# Out:
# 2025-07-12 13:13:36.980428: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752326017.208084      70 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752326017.274395      70 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Shape after dropping NA assignees: (2103, 6)
# Number of unique assignees (classes): 82
# Warning: Some classes have fewer than 2 samples (min_samples_per_class=1). Stratification for train/test split might not be possible or effective.
# ✅ Loading pre-saved augmented dataset from 'datasets/augmented_train_dataset_2_GCC.csv'.
# tokenizer_config.json: 100%|██████████████████| 48.0/48.0 [00:00<00:00, 435kB/s]
# vocab.txt: 100%|█████████████████████████████| 232k/232k [00:00<00:00, 1.08MB/s]
# tokenizer.json: 100%|████████████████████████| 466k/466k [00:00<00:00, 4.58MB/s]
# config.json: 100%|█████████████████████████████| 570/570 [00:00<00:00, 6.02MB/s]
# Using device: cuda
# model.safetensors: 100%|██████████████████████| 440M/440M [00:01<00:00, 234MB/s]
# Generating Full Embeddings: 100%|█████████████| 276/276 [01:33<00:00,  2.95it/s]
# Generating Full Embeddings: 100%|███████████████| 14/14 [00:04<00:00,  3.10it/s]
# Generating Full Embeddings: 100%|███████████████| 27/27 [00:08<00:00,  3.05it/s]
#
# DataLoaders created successfully!
# Training batches: 276
# Validation batches: 14
# Test batches: 27
# using bert embeddings
#
# ------
# lstm model info:
# {'total_parameters': 4029522, 'trainable_parameters': 4029522, 'model_size_mb': 15.371406555175781, 'config': LSTMConfig(input_size=768, hidden_size=256, num_layers=2, num_classes=82, dropout=0.4, bidirectional=True, use_attention=True, attention_heads=1, attention_dropout=0.1, layer_norm=True, residual_connections=0, gradient_clipping=1.0, luong_attention_method='dot'), 'is_bidirectional': True, 'uses_attention': True, 'attention_heads': 1}
# ------
#
# OPTIMIZER=SGD, LR=0.1
# Epoch 0: 100%|███| 276/276 [00:30<00:00,  9.02batch/s, accuracy=12.3, loss=3.85]
# OPTIMIZER=SGD, LR=0.01
# Epoch 0: 100%|███| 276/276 [00:29<00:00,  9.39batch/s, accuracy=14.5, loss=3.82]
# OPTIMIZER=SGD, LR=0.001
# Epoch 0: 100%|███| 276/276 [00:29<00:00,  9.41batch/s, accuracy=11.4, loss=4.12]
# OPTIMIZER=SGD, LR=0.0001
# Epoch 0: 100%|███| 276/276 [00:29<00:00,  9.40batch/s, accuracy=1.74, loss=4.83]
# OPTIMIZER=Adam, LR=0.1
# Epoch 0: 100%|███| 276/276 [00:30<00:00,  9.13batch/s, accuracy=10.1, loss=9.41]
# OPTIMIZER=Adam, LR=0.01
# Epoch 0: 100%|███| 276/276 [00:30<00:00,  9.15batch/s, accuracy=11.8, loss=3.86]
# OPTIMIZER=Adam, LR=0.001
# Epoch 0: 100%|███| 276/276 [00:30<00:00,  9.13batch/s, accuracy=13.9, loss=3.75]
# OPTIMIZER=Adam, LR=0.0001
# Epoch 0: 100%|███| 276/276 [00:29<00:00,  9.27batch/s, accuracy=21.1, loss=3.67]
# OPTIMIZER=Adamw, LR=0.1
# Epoch 0: 100%|███| 276/276 [00:30<00:00,  9.12batch/s, accuracy=11.8, loss=5.38]
# OPTIMIZER=Adamw, LR=0.01
# Epoch 0: 100%|███| 276/276 [00:30<00:00,  9.14batch/s, accuracy=11.5, loss=3.84]
# OPTIMIZER=Adamw, LR=0.001
# Epoch 0: 100%|███| 276/276 [00:30<00:00,  9.13batch/s, accuracy=14.3, loss=3.74]
# OPTIMIZER=Adamw, LR=0.0001
# Epoch 0: 100%|███| 276/276 [00:29<00:00,  9.25batch/s, accuracy=20.6, loss=3.67]
# <class 'torch.optim.adam.Adam'> 0.0001
#
# ✅ Start Training 7 epochs ...
# Epoch 1/7 | Current LR: 0.000100
# Epoch 1: 100%|███| 276/276 [00:29<00:00,  9.22batch/s, accuracy=20.3, loss=3.67]
# 	Train: Loss = 3.6703, Acc = 20.3263
# 	Valid: Loss = 3.2982, Acc = 28.4360
# 	✨ New best validation loss: 3.2982
# ------------------------------------------------------------
# Epoch 2/7 | Current LR: 0.000095
# Epoch 2: 100%|███| 276/276 [00:29<00:00,  9.22batch/s, accuracy=35.2, loss=3.04]
# 	Train: Loss = 3.0365, Acc = 35.1688
# 	Valid: Loss = 3.0533, Acc = 37.9147
# 	✨ New best validation loss: 3.0533
# ------------------------------------------------------------
# Epoch 3/7 | Current LR: 0.000081
# Epoch 3: 100%|███| 276/276 [00:29<00:00,  9.21batch/s, accuracy=44.1, loss=2.66]
# 	Train: Loss = 2.6599, Acc = 44.1423
# 	Valid: Loss = 2.8997, Acc = 39.8104
# 	✨ New best validation loss: 2.8997
# ------------------------------------------------------------
# Epoch 4/7 | Current LR: 0.000062
# Epoch 4: 100%|███| 276/276 [00:29<00:00,  9.26batch/s, accuracy=52.9, loss=2.33]
# 	Train: Loss = 2.3298, Acc = 52.8665
# 	Valid: Loss = 2.8793, Acc = 41.2322
# 	✨ New best validation loss: 2.8793
# ------------------------------------------------------------
# Epoch 5/7 | Current LR: 0.000039
# Epoch 5: 100%|████| 276/276 [00:29<00:00,  9.22batch/s, accuracy=59.5, loss=2.1]
# 	Train: Loss = 2.0985, Acc = 59.4833
# 	Valid: Loss = 2.8269, Acc = 44.0758
# 	✨ New best validation loss: 2.8269
# ------------------------------------------------------------
# Epoch 6/7 | Current LR: 0.000020
# Epoch 6: 100%|█████| 276/276 [00:29<00:00,  9.24batch/s, accuracy=65, loss=1.92]
# 	Train: Loss = 1.9245, Acc = 65.0125
# 	Valid: Loss = 2.8195, Acc = 42.1801
# 	✨ New best validation loss: 2.8195
# ------------------------------------------------------------
# Epoch 7/7 | Current LR: 0.000006
# Epoch 7: 100%|█████| 276/276 [00:30<00:00,  9.17batch/s, accuracy=68, loss=1.84]
# 	Train: Loss = 1.8406, Acc = 67.9583
# 	Valid: Loss = 2.8279, Acc = 43.6019
# 	Validation loss did not improve. Patience: 1/5
# ------------------------------------------------------------
#
# ✅ Loaded best model based on validation accuracy for final testing. /kaggle/working/bac/.models/lstm_bert_model.pt
# Figure(1400x600)
#
# 🧪 Evaluating on Test Set...
#
# --- Test Set Results (Best Validation Model) ---
# 	Test Loss: 2.6837
# 	Test Accuracy (Top-1): 44.18%
# 	Test MRR: 0.5640
# {'loss_train_hist': [3.6702765260917554, 3.0364819622558095, 2.659892255845277, 2.3297622229741966, 2.0985042241172516, 1.924488769925159, 1.840584126935489], 'loss_valid_hist': [3.2981592416763306, 3.0532985585076466, 2.899724841117859, 2.879268544060843, 2.826944981302534, 2.8194836718695506, 2.827917763165065], 'acc_train_hist': [20.326308633582595, 35.16881939723544, 44.14230682075686, 52.86653070473601, 59.48334466349422, 65.0124631769771, 67.95830500793112], 'acc_valid_hist': [28.436018957345972, 37.91469194312796, 39.81042654028436, 41.23222748815166, 44.07582938388626, 42.18009478672986, 43.60189573459716], 'test_top_5_acc': 0.7007125890736342, 'test_top_10_acc': 0.8076009501187649, 'test_loss_final': 2.683650502452144, 'test_acc_top1_final': 44.180522565320665, 'test_mrr_final': 0.5639511635743241}

# %%
result_load_path = f"{os.getcwd()}/.result/lstm_bert_result.json"
plot_history(result_load_path, 7)

# %% [markdown]
# ## JDT dataset

# %%
# !python -m src.run_lstm -e bert -d jdt -ne 7 -rsw 0 -a 1 -b 1 -r 0 -hs 256 -l 2 -nah 1 -lam dot
# Out:
# 2025-07-12 13:25:39.453766: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752326739.477155     354 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752326739.483988     354 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Shape after dropping NA assignees: (1465, 5)
# Number of unique assignees (classes): 69
# Warning: Some classes have fewer than 2 samples (min_samples_per_class=1). Stratification for train/test split might not be possible or effective.
# ✅ Loading pre-saved augmented dataset from 'datasets/augmented_train_dataset_2_JDT.csv'.
# Using device: cuda
# Generating Full Embeddings: 100%|█████████████| 193/193 [01:04<00:00,  2.97it/s]
# Generating Full Embeddings: 100%|███████████████| 10/10 [00:03<00:00,  3.28it/s]
# Generating Full Embeddings: 100%|███████████████| 19/19 [00:06<00:00,  3.04it/s]
#
# DataLoaders created successfully!
# Training batches: 193
# Validation batches: 10
# Test batches: 19
# using bert embeddings
#
# ------
# lstm model info:
# {'total_parameters': 4026181, 'trainable_parameters': 4026181, 'model_size_mb': 15.358661651611328, 'config': LSTMConfig(input_size=768, hidden_size=256, num_layers=2, num_classes=69, dropout=0.4, bidirectional=True, use_attention=True, attention_heads=1, attention_dropout=0.1, layer_norm=True, residual_connections=0, gradient_clipping=1.0, luong_attention_method='dot'), 'is_bidirectional': True, 'uses_attention': True, 'attention_heads': 1}
# ------
#
# OPTIMIZER=SGD, LR=0.1
# Epoch 0: 100%|███| 193/193 [00:21<00:00,  8.96batch/s, accuracy=13.9, loss=3.64]
# OPTIMIZER=SGD, LR=0.01
# Epoch 0: 100%|█████| 193/193 [00:20<00:00,  9.19batch/s, accuracy=16, loss=3.52]
# OPTIMIZER=SGD, LR=0.001
# Epoch 0: 100%|████| 193/193 [00:20<00:00,  9.20batch/s, accuracy=12.5, loss=3.9]
# OPTIMIZER=SGD, LR=0.0001
# Epoch 0: 100%|███| 193/193 [00:20<00:00,  9.22batch/s, accuracy=2.28, loss=4.84]
# OPTIMIZER=Adam, LR=0.1
# Epoch 0: 100%|███| 193/193 [00:21<00:00,  9.01batch/s, accuracy=12.3, loss=9.35]
# OPTIMIZER=Adam, LR=0.01
# Epoch 0: 100%|████| 193/193 [00:21<00:00,  9.01batch/s, accuracy=14.4, loss=3.6]
# OPTIMIZER=Adam, LR=0.001
# Epoch 0: 100%|███| 193/193 [00:21<00:00,  8.97batch/s, accuracy=16.1, loss=3.45]
# OPTIMIZER=Adam, LR=0.0001
# Epoch 0: 100%|███| 193/193 [00:21<00:00,  9.17batch/s, accuracy=19.3, loss=3.47]
# OPTIMIZER=Adamw, LR=0.1
# Epoch 0: 100%|███| 193/193 [00:21<00:00,  9.09batch/s, accuracy=14.5, loss=7.77]
# OPTIMIZER=Adamw, LR=0.01
# Epoch 0: 100%|███| 193/193 [00:21<00:00,  9.04batch/s, accuracy=14.5, loss=3.63]
# OPTIMIZER=Adamw, LR=0.001
# Epoch 0: 100%|█████| 193/193 [00:21<00:00,  9.00batch/s, accuracy=16, loss=3.46]
# OPTIMIZER=Adamw, LR=0.0001
# Epoch 0: 100%|███| 193/193 [00:21<00:00,  9.15batch/s, accuracy=17.8, loss=3.49]
# <class 'torch.optim.adam.Adam'> 0.0001
#
# ✅ Start Training 7 epochs ...
# Epoch 1/7 | Current LR: 0.000100
# Epoch 1: 100%|███| 193/193 [00:21<00:00,  8.98batch/s, accuracy=18.4, loss=3.49]
# 	Train: Loss = 3.4939, Acc = 18.4065
# 	Valid: Loss = 3.1509, Acc = 19.7279
# 	✨ New best validation loss: 3.1509
# ------------------------------------------------------------
# Epoch 2/7 | Current LR: 0.000095
# Epoch 2: 100%|█████| 193/193 [00:21<00:00,  9.11batch/s, accuracy=27, loss=3.06]
# 	Train: Loss = 3.0632, Acc = 26.9593
# 	Valid: Loss = 2.9967, Acc = 29.2517
# 	✨ New best validation loss: 2.9967
# ------------------------------------------------------------
# Epoch 3/7 | Current LR: 0.000081
# Epoch 3: 100%|███| 193/193 [00:21<00:00,  9.13batch/s, accuracy=37.6, loss=2.73]
# 	Train: Loss = 2.7314, Acc = 37.6260
# 	Valid: Loss = 2.9680, Acc = 31.9728
# 	✨ New best validation loss: 2.9680
# ------------------------------------------------------------
# Epoch 4/7 | Current LR: 0.000062
# Epoch 4: 100%|███| 193/193 [00:21<00:00,  9.17batch/s, accuracy=45.1, loss=2.45]
# 	Train: Loss = 2.4451, Acc = 45.1057
# 	Valid: Loss = 2.9043, Acc = 31.2925
# 	✨ New best validation loss: 2.9043
# ------------------------------------------------------------
# Epoch 5/7 | Current LR: 0.000039
# Epoch 5: 100%|███| 193/193 [00:21<00:00,  9.13batch/s, accuracy=53.3, loss=2.18]
# 	Train: Loss = 2.1773, Acc = 53.3008
# 	Valid: Loss = 2.9432, Acc = 34.0136
# 	Validation loss did not improve. Patience: 1/5
# ------------------------------------------------------------
# Epoch 6/7 | Current LR: 0.000020
# Epoch 6: 100%|███| 193/193 [00:21<00:00,  9.13batch/s, accuracy=59.4, loss=2.01]
# 	Train: Loss = 2.0083, Acc = 59.3821
# 	Valid: Loss = 2.9259, Acc = 32.6531
# 	Validation loss did not improve. Patience: 2/5
# ------------------------------------------------------------
# Epoch 7/7 | Current LR: 0.000006
# Epoch 7: 100%|████| 193/193 [00:21<00:00,  9.08batch/s, accuracy=61.8, loss=1.9]
# 	Train: Loss = 1.9045, Acc = 61.7561
# 	Valid: Loss = 2.9180, Acc = 34.6939
# 	Validation loss did not improve. Patience: 3/5
# ------------------------------------------------------------
#
# ✅ Loaded best model based on validation accuracy for final testing. /kaggle/working/bac/.models/lstm_bert_model.pt
# Figure(1400x600)
#
# 🧪 Evaluating on Test Set...
#
# --- Test Set Results (Best Validation Model) ---
# 	Test Loss: 2.9498
# 	Test Accuracy (Top-1): 32.42%
# 	Test MRR: 0.4780
# {'loss_train_hist': [3.49392982962218, 3.0632279462764918, 2.7313813397303766, 2.4450739788885563, 2.177331673666603, 2.008300596568251, 1.90448364630882], 'loss_valid_hist': [3.1509330749511717, 2.9966925621032714, 2.9679776191711427, 2.9043063640594484, 2.9432163000106812, 2.9259047746658324, 2.917950487136841], 'acc_train_hist': [18.40650406504065, 26.959349593495936, 37.6260162601626, 45.10569105691057, 53.300813008130085, 59.38211382113821, 61.75609756097561], 'acc_valid_hist': [19.727891156462587, 29.25170068027211, 31.972789115646258, 31.292517006802722, 34.01360544217687, 32.6530612244898, 34.69387755102041], 'test_top_5_acc': 0.6689419795221843, 'test_top_10_acc': 0.8395904436860068, 'test_loss_final': 2.949803251969187, 'test_acc_top1_final': 32.42320819112628, 'test_mrr_final': 0.4779706256387729}

# %%
result_load_path = f"{os.getcwd()}/.result/lstm_bert_result.json"
plot_history(result_load_path, 7)
