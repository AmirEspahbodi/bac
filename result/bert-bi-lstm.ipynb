# %%
# %cd /kaggle/working
# !git clone https://github.com/AmirEspahbodi/bac.git
# Out:
# /kaggle/working
# fatal: destination path 'bac' already exists and is not an empty directory.

# %%
# !pip install bitsandbytes

# %%
# %cd /kaggle/working/bac
# !git pull
# !ls
# Out:
# /kaggle/working/bac
# Already up to date.
# datasets     poetry.lock     README.md	src
# inspiration  pyproject.toml  scripts	state.db

# %%
import os
import json
import matplotlib.pyplot as plt


def plot_history(result_load_path, NUM_EPOCHS):
    loss_train_hist = None
    loss_valid_hist = None
    acc_train_hist = None
    acc_valid_hist = None
    test_top_5_acc = None
    test_top_10_acc = None
    test_loss_final = None
    test_acc_top1_final = None
    test_mrr_final = None
        
    # Load the data from the JSON file
    try:
        with open(result_load_path, "r") as f:
            # json.load() reads the file and parses the JSON data into a Python dictionary
            loaded_results = json.load(f)
    
        # Unpack the dictionary values into your variables
        loss_train_hist = loaded_results.get("loss_train_hist")
        loss_valid_hist = loaded_results.get("loss_valid_hist")
        acc_train_hist = loaded_results.get("acc_train_hist")
        acc_valid_hist = loaded_results.get("acc_valid_hist")
        test_top_5_acc = loaded_results.get("test_top_5_acc")
        test_top_10_acc = loaded_results.get("test_top_10_acc")
        test_loss_final = loaded_results.get("test_loss_final")
        test_acc_top1_final = loaded_results.get("test_acc_top1_final")
        test_mrr_final = loaded_results.get("test_mrr_final")
    
    except FileNotFoundError:
        print(f"Error: The file at '{result_load_path}' was not found.")
    except json.JSONDecodeError:
        print(f"Error: The file at '{result_load_path}' is not a valid JSON file.")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")
    
    epochs_range = range(1, NUM_EPOCHS + 1)
    
    plt.figure(figsize=(14, 6))
    
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, loss_train_hist, "bo-", label="Training Loss")
    plt.plot(epochs_range, loss_valid_hist, "ro-", label="Validation Loss")
    plt.title("Training and Validation Loss")
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.legend()
    plt.grid(True)
    
    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, acc_train_hist, "bo-", label="Training Accuracy (Top-1)")
    plt.plot(epochs_range, acc_valid_hist, "ro-", label="Validation Accuracy (Top-1)")
    plt.title("Training and Validation Accuracy (Top-1)")
    plt.xlabel("Epochs")
    plt.ylabel("Accuracy")
    plt.legend()
    plt.grid(True)
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## GCC dataset

# %%
# !python -m src.run_lstm -e bert -d gcc -ne 7 -rsw 0 -a 0 -b 1 -r 0 -hs 256 -l 2 -nah 1 -lam concat
# Out:
# 2025-07-12 17:41:17.642645: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752342077.665759    3705 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752342077.672810    3705 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Shape after dropping NA assignees: (2103, 6)
# Number of unique assignees (classes): 82
# Warning: Some classes have fewer than 2 samples (min_samples_per_class=1). Stratification for train/test split might not be possible or effective.
# ✅ Loading pre-saved augmented dataset from 'datasets/augmented_train_dataset_2_GCC.csv'.
# Using device: cuda
# Generating Full Embeddings: 100%|█████████████| 276/276 [01:33<00:00,  2.97it/s]
# Generating Full Embeddings: 100%|███████████████| 14/14 [00:04<00:00,  3.12it/s]
# Generating Full Embeddings: 100%|███████████████| 27/27 [00:08<00:00,  3.14it/s]
#
# DataLoaders created successfully!
# Training batches: 276
# Validation batches: 14
# Test batches: 27
# using bert embeddings
#
# ------
# lstm model info:
# {'total_parameters': 4029522, 'trainable_parameters': 4029522, 'model_size_mb': 15.371406555175781, 'config': LSTMConfig(input_size=768, hidden_size=256, num_layers=2, num_classes=82, dropout=0.4, bidirectional=True, use_attention=False, attention_heads=1, attention_dropout=0.1, layer_norm=True, residual_connections=0, gradient_clipping=1.0, luong_attention_method='concat'), 'is_bidirectional': True, 'uses_attention': False, 'attention_heads': 0}
# ------
#
# OPTIMIZER=SGD, LR=0.1
# Epoch 0: 100%|█████| 276/276 [00:29<00:00,  9.23batch/s, accuracy=17, loss=3.59]
# OPTIMIZER=SGD, LR=0.01
# Epoch 0: 100%|███| 276/276 [00:29<00:00,  9.26batch/s, accuracy=12.9, loss=3.73]
# OPTIMIZER=SGD, LR=0.001
# Epoch 0: 100%|███| 276/276 [00:29<00:00,  9.39batch/s, accuracy=11.2, loss=4.13]
# OPTIMIZER=SGD, LR=0.0001
# Epoch 0: 100%|███| 276/276 [00:29<00:00,  9.30batch/s, accuracy=4.19, loss=4.38]
# OPTIMIZER=Adam, LR=0.1
# Epoch 0: 100%|███| 276/276 [00:30<00:00,  9.10batch/s, accuracy=9.74, loss=6.25]
# OPTIMIZER=Adam, LR=0.01
# Epoch 0: 100%|███| 276/276 [00:30<00:00,  9.10batch/s, accuracy=12.4, loss=3.73]
# OPTIMIZER=Adam, LR=0.001
# Epoch 0: 100%|███| 276/276 [00:30<00:00,  9.16batch/s, accuracy=21.4, loss=3.46]
# OPTIMIZER=Adam, LR=0.0001
# Epoch 0: 100%|██████| 276/276 [00:29<00:00,  9.22batch/s, accuracy=16, loss=3.7]
# OPTIMIZER=Adamw, LR=0.1
# Epoch 0: 100%|███| 276/276 [00:29<00:00,  9.22batch/s, accuracy=12.6, loss=4.75]
# OPTIMIZER=Adamw, LR=0.01
# Epoch 0: 100%|███| 276/276 [00:30<00:00,  9.16batch/s, accuracy=12.1, loss=3.71]
# OPTIMIZER=Adamw, LR=0.001
# Epoch 0: 100%|████| 276/276 [00:30<00:00,  9.15batch/s, accuracy=22.7, loss=3.4]
# OPTIMIZER=Adamw, LR=0.0001
# Epoch 0: 100%|████| 276/276 [00:30<00:00,  9.13batch/s, accuracy=16.2, loss=3.7]
# <class 'torch.optim.adamw.AdamW'> 0.001
#
# ✅ Start Training 7 epochs ...
# Epoch 1/7 | Current LR: 0.001000
# Epoch 1: 100%|███| 276/276 [00:30<00:00,  9.18batch/s, accuracy=21.9, loss=3.45]
# 	Train: Loss = 3.4539, Acc = 21.9125
# 	Valid: Loss = 3.3744, Acc = 25.1185
# 	✨ New best validation loss: 3.3744
# ------------------------------------------------------------
# Epoch 2/7 | Current LR: 0.000951
# Epoch 2: 100%|███| 276/276 [00:30<00:00,  9.11batch/s, accuracy=38.8, loss=2.81]
# 	Train: Loss = 2.8139, Acc = 38.8398
# 	Valid: Loss = 3.0475, Acc = 33.6493
# 	✨ New best validation loss: 3.0475
# ------------------------------------------------------------
# Epoch 3/7 | Current LR: 0.000812
# Epoch 3: 100%|███| 276/276 [00:30<00:00,  8.99batch/s, accuracy=53.7, loss=2.26]
# 	Train: Loss = 2.2623, Acc = 53.6596
# 	Valid: Loss = 2.8891, Acc = 39.8104
# 	✨ New best validation loss: 2.8891
# ------------------------------------------------------------
# Epoch 4/7 | Current LR: 0.000612
# Epoch 4: 100%|███| 276/276 [00:30<00:00,  9.16batch/s, accuracy=71.9, loss=1.69]
# 	Train: Loss = 1.6924, Acc = 71.8559
# 	Valid: Loss = 3.0133, Acc = 38.3886
# 	Validation loss did not improve. Patience: 1/5
# ------------------------------------------------------------
# Epoch 5/7 | Current LR: 0.000389
# Epoch 5: 100%|███| 276/276 [00:30<00:00,  9.10batch/s, accuracy=89.5, loss=1.22]
# 	Train: Loss = 1.2153, Acc = 89.4856
# 	Valid: Loss = 2.9352, Acc = 38.8626
# 	Validation loss did not improve. Patience: 2/5
# ------------------------------------------------------------
# Epoch 6/7 | Current LR: 0.000189
# Epoch 6: 100%|██| 276/276 [00:30<00:00,  9.14batch/s, accuracy=97.6, loss=0.997]
# 	Train: Loss = 0.9968, Acc = 97.6433
# 	Valid: Loss = 3.0264, Acc = 40.2844
# 	Validation loss did not improve. Patience: 3/5
# ------------------------------------------------------------
# Epoch 7/7 | Current LR: 0.000050
# Epoch 7: 100%|██| 276/276 [00:30<00:00,  9.11batch/s, accuracy=99.4, loss=0.929]
# 	Train: Loss = 0.9289, Acc = 99.3655
# 	Valid: Loss = 2.9969, Acc = 41.2322
# 	Validation loss did not improve. Patience: 4/5
# ------------------------------------------------------------
#
# ✅ Loaded best model based on validation accuracy for final testing. /kaggle/working/bac/.models/lstm_bert_model.pt
# Figure(1400x600)
#
# 🧪 Evaluating on Test Set...
#
# --- Test Set Results (Best Validation Model) ---
# 	Test Loss: 2.8118
# 	Test Accuracy (Top-1): 39.67%
# 	Test MRR: 0.5263
# {'loss_train_hist': [3.453942741172901, 2.813912822716478, 2.262330494065216, 1.692441179268602, 1.2153386601071428, 0.9967685013577559, 0.9289441747941832], 'loss_valid_hist': [3.3743930544172014, 3.047483648572649, 2.889088068689619, 3.0133398600987027, 2.9351977791104997, 3.026433535984584, 2.9968745538166592], 'acc_train_hist': [21.912531157942443, 38.83979152503966, 53.65964196691593, 71.85588035350102, 89.48561069567188, 97.6433265352368, 99.36551099025606], 'acc_valid_hist': [25.118483412322274, 33.649289099526065, 39.81042654028436, 38.388625592417064, 38.86255924170616, 40.28436018957346, 41.23222748815166], 'test_top_5_acc': 0.66270783847981, 'test_top_10_acc': 0.7862232779097387, 'test_loss_final': 2.811815138216372, 'test_acc_top1_final': 39.66745843230404, 'test_mrr_final': 0.5262802677546494}

# %%
result_load_path = f"{os.getcwd()}/.result/lstm_bert_result.json"
plot_history(result_load_path, 7)

# %% [markdown]
# ## JDT dataset

# %%
# !python -m src.run_lstm -e bert -d jdt -ne 7 -rsw 0 -a 0 -b 1 -r 0 -hs 256 -l 2 -nah 1 -lam concat
# Out:
# 2025-07-12 17:53:07.976964: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752342788.000681    3954 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752342788.007829    3954 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Shape after dropping NA assignees: (1465, 5)
# Number of unique assignees (classes): 69
# Warning: Some classes have fewer than 2 samples (min_samples_per_class=1). Stratification for train/test split might not be possible or effective.
# ✅ Loading pre-saved augmented dataset from 'datasets/augmented_train_dataset_2_JDT.csv'.
# Using device: cuda
# Generating Full Embeddings: 100%|█████████████| 193/193 [01:03<00:00,  3.04it/s]
# Generating Full Embeddings: 100%|███████████████| 10/10 [00:02<00:00,  3.34it/s]
# Generating Full Embeddings: 100%|███████████████| 19/19 [00:06<00:00,  3.08it/s]
#
# DataLoaders created successfully!
# Training batches: 193
# Validation batches: 10
# Test batches: 19
# using bert embeddings
#
# ------
# lstm model info:
# {'total_parameters': 4026181, 'trainable_parameters': 4026181, 'model_size_mb': 15.358661651611328, 'config': LSTMConfig(input_size=768, hidden_size=256, num_layers=2, num_classes=69, dropout=0.4, bidirectional=True, use_attention=False, attention_heads=1, attention_dropout=0.1, layer_norm=True, residual_connections=0, gradient_clipping=1.0, luong_attention_method='concat'), 'is_bidirectional': True, 'uses_attention': False, 'attention_heads': 0}
# ------
#
# OPTIMIZER=SGD, LR=0.1
# Epoch 0: 100%|███| 193/193 [00:21<00:00,  9.08batch/s, accuracy=23.8, loss=3.16]
# OPTIMIZER=SGD, LR=0.01
# Epoch 0: 100%|███| 193/193 [00:21<00:00,  9.18batch/s, accuracy=18.3, loss=3.39]
# OPTIMIZER=SGD, LR=0.001
# Epoch 0: 100%|███| 193/193 [00:20<00:00,  9.21batch/s, accuracy=14.3, loss=3.98]
# OPTIMIZER=SGD, LR=0.0001
# Epoch 0: 100%|███| 193/193 [00:20<00:00,  9.27batch/s, accuracy=1.92, loss=4.22]
# OPTIMIZER=Adam, LR=0.1
# Epoch 0: 100%|███| 193/193 [00:21<00:00,  9.09batch/s, accuracy=14.1, loss=5.49]
# OPTIMIZER=Adam, LR=0.01
# Epoch 0: 100%|███| 193/193 [00:21<00:00,  9.05batch/s, accuracy=17.8, loss=3.35]
# OPTIMIZER=Adam, LR=0.001
# Epoch 0: 100%|███| 193/193 [00:21<00:00,  9.07batch/s, accuracy=27.5, loss=3.05]
# OPTIMIZER=Adam, LR=0.0001
# Epoch 0: 100%|███| 193/193 [00:21<00:00,  9.10batch/s, accuracy=20.2, loss=3.39]
# OPTIMIZER=Adamw, LR=0.1
# Epoch 0: 100%|███| 193/193 [00:21<00:00,  9.08batch/s, accuracy=15.6, loss=4.68]
# OPTIMIZER=Adamw, LR=0.01
# Epoch 0: 100%|███| 193/193 [00:21<00:00,  9.11batch/s, accuracy=15.1, loss=3.44]
# OPTIMIZER=Adamw, LR=0.001
# Epoch 0: 100%|███| 193/193 [00:21<00:00,  9.10batch/s, accuracy=26.4, loss=3.12]
# OPTIMIZER=Adamw, LR=0.0001
# Epoch 0: 100%|███| 193/193 [00:21<00:00,  9.12batch/s, accuracy=20.4, loss=3.39]
# <class 'torch.optim.adam.Adam'> 0.001
#
# ✅ Start Training 7 epochs ...
# Epoch 1/7 | Current LR: 0.001000
# Epoch 1: 100%|███| 193/193 [00:21<00:00,  9.06batch/s, accuracy=26.3, loss=3.11]
# 	Train: Loss = 3.1117, Acc = 26.3089
# 	Valid: Loss = 2.8792, Acc = 25.8503
# 	✨ New best validation loss: 2.8792
# ------------------------------------------------------------
# Epoch 2/7 | Current LR: 0.000951
# Epoch 2: 100%|███| 193/193 [00:21<00:00,  9.12batch/s, accuracy=39.5, loss=2.59]
# 	Train: Loss = 2.5941, Acc = 39.4797
# 	Valid: Loss = 2.7574, Acc = 34.6939
# 	✨ New best validation loss: 2.7574
# ------------------------------------------------------------
# Epoch 3/7 | Current LR: 0.000812
# Epoch 3: 100%|█████| 193/193 [00:21<00:00,  9.10batch/s, accuracy=56, loss=2.12]
# 	Train: Loss = 2.1166, Acc = 55.9675
# 	Valid: Loss = 2.7242, Acc = 34.0136
# 	✨ New best validation loss: 2.7242
# ------------------------------------------------------------
# Epoch 4/7 | Current LR: 0.000612
# Epoch 4: 100%|███| 193/193 [00:21<00:00,  9.10batch/s, accuracy=72.2, loss=1.62]
# 	Train: Loss = 1.6218, Acc = 72.1626
# 	Valid: Loss = 3.0804, Acc = 36.7347
# 	Validation loss did not improve. Patience: 1/5
# ------------------------------------------------------------
# Epoch 5/7 | Current LR: 0.000389
# Epoch 5: 100%|███| 193/193 [00:21<00:00,  9.10batch/s, accuracy=85.6, loss=1.26]
# 	Train: Loss = 1.2577, Acc = 85.5935
# 	Valid: Loss = 3.2616, Acc = 30.6122
# 	Validation loss did not improve. Patience: 2/5
# ------------------------------------------------------------
# Epoch 6/7 | Current LR: 0.000189
# Epoch 6: 100%|███| 193/193 [00:21<00:00,  9.05batch/s, accuracy=94.8, loss=1.04]
# 	Train: Loss = 1.0408, Acc = 94.7642
# 	Valid: Loss = 3.4108, Acc = 31.9728
# 	Validation loss did not improve. Patience: 3/5
# ------------------------------------------------------------
# Epoch 7/7 | Current LR: 0.000050
# Epoch 7: 100%|██| 193/193 [00:21<00:00,  9.05batch/s, accuracy=98.4, loss=0.938]
# 	Train: Loss = 0.9381, Acc = 98.4390
# 	Valid: Loss = 3.4015, Acc = 31.9728
# 	Validation loss did not improve. Patience: 4/5
# ------------------------------------------------------------
#
# ✅ Loaded best model based on validation accuracy for final testing. /kaggle/working/bac/.models/lstm_bert_model.pt
# Figure(1400x600)
#
# 🧪 Evaluating on Test Set...
#
# --- Test Set Results (Best Validation Model) ---
# 	Test Loss: 2.9046
# 	Test Accuracy (Top-1): 34.13%
# 	Test MRR: 0.5026
# {'loss_train_hist': [3.1117249103407785, 2.594139876760967, 2.116552334375332, 1.6217726734635745, 1.257746737238039, 1.040750113484773, 0.9380979028390479], 'loss_valid_hist': [2.8792185544967652, 2.7574007749557494, 2.7241886377334597, 3.0804316282272337, 3.2616469860076904, 3.4108166217803957, 3.4014508962631225], 'acc_train_hist': [26.308943089430894, 39.479674796747965, 55.96747967479675, 72.16260162601625, 85.59349593495935, 94.76422764227642, 98.4390243902439], 'acc_valid_hist': [25.85034013605442, 34.69387755102041, 34.01360544217687, 36.734693877551024, 30.612244897959183, 31.972789115646258, 31.972789115646258], 'test_top_5_acc': 0.6996587030716723, 'test_top_10_acc': 0.8327645051194539, 'test_loss_final': 2.9046097931108976, 'test_acc_top1_final': 34.129692832764505, 'test_mrr_final': 0.5025926990268346}

# %%
result_load_path = f"{os.getcwd()}/.result/lstm_bert_result.json"
plot_history(result_load_path, 7)
