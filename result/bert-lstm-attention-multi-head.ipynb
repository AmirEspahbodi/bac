# %%
# %cd /kaggle/working
# !git clone https://github.com/AmirEspahbodi/bac.git
# Out:
# /kaggle/working
# fatal: destination path 'bac' already exists and is not an empty directory.

# %%
# %cd /kaggle/working/bac
# !git pull
# !ls
# Out:
# /kaggle/working/bac
# Already up to date.
# datasets     poetry.lock     README.md	src
# inspiration  pyproject.toml  scripts	state.db

# %%
import os
import json
import matplotlib.pyplot as plt


def plot_history(result_load_path, NUM_EPOCHS):
    loss_train_hist = None
    loss_valid_hist = None
    acc_train_hist = None
    acc_valid_hist = None
    test_top_5_acc = None
    test_top_10_acc = None
    test_loss_final = None
    test_acc_top1_final = None
    test_mrr_final = None
        
    # Load the data from the JSON file
    try:
        with open(result_load_path, "r") as f:
            # json.load() reads the file and parses the JSON data into a Python dictionary
            loaded_results = json.load(f)
    
        # Unpack the dictionary values into your variables
        loss_train_hist = loaded_results.get("loss_train_hist")
        loss_valid_hist = loaded_results.get("loss_valid_hist")
        acc_train_hist = loaded_results.get("acc_train_hist")
        acc_valid_hist = loaded_results.get("acc_valid_hist")
        test_top_5_acc = loaded_results.get("test_top_5_acc")
        test_top_10_acc = loaded_results.get("test_top_10_acc")
        test_loss_final = loaded_results.get("test_loss_final")
        test_acc_top1_final = loaded_results.get("test_acc_top1_final")
        test_mrr_final = loaded_results.get("test_mrr_final")
    
    except FileNotFoundError:
        print(f"Error: The file at '{result_load_path}' was not found.")
    except json.JSONDecodeError:
        print(f"Error: The file at '{result_load_path}' is not a valid JSON file.")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")
    
    epochs_range = range(1, NUM_EPOCHS + 1)
    
    plt.figure(figsize=(14, 6))
    
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, loss_train_hist, "bo-", label="Training Loss")
    plt.plot(epochs_range, loss_valid_hist, "ro-", label="Validation Loss")
    plt.title("Training and Validation Loss")
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.legend()
    plt.grid(True)
    
    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, acc_train_hist, "bo-", label="Training Accuracy (Top-1)")
    plt.plot(epochs_range, acc_valid_hist, "ro-", label="Validation Accuracy (Top-1)")
    plt.title("Training and Validation Accuracy (Top-1)")
    plt.xlabel("Epochs")
    plt.ylabel("Accuracy")
    plt.legend()
    plt.grid(True)
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## GCC dataset

# %%
# !python -m src.run_lstm -e bert -d gcc -ne 7 -rsw 0 -a 1 -b 0 -r 0 -hs 256 -l 2 -nah 8 -lam dot
# Out:
# 2025-07-12 14:12:40.090449: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752329560.114173    1125 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752329560.121509    1125 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Shape after dropping NA assignees: (2103, 6)
# Number of unique assignees (classes): 82
# Warning: Some classes have fewer than 2 samples (min_samples_per_class=1). Stratification for train/test split might not be possible or effective.
# ✅ Loading pre-saved augmented dataset from 'datasets/augmented_train_dataset_2_GCC.csv'.
# Using device: cuda
# Generating Full Embeddings: 100%|█████████████| 276/276 [01:33<00:00,  2.95it/s]
# Generating Full Embeddings: 100%|███████████████| 14/14 [00:04<00:00,  3.10it/s]
# Generating Full Embeddings: 100%|███████████████| 27/27 [00:08<00:00,  3.09it/s]
#
# DataLoaders created successfully!
# Training batches: 276
# Validation batches: 14
# Test batches: 27
# using bert embeddings
#
# ------
# lstm model info:
# {'total_parameters': 2081490, 'trainable_parameters': 2081490, 'model_size_mb': 7.940254211425781, 'config': LSTMConfig(input_size=768, hidden_size=256, num_layers=2, num_classes=82, dropout=0.4, bidirectional=False, use_attention=True, attention_heads=8, attention_dropout=0.1, layer_norm=True, residual_connections=0, gradient_clipping=1.0, luong_attention_method='dot'), 'is_bidirectional': False, 'uses_attention': True, 'attention_heads': 8}
# ------
#
# OPTIMIZER=SGD, LR=0.1
# Epoch 0: 100%|████| 276/276 [00:19<00:00, 13.92batch/s, accuracy=11.9, loss=3.8]
# OPTIMIZER=SGD, LR=0.01
# Epoch 0: 100%|███| 276/276 [00:19<00:00, 14.23batch/s, accuracy=12.6, loss=3.86]
# OPTIMIZER=SGD, LR=0.001
# Epoch 0: 100%|███| 276/276 [00:19<00:00, 14.36batch/s, accuracy=9.56, loss=4.15]
# OPTIMIZER=SGD, LR=0.0001
# Epoch 0: 100%|████| 276/276 [00:19<00:00, 14.28batch/s, accuracy=2.56, loss=4.6]
# OPTIMIZER=Adam, LR=0.1
# Epoch 0: 100%|███| 276/276 [00:19<00:00, 14.13batch/s, accuracy=11.1, loss=5.96]
# OPTIMIZER=Adam, LR=0.01
# Epoch 0: 100%|███| 276/276 [00:19<00:00, 13.98batch/s, accuracy=11.2, loss=3.86]
# OPTIMIZER=Adam, LR=0.001
# Epoch 0: 100%|███| 276/276 [00:19<00:00, 14.15batch/s, accuracy=12.5, loss=3.82]
# OPTIMIZER=Adam, LR=0.0001
# Epoch 0: 100%|███| 276/276 [00:19<00:00, 14.40batch/s, accuracy=17.3, loss=3.85]
# OPTIMIZER=Adamw, LR=0.1
# Epoch 0: 100%|█████| 276/276 [00:19<00:00, 14.12batch/s, accuracy=12, loss=6.32]
# OPTIMIZER=Adamw, LR=0.01
# Epoch 0: 100%|████| 276/276 [00:19<00:00, 14.11batch/s, accuracy=12.2, loss=3.8]
# OPTIMIZER=Adamw, LR=0.001
# Epoch 0: 100%|███| 276/276 [00:19<00:00, 13.92batch/s, accuracy=11.1, loss=3.84]
# OPTIMIZER=Adamw, LR=0.0001
# Epoch 0: 100%|███| 276/276 [00:19<00:00, 14.37batch/s, accuracy=17.8, loss=3.83]
# <class 'torch.optim.adamw.AdamW'> 0.0001
#
# ✅ Start Training 7 epochs ...
# Epoch 1/7 | Current LR: 0.000100
# Epoch 1: 100%|███| 276/276 [00:19<00:00, 14.06batch/s, accuracy=17.3, loss=3.85]
# 	Train: Loss = 3.8458, Acc = 17.2898
# 	Valid: Loss = 3.4950, Acc = 23.6967
# 	✨ New best validation loss: 3.4950
# ------------------------------------------------------------
# Epoch 2/7 | Current LR: 0.000095
# Epoch 2: 100%|███| 276/276 [00:19<00:00, 14.27batch/s, accuracy=32.5, loss=3.22]
# 	Train: Loss = 3.2231, Acc = 32.5176
# 	Valid: Loss = 3.1184, Acc = 36.4929
# 	✨ New best validation loss: 3.1184
# ------------------------------------------------------------
# Epoch 3/7 | Current LR: 0.000081
# Epoch 3: 100%|███| 276/276 [00:19<00:00, 14.17batch/s, accuracy=39.7, loss=2.91]
# 	Train: Loss = 2.9090, Acc = 39.7009
# 	Valid: Loss = 2.9639, Acc = 38.8626
# 	✨ New best validation loss: 2.9639
# ------------------------------------------------------------
# Epoch 4/7 | Current LR: 0.000062
# Epoch 4: 100%|███| 276/276 [00:19<00:00, 14.26batch/s, accuracy=45.7, loss=2.65]
# 	Train: Loss = 2.6508, Acc = 45.7059
# 	Valid: Loss = 2.9233, Acc = 40.7583
# 	✨ New best validation loss: 2.9233
# ------------------------------------------------------------
# Epoch 5/7 | Current LR: 0.000039
# Epoch 5: 100%|███| 276/276 [00:19<00:00, 14.30batch/s, accuracy=51.1, loss=2.45]
# 	Train: Loss = 2.4492, Acc = 51.1217
# 	Valid: Loss = 2.8636, Acc = 43.1280
# 	✨ New best validation loss: 2.8636
# ------------------------------------------------------------
# Epoch 6/7 | Current LR: 0.000020
# Epoch 6: 100%|████| 276/276 [00:19<00:00, 14.39batch/s, accuracy=54.7, loss=2.3]
# 	Train: Loss = 2.2990, Acc = 54.6567
# 	Valid: Loss = 2.8555, Acc = 42.1801
# 	✨ New best validation loss: 2.8555
# ------------------------------------------------------------
# Epoch 7/7 | Current LR: 0.000006
# Epoch 7: 100%|███| 276/276 [00:19<00:00, 14.28batch/s, accuracy=57.1, loss=2.22]
# 	Train: Loss = 2.2244, Acc = 57.1493
# 	Valid: Loss = 2.8466, Acc = 43.6019
# 	✨ New best validation loss: 2.8466
# ------------------------------------------------------------
#
# ✅ Loaded best model based on validation accuracy for final testing. /kaggle/working/bac/.models/lstm_bert_model.pt
# Figure(1400x600)
#
# 🧪 Evaluating on Test Set...
#
# --- Test Set Results (Best Validation Model) ---
# 	Test Loss: 2.7654
# 	Test Accuracy (Top-1): 43.94%
# 	Test MRR: 0.5595
# {'loss_train_hist': [3.845755083837371, 3.223100775393887, 2.909005290356235, 2.6507711691268976, 2.449214875266172, 2.2990335718445154, 2.224414333485175], 'loss_valid_hist': [3.494971070970808, 3.1183539628982544, 2.963869946343558, 2.9232700211661204, 2.8635829516819546, 2.8555277415684293, 2.846637725830078], 'acc_train_hist': [17.28982551552232, 32.51756174937684, 39.70088375254929, 45.70586902334013, 51.12168592794018, 54.65669612508498, 57.149331520507594], 'acc_valid_hist': [23.696682464454977, 36.492890995260666, 38.86255924170616, 40.758293838862556, 43.127962085308056, 42.18009478672986, 43.60189573459716], 'test_top_5_acc': 0.6935866983372921, 'test_top_10_acc': 0.7814726840855107, 'test_loss_final': 2.7654396251395896, 'test_acc_top1_final': 43.942992874109265, 'test_mrr_final': 0.5594900036842658}

# %%
result_load_path = f"{os.getcwd()}/.result/lstm_bert_result.json"
plot_history(result_load_path, 7)

# %% [markdown]
# ## JDT dataset

# %%
# !python -m src.run_lstm -e bert -d jdt -ne 7 -rsw 0 -a 1 -b 0 -r 0 -hs 256 -l 2 -nah 8 -lam dot
# Out:
# 2025-07-12 14:21:04.529319: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752330064.551623    1374 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752330064.558882    1374 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Shape after dropping NA assignees: (1465, 5)
# Number of unique assignees (classes): 69
# Warning: Some classes have fewer than 2 samples (min_samples_per_class=1). Stratification for train/test split might not be possible or effective.
# ✅ Loading pre-saved augmented dataset from 'datasets/augmented_train_dataset_2_JDT.csv'.
# Using device: cuda
# Generating Full Embeddings: 100%|█████████████| 193/193 [01:04<00:00,  3.00it/s]
# Generating Full Embeddings: 100%|███████████████| 10/10 [00:03<00:00,  3.27it/s]
# Generating Full Embeddings: 100%|███████████████| 19/19 [00:06<00:00,  3.08it/s]
#
# DataLoaders created successfully!
# Training batches: 193
# Validation batches: 10
# Test batches: 19
# using bert embeddings
#
# ------
# lstm model info:
# {'total_parameters': 2079813, 'trainable_parameters': 2079813, 'model_size_mb': 7.933856964111328, 'config': LSTMConfig(input_size=768, hidden_size=256, num_layers=2, num_classes=69, dropout=0.4, bidirectional=False, use_attention=True, attention_heads=8, attention_dropout=0.1, layer_norm=True, residual_connections=0, gradient_clipping=1.0, luong_attention_method='dot'), 'is_bidirectional': False, 'uses_attention': True, 'attention_heads': 8}
# ------
#
# OPTIMIZER=SGD, LR=0.1
# Epoch 0: 100%|███| 193/193 [00:14<00:00, 13.65batch/s, accuracy=14.4, loss=3.61]
# OPTIMIZER=SGD, LR=0.01
# Epoch 0: 100%|███| 193/193 [00:13<00:00, 14.11batch/s, accuracy=14.5, loss=3.58]
# OPTIMIZER=SGD, LR=0.001
# Epoch 0: 100%|███| 193/193 [00:13<00:00, 14.33batch/s, accuracy=10.9, loss=3.91]
# OPTIMIZER=SGD, LR=0.0001
# Epoch 0: 100%|███| 193/193 [00:13<00:00, 14.22batch/s, accuracy=2.63, loss=4.54]
# OPTIMIZER=Adam, LR=0.1
# Epoch 0: 100%|███| 193/193 [00:13<00:00, 13.91batch/s, accuracy=14.4, loss=7.84]
# OPTIMIZER=Adam, LR=0.01
# Epoch 0: 100%|███| 193/193 [00:13<00:00, 13.92batch/s, accuracy=14.9, loss=3.57]
# OPTIMIZER=Adam, LR=0.001
# Epoch 0: 100%|████| 193/193 [00:13<00:00, 13.86batch/s, accuracy=15.3, loss=3.5]
# OPTIMIZER=Adam, LR=0.0001
# Epoch 0: 100%|███| 193/193 [00:13<00:00, 14.19batch/s, accuracy=16.6, loss=3.59]
# OPTIMIZER=Adamw, LR=0.1
# Epoch 0: 100%|█████| 193/193 [00:13<00:00, 14.16batch/s, accuracy=16, loss=4.74]
# OPTIMIZER=Adamw, LR=0.01
# Epoch 0: 100%|███| 193/193 [00:13<00:00, 14.17batch/s, accuracy=15.1, loss=3.53]
# OPTIMIZER=Adamw, LR=0.001
# Epoch 0: 100%|███| 193/193 [00:13<00:00, 13.94batch/s, accuracy=15.3, loss=3.52]
# OPTIMIZER=Adamw, LR=0.0001
# Epoch 0: 100%|█████| 193/193 [00:13<00:00, 14.07batch/s, accuracy=17, loss=3.57]
# <class 'torch.optim.adamw.AdamW'> 0.0001
#
# ✅ Start Training 7 epochs ...
# Epoch 1/7 | Current LR: 0.000100
# Epoch 1: 100%|████| 193/193 [00:13<00:00, 14.15batch/s, accuracy=16.6, loss=3.6]
# 	Train: Loss = 3.5982, Acc = 16.6179
# 	Valid: Loss = 3.2788, Acc = 20.4082
# 	✨ New best validation loss: 3.2788
# ------------------------------------------------------------
# Epoch 2/7 | Current LR: 0.000095
# Epoch 2: 100%|███| 193/193 [00:13<00:00, 14.16batch/s, accuracy=25.7, loss=3.25]
# 	Train: Loss = 3.2508, Acc = 25.6585
# 	Valid: Loss = 3.1242, Acc = 25.1701
# 	✨ New best validation loss: 3.1242
# ------------------------------------------------------------
# Epoch 3/7 | Current LR: 0.000081
# Epoch 3: 100%|███| 193/193 [00:13<00:00, 14.25batch/s, accuracy=32.8, loss=2.96]
# 	Train: Loss = 2.9588, Acc = 32.7805
# 	Valid: Loss = 3.0346, Acc = 29.2517
# 	✨ New best validation loss: 3.0346
# ------------------------------------------------------------
# Epoch 4/7 | Current LR: 0.000062
# Epoch 4: 100%|███| 193/193 [00:13<00:00, 14.22batch/s, accuracy=39.2, loss=2.74]
# 	Train: Loss = 2.7381, Acc = 39.1545
# 	Valid: Loss = 3.0164, Acc = 33.3333
# 	✨ New best validation loss: 3.0164
# ------------------------------------------------------------
# Epoch 5/7 | Current LR: 0.000039
# Epoch 5: 100%|███| 193/193 [00:13<00:00, 14.37batch/s, accuracy=45.2, loss=2.52]
# 	Train: Loss = 2.5233, Acc = 45.1707
# 	Valid: Loss = 3.1023, Acc = 30.6122
# 	Validation loss did not improve. Patience: 1/5
# ------------------------------------------------------------
# Epoch 6/7 | Current LR: 0.000020
# Epoch 6: 100%|███| 193/193 [00:13<00:00, 14.19batch/s, accuracy=47.9, loss=2.41]
# 	Train: Loss = 2.4143, Acc = 47.8699
# 	Valid: Loss = 3.0533, Acc = 28.5714
# 	Validation loss did not improve. Patience: 2/5
# ------------------------------------------------------------
# Epoch 7/7 | Current LR: 0.000006
# Epoch 7: 100%|███| 193/193 [00:13<00:00, 14.30batch/s, accuracy=51.4, loss=2.32]
# 	Train: Loss = 2.3165, Acc = 51.4146
# 	Valid: Loss = 3.0723, Acc = 29.9320
# 	Validation loss did not improve. Patience: 3/5
# ------------------------------------------------------------
#
# ✅ Loaded best model based on validation accuracy for final testing. /kaggle/working/bac/.models/lstm_bert_model.pt
# Figure(1400x600)
#
# 🧪 Evaluating on Test Set...
#
# --- Test Set Results (Best Validation Model) ---
# 	Test Loss: 3.0607
# 	Test Accuracy (Top-1): 29.35%
# 	Test MRR: 0.4479
# {'loss_train_hist': [3.5981660160993667, 3.250816787462778, 2.9587706605387476, 2.7381300543256373, 2.523333084397983, 2.4143437468326154, 2.3165121646742746], 'loss_valid_hist': [3.2788031339645385, 3.1241790056228638, 3.0345648288726808, 3.0164068698883058, 3.1023404121398928, 3.0532715797424315, 3.0723425149917603], 'acc_train_hist': [16.617886178861788, 25.658536585365855, 32.78048780487805, 39.15447154471545, 45.170731707317074, 47.86991869918699, 51.41463414634146], 'acc_valid_hist': [20.408163265306122, 25.170068027210885, 29.25170068027211, 33.333333333333336, 30.612244897959183, 28.571428571428573, 29.931972789115648], 'test_top_5_acc': 0.6552901023890785, 'test_top_10_acc': 0.7849829351535836, 'test_loss_final': 3.060700592241789, 'test_acc_top1_final': 29.351535836177476, 'test_mrr_final': 0.447871985016756}

# %%
result_load_path = f"{os.getcwd()}/.result/lstm_bert_result.json"
plot_history(result_load_path, 7)
