# %%
# %cd /kaggle/working
# !git clone https://github.com/AmirEspahbodi/bac.git
# Out:
# /kaggle/working
# fatal: destination path 'bac' already exists and is not an empty directory.

# %%
# %cd /kaggle/working/bac
# !git pull
# !ls
# Out:
# /kaggle/working/bac
# Already up to date.
# datasets     poetry.lock     README.md	src
# inspiration  pyproject.toml  scripts	state.db

# %%
import os
import json
import matplotlib.pyplot as plt


def plot_history(result_load_path, NUM_EPOCHS):
    loss_train_hist = None
    loss_valid_hist = None
    acc_train_hist = None
    acc_valid_hist = None
    test_top_5_acc = None
    test_top_10_acc = None
    test_loss_final = None
    test_acc_top1_final = None
    test_mrr_final = None
        
    # Load the data from the JSON file
    try:
        with open(result_load_path, "r") as f:
            # json.load() reads the file and parses the JSON data into a Python dictionary
            loaded_results = json.load(f)
    
        # Unpack the dictionary values into your variables
        loss_train_hist = loaded_results.get("loss_train_hist")
        loss_valid_hist = loaded_results.get("loss_valid_hist")
        acc_train_hist = loaded_results.get("acc_train_hist")
        acc_valid_hist = loaded_results.get("acc_valid_hist")
        test_top_5_acc = loaded_results.get("test_top_5_acc")
        test_top_10_acc = loaded_results.get("test_top_10_acc")
        test_loss_final = loaded_results.get("test_loss_final")
        test_acc_top1_final = loaded_results.get("test_acc_top1_final")
        test_mrr_final = loaded_results.get("test_mrr_final")
    
    except FileNotFoundError:
        print(f"Error: The file at '{result_load_path}' was not found.")
    except json.JSONDecodeError:
        print(f"Error: The file at '{result_load_path}' is not a valid JSON file.")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")
    
    epochs_range = range(1, NUM_EPOCHS + 1)
    
    plt.figure(figsize=(14, 6))
    
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, loss_train_hist, "bo-", label="Training Loss")
    plt.plot(epochs_range, loss_valid_hist, "ro-", label="Validation Loss")
    plt.title("Training and Validation Loss")
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.legend()
    plt.grid(True)
    
    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, acc_train_hist, "bo-", label="Training Accuracy (Top-1)")
    plt.plot(epochs_range, acc_valid_hist, "ro-", label="Validation Accuracy (Top-1)")
    plt.title("Training and Validation Accuracy (Top-1)")
    plt.xlabel("Epochs")
    plt.ylabel("Accuracy")
    plt.legend()
    plt.grid(True)
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## GCC dataset

# %%
# !python -m src.run_lstm -e bert -d gcc -ne 7 -rsw 0 -a 1 -b 0 -r 0 -hs 256 -l 2 -nah 1 -lam concat
# Out:
# 2025-07-12 16:46:37.116793: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752338797.138998    2159 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752338797.146530    2159 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Shape after dropping NA assignees: (2103, 6)
# Number of unique assignees (classes): 82
# Warning: Some classes have fewer than 2 samples (min_samples_per_class=1). Stratification for train/test split might not be possible or effective.
# ✅ Loading pre-saved augmented dataset from 'datasets/augmented_train_dataset_2_GCC.csv'.
# Using device: cuda
# Generating Full Embeddings: 100%|█████████████| 276/276 [01:32<00:00,  2.97it/s]
# Generating Full Embeddings: 100%|███████████████| 14/14 [00:04<00:00,  3.14it/s]
# Generating Full Embeddings: 100%|███████████████| 27/27 [00:08<00:00,  3.07it/s]
#
# DataLoaders created successfully!
# Training batches: 276
# Validation batches: 14
# Test batches: 27
# using bert embeddings
#
# ------
# lstm model info:
# {'total_parameters': 1949650, 'trainable_parameters': 1949650, 'model_size_mb': 7.437324523925781, 'config': LSTMConfig(input_size=768, hidden_size=256, num_layers=2, num_classes=82, dropout=0.4, bidirectional=False, use_attention=True, attention_heads=1, attention_dropout=0.1, layer_norm=True, residual_connections=0, gradient_clipping=1.0, luong_attention_method='concat'), 'is_bidirectional': False, 'uses_attention': True, 'attention_heads': 1}
# ------
#
# OPTIMIZER=SGD, LR=0.1
# Epoch 0: 100%|███| 276/276 [00:19<00:00, 13.87batch/s, accuracy=12.3, loss=3.81]
# OPTIMIZER=SGD, LR=0.01
# Epoch 0: 100%|███| 276/276 [00:19<00:00, 14.21batch/s, accuracy=13.5, loss=3.84]
# OPTIMIZER=SGD, LR=0.001
# Epoch 0: 100%|███| 276/276 [00:19<00:00, 14.24batch/s, accuracy=9.13, loss=4.16]
# OPTIMIZER=SGD, LR=0.0001
# Epoch 0: 100%|███| 276/276 [00:19<00:00, 14.25batch/s, accuracy=2.61, loss=4.73]
# OPTIMIZER=Adam, LR=0.1
# Epoch 0: 100%|███| 276/276 [00:19<00:00, 13.92batch/s, accuracy=11.9, loss=4.57]
# OPTIMIZER=Adam, LR=0.01
# Epoch 0: 100%|███| 276/276 [00:19<00:00, 13.92batch/s, accuracy=12.1, loss=3.79]
# OPTIMIZER=Adam, LR=0.001
# Epoch 0: 100%|███| 276/276 [00:19<00:00, 14.06batch/s, accuracy=14.5, loss=3.75]
# OPTIMIZER=Adam, LR=0.0001
# Epoch 0: 100%|███| 276/276 [00:19<00:00, 14.01batch/s, accuracy=20.3, loss=3.77]
# OPTIMIZER=Adamw, LR=0.1
# Epoch 0: 100%|███| 276/276 [00:19<00:00, 14.13batch/s, accuracy=12.7, loss=4.16]
# OPTIMIZER=Adamw, LR=0.01
# Epoch 0: 100%|███| 276/276 [00:19<00:00, 14.10batch/s, accuracy=12.1, loss=3.78]
# OPTIMIZER=Adamw, LR=0.001
# Epoch 0: 100%|███| 276/276 [00:19<00:00, 13.97batch/s, accuracy=15.6, loss=3.74]
# OPTIMIZER=Adamw, LR=0.0001
# Epoch 0: 100%|███| 276/276 [00:19<00:00, 14.18batch/s, accuracy=20.1, loss=3.77]
# <class 'torch.optim.adam.Adam'> 0.0001
#
# ✅ Start Training 7 epochs ...
# Epoch 1/7 | Current LR: 0.000100
# Epoch 1: 100%|███| 276/276 [00:19<00:00, 14.10batch/s, accuracy=19.4, loss=3.79]
# 	Train: Loss = 3.7901, Acc = 19.3746
# 	Valid: Loss = 3.3441, Acc = 28.9100
# 	✨ New best validation loss: 3.3441
# ------------------------------------------------------------
# Epoch 2/7 | Current LR: 0.000095
# Epoch 2: 100%|█████| 276/276 [00:19<00:00, 14.16batch/s, accuracy=36, loss=3.14]
# 	Train: Loss = 3.1377, Acc = 36.0299
# 	Valid: Loss = 3.0014, Acc = 37.9147
# 	✨ New best validation loss: 3.0014
# ------------------------------------------------------------
# Epoch 3/7 | Current LR: 0.000081
# Epoch 3: 100%|███| 276/276 [00:19<00:00, 14.00batch/s, accuracy=44.3, loss=2.76]
# 	Train: Loss = 2.7562, Acc = 44.2783
# 	Valid: Loss = 2.8920, Acc = 40.2844
# 	✨ New best validation loss: 2.8920
# ------------------------------------------------------------
# Epoch 4/7 | Current LR: 0.000062
# Epoch 4: 100%|███| 276/276 [00:19<00:00, 14.13batch/s, accuracy=50.9, loss=2.47]
# 	Train: Loss = 2.4659, Acc = 50.8724
# 	Valid: Loss = 2.8135, Acc = 43.1280
# 	✨ New best validation loss: 2.8135
# ------------------------------------------------------------
# Epoch 5/7 | Current LR: 0.000039
# Epoch 5: 100%|███| 276/276 [00:19<00:00, 14.22batch/s, accuracy=56.7, loss=2.28]
# 	Train: Loss = 2.2816, Acc = 56.6735
# 	Valid: Loss = 2.8034, Acc = 44.0758
# 	✨ New best validation loss: 2.8034
# ------------------------------------------------------------
# Epoch 6/7 | Current LR: 0.000020
# Epoch 6: 100%|███| 276/276 [00:19<00:00, 14.12batch/s, accuracy=60.4, loss=2.14]
# 	Train: Loss = 2.1352, Acc = 60.4124
# 	Valid: Loss = 2.7740, Acc = 45.4976
# 	✨ New best validation loss: 2.7740
# ------------------------------------------------------------
# Epoch 7/7 | Current LR: 0.000006
# Epoch 7: 100%|█████| 276/276 [00:19<00:00, 14.13batch/s, accuracy=62, loss=2.08]
# 	Train: Loss = 2.0755, Acc = 61.9986
# 	Valid: Loss = 2.7457, Acc = 47.3934
# 	✨ New best validation loss: 2.7457
# ------------------------------------------------------------
#
# ✅ Loaded best model based on validation accuracy for final testing. /kaggle/working/bac/.models/lstm_bert_model.pt
# Figure(1400x600)
#
# 🧪 Evaluating on Test Set...
#
# --- Test Set Results (Best Validation Model) ---
# 	Test Loss: 2.5456
# 	Test Accuracy (Top-1): 49.88%
# 	Test MRR: 0.6069
# {'loss_train_hist': [3.790131981822028, 3.137659513432047, 2.756217192048612, 2.465880590936412, 2.281604567731636, 2.1351942048556563, 2.0755185204139655], 'loss_valid_hist': [3.3440839563097273, 3.001413038798741, 2.8920350585665022, 2.8135172639574324, 2.803408537592207, 2.7739855902535573, 2.7457080568586076], 'acc_train_hist': [19.37457511896669, 36.02991162474507, 44.27826875141627, 50.872422388397915, 56.67346476319964, 60.41241785633356, 61.99864038069341], 'acc_valid_hist': [28.90995260663507, 37.91469194312796, 40.28436018957346, 43.127962085308056, 44.07582938388626, 45.497630331753555, 47.39336492890995], 'test_top_5_acc': 0.7339667458432304, 'test_top_10_acc': 0.8123515439429929, 'test_loss_final': 2.545579605632358, 'test_acc_top1_final': 49.8812351543943, 'test_mrr_final': 0.6069435266835952}

# %%
result_load_path = f"{os.getcwd()}/.result/lstm_bert_result.json"
plot_history(result_load_path, 7)

# %% [markdown]
# ## JDT dataset

# %%
# !python -m src.run_lstm -e bert -d jdt -ne 7 -rsw 0 -a 1 -b 0 -r 0 -hs 256 -l 2 -nah 1 -lam concat
# Out:
# 2025-07-12 16:55:04.586461: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752339304.609418    2408 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752339304.616436    2408 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Shape after dropping NA assignees: (1465, 5)
# Number of unique assignees (classes): 69
# Warning: Some classes have fewer than 2 samples (min_samples_per_class=1). Stratification for train/test split might not be possible or effective.
# ✅ Loading pre-saved augmented dataset from 'datasets/augmented_train_dataset_2_JDT.csv'.
# Using device: cuda
# Generating Full Embeddings: 100%|█████████████| 193/193 [01:03<00:00,  3.04it/s]
# Generating Full Embeddings: 100%|███████████████| 10/10 [00:03<00:00,  3.31it/s]
# Generating Full Embeddings: 100%|███████████████| 19/19 [00:06<00:00,  3.14it/s]
#
# DataLoaders created successfully!
# Training batches: 193
# Validation batches: 10
# Test batches: 19
# using bert embeddings
#
# ------
# lstm model info:
# {'total_parameters': 1947973, 'trainable_parameters': 1947973, 'model_size_mb': 7.430927276611328, 'config': LSTMConfig(input_size=768, hidden_size=256, num_layers=2, num_classes=69, dropout=0.4, bidirectional=False, use_attention=True, attention_heads=1, attention_dropout=0.1, layer_norm=True, residual_connections=0, gradient_clipping=1.0, luong_attention_method='concat'), 'is_bidirectional': False, 'uses_attention': True, 'attention_heads': 1}
# ------
#
# OPTIMIZER=SGD, LR=0.1
# Epoch 0: 100%|███| 193/193 [00:14<00:00, 13.58batch/s, accuracy=13.4, loss=3.59]
# OPTIMIZER=SGD, LR=0.01
# Epoch 0: 100%|██████| 193/193 [00:13<00:00, 14.16batch/s, accuracy=15, loss=3.6]
# OPTIMIZER=SGD, LR=0.001
# Epoch 0: 100%|███| 193/193 [00:13<00:00, 14.30batch/s, accuracy=10.9, loss=3.96]
# OPTIMIZER=SGD, LR=0.0001
# Epoch 0: 100%|███| 193/193 [00:13<00:00, 14.18batch/s, accuracy=3.38, loss=4.48]
# OPTIMIZER=Adam, LR=0.1
# Epoch 0: 100%|████| 193/193 [00:13<00:00, 13.81batch/s, accuracy=14.5, loss=5.8]
# OPTIMIZER=Adam, LR=0.01
# Epoch 0: 100%|█████| 193/193 [00:13<00:00, 13.95batch/s, accuracy=14, loss=3.51]
# OPTIMIZER=Adam, LR=0.001
# Epoch 0: 100%|███| 193/193 [00:13<00:00, 13.96batch/s, accuracy=17.8, loss=3.47]
# OPTIMIZER=Adam, LR=0.0001
# Epoch 0: 100%|███| 193/193 [00:13<00:00, 14.14batch/s, accuracy=17.1, loss=3.64]
# OPTIMIZER=Adamw, LR=0.1
# Epoch 0: 100%|███| 193/193 [00:13<00:00, 14.02batch/s, accuracy=16.4, loss=3.91]
# OPTIMIZER=Adamw, LR=0.01
# Epoch 0: 100%|████| 193/193 [00:13<00:00, 13.83batch/s, accuracy=14.8, loss=3.5]
# OPTIMIZER=Adamw, LR=0.001
# Epoch 0: 100%|███| 193/193 [00:13<00:00, 13.82batch/s, accuracy=16.7, loss=3.48]
# OPTIMIZER=Adamw, LR=0.0001
# Epoch 0: 100%|███| 193/193 [00:13<00:00, 14.11batch/s, accuracy=17.7, loss=3.62]
# <class 'torch.optim.adam.Adam'> 0.001
#
# ✅ Start Training 7 epochs ...
# Epoch 1/7 | Current LR: 0.001000
# Epoch 1: 100%|███| 193/193 [00:14<00:00, 13.71batch/s, accuracy=16.3, loss=3.51]
# 	Train: Loss = 3.5089, Acc = 16.2927
# 	Valid: Loss = 3.2216, Acc = 20.4082
# 	✨ New best validation loss: 3.2216
# ------------------------------------------------------------
# Epoch 2/7 | Current LR: 0.000951
# Epoch 2: 100%|███| 193/193 [00:13<00:00, 13.94batch/s, accuracy=25.5, loss=3.14]
# 	Train: Loss = 3.1385, Acc = 25.4959
# 	Valid: Loss = 2.9801, Acc = 24.4898
# 	✨ New best validation loss: 2.9801
# ------------------------------------------------------------
# Epoch 3/7 | Current LR: 0.000812
# Epoch 3: 100%|███| 193/193 [00:13<00:00, 13.84batch/s, accuracy=31.9, loss=2.94]
# 	Train: Loss = 2.9353, Acc = 31.8699
# 	Valid: Loss = 2.9953, Acc = 29.9320
# 	Validation loss did not improve. Patience: 1/5
# ------------------------------------------------------------
# Epoch 4/7 | Current LR: 0.000612
# Epoch 4: 100%|███| 193/193 [00:13<00:00, 13.89batch/s, accuracy=37.1, loss=2.73]
# 	Train: Loss = 2.7333, Acc = 37.1057
# 	Valid: Loss = 2.7197, Acc = 31.2925
# 	✨ New best validation loss: 2.7197
# ------------------------------------------------------------
# Epoch 5/7 | Current LR: 0.000389
# Epoch 5: 100%|████| 193/193 [00:13<00:00, 13.96batch/s, accuracy=44.9, loss=2.5]
# 	Train: Loss = 2.4997, Acc = 44.9106
# 	Valid: Loss = 2.7358, Acc = 34.6939
# 	Validation loss did not improve. Patience: 1/5
# ------------------------------------------------------------
# Epoch 6/7 | Current LR: 0.000189
# Epoch 6: 100%|███| 193/193 [00:13<00:00, 13.91batch/s, accuracy=51.8, loss=2.27]
# 	Train: Loss = 2.2660, Acc = 51.8049
# 	Valid: Loss = 2.7753, Acc = 35.3741
# 	Validation loss did not improve. Patience: 2/5
# ------------------------------------------------------------
# Epoch 7/7 | Current LR: 0.000050
# Epoch 7: 100%|███| 193/193 [00:13<00:00, 13.90batch/s, accuracy=57.6, loss=2.09]
# 	Train: Loss = 2.0921, Acc = 57.6260
# 	Valid: Loss = 2.8051, Acc = 39.4558
# 	Validation loss did not improve. Patience: 3/5
# ------------------------------------------------------------
#
# ✅ Loaded best model based on validation accuracy for final testing. /kaggle/working/bac/.models/lstm_bert_model.pt
# Figure(1400x600)
#
# 🧪 Evaluating on Test Set...
#
# --- Test Set Results (Best Validation Model) ---
# 	Test Loss: 2.9255
# 	Test Accuracy (Top-1): 33.11%
# 	Test MRR: 0.4909
# {'loss_train_hist': [3.5089187177351717, 3.138519928245347, 2.9353236497375015, 2.7333069144135314, 2.49969375998245, 2.2659664969370157, 2.092125912404431], 'loss_valid_hist': [3.2215744733810423, 2.980122375488281, 2.9953091382980346, 2.719741415977478, 2.735815477371216, 2.775315022468567, 2.8050943851470946], 'acc_train_hist': [16.29268292682927, 25.495934959349594, 31.869918699186993, 37.10569105691057, 44.91056910569106, 51.80487804878049, 57.6260162601626], 'acc_valid_hist': [20.408163265306122, 24.489795918367346, 29.931972789115648, 31.292517006802722, 34.69387755102041, 35.374149659863946, 39.45578231292517], 'test_top_5_acc': 0.7030716723549488, 'test_top_10_acc': 0.8430034129692833, 'test_loss_final': 2.925537247406809, 'test_acc_top1_final': 33.10580204778157, 'test_mrr_final': 0.4908657573015941}

# %%
result_load_path = f"{os.getcwd()}/.result/lstm_bert_result.json"
plot_history(result_load_path, 7)
