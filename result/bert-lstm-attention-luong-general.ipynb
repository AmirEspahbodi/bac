# %%
# %cd /kaggle/working
# !git clone https://github.com/AmirEspahbodi/bac.git
# Out:
# /kaggle/working
# fatal: destination path 'bac' already exists and is not an empty directory.

# %%
import os
from kaggle_secrets import UserSecretsClient
from huggingface_hub import login

# --- Hugging Face Authentication ---
try:
    user_secrets = UserSecretsClient()
    HUGGING_FACE_TOKEN = user_secrets.get_secret("HUGGING_FACE_TOKEN")
    # Ensure the token is set as an environment variable for transformers
    os.environ["HUGGING_FACE_HUB_TOKEN"] = HUGGING_FACE_TOKEN
    # Log in to Hugging Face Hub
    login(token=hf_token)
    print("✅ Successfully authenticated with Hugging Face.")
except Exception as e:
    print(f"⚠️ Could not authenticate with Hugging Face. Make sure the 'HUGGING_FACE_TOKEN' secret is set. Error: {e}")

# %%
# !pip install bitsandbytes

# %%
# %cd /kaggle/working/bac
# !git pull
# !ls
# Out:
# /kaggle/working/bac
# Already up to date.
# datasets     poetry.lock     README.md	src
# inspiration  pyproject.toml  scripts	state.db

# %%
import os
import json
import matplotlib.pyplot as plt


def plot_history(result_load_path, NUM_EPOCHS):
    loss_train_hist = None
    loss_valid_hist = None
    acc_train_hist = None
    acc_valid_hist = None
    test_top_5_acc = None
    test_top_10_acc = None
    test_loss_final = None
    test_acc_top1_final = None
    test_mrr_final = None
        
    # Load the data from the JSON file
    try:
        with open(result_load_path, "r") as f:
            # json.load() reads the file and parses the JSON data into a Python dictionary
            loaded_results = json.load(f)
    
        # Unpack the dictionary values into your variables
        loss_train_hist = loaded_results.get("loss_train_hist")
        loss_valid_hist = loaded_results.get("loss_valid_hist")
        acc_train_hist = loaded_results.get("acc_train_hist")
        acc_valid_hist = loaded_results.get("acc_valid_hist")
        test_top_5_acc = loaded_results.get("test_top_5_acc")
        test_top_10_acc = loaded_results.get("test_top_10_acc")
        test_loss_final = loaded_results.get("test_loss_final")
        test_acc_top1_final = loaded_results.get("test_acc_top1_final")
        test_mrr_final = loaded_results.get("test_mrr_final")
    
    except FileNotFoundError:
        print(f"Error: The file at '{result_load_path}' was not found.")
    except json.JSONDecodeError:
        print(f"Error: The file at '{result_load_path}' is not a valid JSON file.")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")
    
    epochs_range = range(1, NUM_EPOCHS + 1)
    
    plt.figure(figsize=(14, 6))
    
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, loss_train_hist, "bo-", label="Training Loss")
    plt.plot(epochs_range, loss_valid_hist, "ro-", label="Validation Loss")
    plt.title("Training and Validation Loss")
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.legend()
    plt.grid(True)
    
    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, acc_train_hist, "bo-", label="Training Accuracy (Top-1)")
    plt.plot(epochs_range, acc_valid_hist, "ro-", label="Validation Accuracy (Top-1)")
    plt.title("Training and Validation Accuracy (Top-1)")
    plt.xlabel("Epochs")
    plt.ylabel("Accuracy")
    plt.legend()
    plt.grid(True)
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## GCC dataset

# %%
# !python -m src.run_lstm -e bert -d gcc -ne 7 -rsw 0 -a 1 -b 0 -r 0 -hs 256 -l 2 -nah 1 -lam general
# Out:
# 2025-07-12 16:26:08.475147: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752337568.498042    1647 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752337568.504911    1647 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Shape after dropping NA assignees: (2103, 6)
# Number of unique assignees (classes): 82
# Warning: Some classes have fewer than 2 samples (min_samples_per_class=1). Stratification for train/test split might not be possible or effective.
# ✅ Loading pre-saved augmented dataset from 'datasets/augmented_train_dataset_2_GCC.csv'.
# Using device: cuda
# Generating Full Embeddings: 100%|█████████████| 276/276 [01:32<00:00,  2.98it/s]
# Generating Full Embeddings: 100%|███████████████| 14/14 [00:04<00:00,  3.08it/s]
# Generating Full Embeddings: 100%|███████████████| 27/27 [00:08<00:00,  3.02it/s]
#
# DataLoaders created successfully!
# Training batches: 276
# Validation batches: 14
# Test batches: 27
# using bert embeddings
#
# ------
# lstm model info:
# {'total_parameters': 1883858, 'trainable_parameters': 1883858, 'model_size_mb': 7.186347961425781, 'config': LSTMConfig(input_size=768, hidden_size=256, num_layers=2, num_classes=82, dropout=0.4, bidirectional=False, use_attention=True, attention_heads=1, attention_dropout=0.1, layer_norm=True, residual_connections=0, gradient_clipping=1.0, luong_attention_method='general'), 'is_bidirectional': False, 'uses_attention': True, 'attention_heads': 1}
# ------
#
# OPTIMIZER=SGD, LR=0.1
# Epoch 0: 100%|███| 276/276 [00:19<00:00, 14.12batch/s, accuracy=11.1, loss=3.84]
# OPTIMIZER=SGD, LR=0.01
# Epoch 0: 100%|███| 276/276 [00:19<00:00, 14.52batch/s, accuracy=13.2, loss=3.85]
# OPTIMIZER=SGD, LR=0.001
# Epoch 0: 100%|███| 276/276 [00:18<00:00, 14.62batch/s, accuracy=10.4, loss=4.12]
# OPTIMIZER=SGD, LR=0.0001
# Epoch 0: 100%|███| 276/276 [00:18<00:00, 14.53batch/s, accuracy=3.38, loss=4.67]
# OPTIMIZER=Adam, LR=0.1
# Epoch 0: 100%|███| 276/276 [00:19<00:00, 14.21batch/s, accuracy=12.9, loss=4.32]
# OPTIMIZER=Adam, LR=0.01
# Epoch 0: 100%|███| 276/276 [00:19<00:00, 14.33batch/s, accuracy=12.6, loss=3.79]
# OPTIMIZER=Adam, LR=0.001
# Epoch 0: 100%|█████| 276/276 [00:19<00:00, 14.35batch/s, accuracy=17, loss=3.69]
# OPTIMIZER=Adam, LR=0.0001
# Epoch 0: 100%|███| 276/276 [00:18<00:00, 14.63batch/s, accuracy=17.5, loss=3.79]
# OPTIMIZER=Adamw, LR=0.1
# Epoch 0: 100%|███| 276/276 [00:19<00:00, 14.18batch/s, accuracy=12.4, loss=4.18]
# OPTIMIZER=Adamw, LR=0.01
# Epoch 0: 100%|███| 276/276 [00:19<00:00, 14.34batch/s, accuracy=12.4, loss=3.79]
# OPTIMIZER=Adamw, LR=0.001
# Epoch 0: 100%|███| 276/276 [00:19<00:00, 14.31batch/s, accuracy=12.8, loss=3.79]
# OPTIMIZER=Adamw, LR=0.0001
# Epoch 0: 100%|███| 276/276 [00:18<00:00, 14.59batch/s, accuracy=17.7, loss=3.82]
# <class 'torch.optim.adamw.AdamW'> 0.0001
#
# ✅ Start Training 7 epochs ...
# Epoch 1/7 | Current LR: 0.000100
# Epoch 1: 100%|████| 276/276 [00:18<00:00, 14.65batch/s, accuracy=17.8, loss=3.8]
# 	Train: Loss = 3.8014, Acc = 17.8337
# 	Valid: Loss = 3.4268, Acc = 27.0142
# 	✨ New best validation loss: 3.4268
# ------------------------------------------------------------
# Epoch 2/7 | Current LR: 0.000095
# Epoch 2: 100%|███| 276/276 [00:18<00:00, 14.72batch/s, accuracy=32.8, loss=3.22]
# 	Train: Loss = 3.2155, Acc = 32.8348
# 	Valid: Loss = 3.1215, Acc = 33.1754
# 	✨ New best validation loss: 3.1215
# ------------------------------------------------------------
# Epoch 3/7 | Current LR: 0.000081
# Epoch 3: 100%|████| 276/276 [00:19<00:00, 14.44batch/s, accuracy=39.7, loss=2.9]
# 	Train: Loss = 2.8979, Acc = 39.7462
# 	Valid: Loss = 2.9420, Acc = 36.9668
# 	✨ New best validation loss: 2.9420
# ------------------------------------------------------------
# Epoch 4/7 | Current LR: 0.000062
# Epoch 4: 100%|███| 276/276 [00:18<00:00, 14.64batch/s, accuracy=45.7, loss=2.66]
# 	Train: Loss = 2.6565, Acc = 45.6605
# 	Valid: Loss = 2.8557, Acc = 37.4408
# 	✨ New best validation loss: 2.8557
# ------------------------------------------------------------
# Epoch 5/7 | Current LR: 0.000039
# Epoch 5: 100%|███| 276/276 [00:18<00:00, 14.60batch/s, accuracy=49.7, loss=2.47]
# 	Train: Loss = 2.4675, Acc = 49.7167
# 	Valid: Loss = 2.7890, Acc = 40.7583
# 	✨ New best validation loss: 2.7890
# ------------------------------------------------------------
# Epoch 6/7 | Current LR: 0.000020
# Epoch 6: 100%|███| 276/276 [00:19<00:00, 14.46batch/s, accuracy=52.9, loss=2.36]
# 	Train: Loss = 2.3636, Acc = 52.9345
# 	Valid: Loss = 2.7621, Acc = 42.6540
# 	✨ New best validation loss: 2.7621
# ------------------------------------------------------------
# Epoch 7/7 | Current LR: 0.000006
# Epoch 7: 100%|████| 276/276 [00:19<00:00, 14.45batch/s, accuracy=54.5, loss=2.3]
# 	Train: Loss = 2.2957, Acc = 54.4528
# 	Valid: Loss = 2.7660, Acc = 42.1801
# 	Validation loss did not improve. Patience: 1/5
# ------------------------------------------------------------
#
# ✅ Loaded best model based on validation accuracy for final testing. /kaggle/working/bac/.models/lstm_bert_model.pt
# Figure(1400x600)
#
# 🧪 Evaluating on Test Set...
#
# --- Test Set Results (Best Validation Model) ---
# 	Test Loss: 2.8152
# 	Test Accuracy (Top-1): 41.09%
# 	Test MRR: 0.5331
# {'loss_train_hist': [3.8013567527135215, 3.2154600896697114, 2.897889646930971, 2.6564988567345384, 2.46754235331563, 2.3636352406895678, 2.295671627573345], 'loss_valid_hist': [3.426759515489851, 3.1215061971119473, 2.9419923509870256, 2.8556877034051076, 2.789021270615714, 2.7621212005615234, 2.7659540687288557], 'acc_train_hist': [17.83367323815998, 32.83480625424881, 39.74620439610243, 45.660548379786995, 49.71674597779288, 52.93451167006572, 54.452753229095855], 'acc_valid_hist': [27.01421800947867, 33.175355450236964, 36.96682464454976, 37.44075829383886, 40.758293838862556, 42.654028436018955, 42.18009478672986], 'test_top_5_acc': 0.667458432304038, 'test_top_10_acc': 0.7767220902612827, 'test_loss_final': 2.815180787333736, 'test_acc_top1_final': 41.09263657957245, 'test_mrr_final': 0.5330835725308032}

# %%
result_load_path = f"{os.getcwd()}/.result/lstm_bert_result.json"
plot_history(result_load_path, 7)

# %% [markdown]
# ## JDT dataset

# %%
# !python -m src.run_lstm -e bert -d jdt -ne 7 -rsw 0 -a 1 -b 0 -r 0 -hs 256 -l 2 -nah 1 -lam general
# Out:
# 2025-07-12 16:34:25.779009: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752338065.808556    1896 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752338065.815794    1896 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Shape after dropping NA assignees: (1465, 5)
# Number of unique assignees (classes): 69
# Warning: Some classes have fewer than 2 samples (min_samples_per_class=1). Stratification for train/test split might not be possible or effective.
# ✅ Loading pre-saved augmented dataset from 'datasets/augmented_train_dataset_2_JDT.csv'.
# Using device: cuda
# Generating Full Embeddings: 100%|█████████████| 193/193 [01:03<00:00,  3.03it/s]
# Generating Full Embeddings: 100%|███████████████| 10/10 [00:03<00:00,  3.29it/s]
# Generating Full Embeddings: 100%|███████████████| 19/19 [00:06<00:00,  3.12it/s]
#
# DataLoaders created successfully!
# Training batches: 193
# Validation batches: 10
# Test batches: 19
# using bert embeddings
#
# ------
# lstm model info:
# {'total_parameters': 1882181, 'trainable_parameters': 1882181, 'model_size_mb': 7.179950714111328, 'config': LSTMConfig(input_size=768, hidden_size=256, num_layers=2, num_classes=69, dropout=0.4, bidirectional=False, use_attention=True, attention_heads=1, attention_dropout=0.1, layer_norm=True, residual_connections=0, gradient_clipping=1.0, luong_attention_method='general'), 'is_bidirectional': False, 'uses_attention': True, 'attention_heads': 1}
# ------
#
# OPTIMIZER=SGD, LR=0.1
# Epoch 0: 100%|███| 193/193 [00:13<00:00, 14.16batch/s, accuracy=14.8, loss=3.59]
# OPTIMIZER=SGD, LR=0.01
# Epoch 0: 100%|█████| 193/193 [00:13<00:00, 14.54batch/s, accuracy=15, loss=3.54]
# OPTIMIZER=SGD, LR=0.001
# Epoch 0: 100%|███| 193/193 [00:13<00:00, 14.68batch/s, accuracy=12.3, loss=3.91]
# OPTIMIZER=SGD, LR=0.0001
# Epoch 0: 100%|███| 193/193 [00:13<00:00, 14.74batch/s, accuracy=2.11, loss=4.65]
# OPTIMIZER=Adam, LR=0.1
# Epoch 0: 100%|████| 193/193 [00:13<00:00, 14.44batch/s, accuracy=14.9, loss=4.3]
# OPTIMIZER=Adam, LR=0.01
# Epoch 0: 100%|███| 193/193 [00:13<00:00, 14.46batch/s, accuracy=14.5, loss=3.49]
# OPTIMIZER=Adam, LR=0.001
# Epoch 0: 100%|███| 193/193 [00:13<00:00, 14.37batch/s, accuracy=16.4, loss=3.46]
# OPTIMIZER=Adam, LR=0.0001
# Epoch 0: 100%|███| 193/193 [00:13<00:00, 14.67batch/s, accuracy=16.3, loss=3.64]
# OPTIMIZER=Adamw, LR=0.1
# Epoch 0: 100%|█████| 193/193 [00:13<00:00, 14.21batch/s, accuracy=16, loss=4.51]
# OPTIMIZER=Adamw, LR=0.01
# Epoch 0: 100%|███| 193/193 [00:13<00:00, 14.24batch/s, accuracy=14.5, loss=3.52]
# OPTIMIZER=Adamw, LR=0.001
# Epoch 0: 100%|███| 193/193 [00:13<00:00, 14.39batch/s, accuracy=16.2, loss=3.47]
# OPTIMIZER=Adamw, LR=0.0001
# Epoch 0: 100%|███| 193/193 [00:13<00:00, 14.58batch/s, accuracy=16.3, loss=3.61]
# <class 'torch.optim.adam.Adam'> 0.001
#
# ✅ Start Training 7 epochs ...
# Epoch 1/7 | Current LR: 0.001000
# Epoch 1: 100%|███| 193/193 [00:13<00:00, 14.45batch/s, accuracy=16.4, loss=3.47]
# 	Train: Loss = 3.4745, Acc = 16.4228
# 	Valid: Loss = 3.1616, Acc = 22.4490
# 	✨ New best validation loss: 3.1616
# ------------------------------------------------------------
# Epoch 2/7 | Current LR: 0.000951
# Epoch 2: 100%|███| 193/193 [00:13<00:00, 14.31batch/s, accuracy=25.7, loss=3.13]
# 	Train: Loss = 3.1290, Acc = 25.6585
# 	Valid: Loss = 2.9436, Acc = 26.5306
# 	✨ New best validation loss: 2.9436
# ------------------------------------------------------------
# Epoch 3/7 | Current LR: 0.000812
# Epoch 3: 100%|███| 193/193 [00:13<00:00, 14.33batch/s, accuracy=34.2, loss=2.88]
# 	Train: Loss = 2.8809, Acc = 34.1789
# 	Valid: Loss = 2.7290, Acc = 31.2925
# 	✨ New best validation loss: 2.7290
# ------------------------------------------------------------
# Epoch 4/7 | Current LR: 0.000612
# Epoch 4: 100%|███| 193/193 [00:13<00:00, 14.33batch/s, accuracy=39.4, loss=2.67]
# 	Train: Loss = 2.6694, Acc = 39.4146
# 	Valid: Loss = 2.7325, Acc = 35.3741
# 	Validation loss did not improve. Patience: 1/5
# ------------------------------------------------------------
# Epoch 5/7 | Current LR: 0.000389
# Epoch 5: 100%|███| 193/193 [00:13<00:00, 14.24batch/s, accuracy=44.7, loss=2.47]
# 	Train: Loss = 2.4707, Acc = 44.7154
# 	Valid: Loss = 2.6214, Acc = 40.1361
# 	✨ New best validation loss: 2.6214
# ------------------------------------------------------------
# Epoch 6/7 | Current LR: 0.000189
# Epoch 6: 100%|███| 193/193 [00:13<00:00, 14.27batch/s, accuracy=52.5, loss=2.21]
# 	Train: Loss = 2.2137, Acc = 52.4878
# 	Valid: Loss = 2.6159, Acc = 39.4558
# 	✨ New best validation loss: 2.6159
# ------------------------------------------------------------
# Epoch 7/7 | Current LR: 0.000050
# Epoch 7: 100%|███| 193/193 [00:13<00:00, 14.20batch/s, accuracy=57.6, loss=2.06]
# 	Train: Loss = 2.0593, Acc = 57.6260
# 	Valid: Loss = 2.7036, Acc = 41.4966
# 	Validation loss did not improve. Patience: 1/5
# ------------------------------------------------------------
#
# ✅ Loaded best model based on validation accuracy for final testing. /kaggle/working/bac/.models/lstm_bert_model.pt
# Figure(1400x600)
#
# 🧪 Evaluating on Test Set...
#
# --- Test Set Results (Best Validation Model) ---
# 	Test Loss: 2.8950
# 	Test Accuracy (Top-1): 33.79%
# 	Test MRR: 0.5038
# {'loss_train_hist': [3.4744886746678327, 3.1289942993401247, 2.880942817796697, 2.669409197229178, 2.470706614187962, 2.213660260556275, 2.059315160766167], 'loss_valid_hist': [3.1615689277648924, 2.9436371088027955, 2.7289559125900267, 2.7324967861175535, 2.621423029899597, 2.6158561229705812, 2.7036097645759583], 'acc_train_hist': [16.422764227642276, 25.658536585365855, 34.17886178861789, 39.41463414634146, 44.71544715447155, 52.48780487804878, 57.6260162601626], 'acc_valid_hist': [22.448979591836736, 26.53061224489796, 31.292517006802722, 35.374149659863946, 40.136054421768705, 39.45578231292517, 41.49659863945578], 'test_top_5_acc': 0.7201365187713311, 'test_top_10_acc': 0.8532423208191127, 'test_loss_final': 2.8949500134116724, 'test_acc_top1_final': 33.78839590443686, 'test_mrr_final': 0.5037937363659387}

# %%
result_load_path = f"{os.getcwd()}/.result/lstm_bert_result.json"
plot_history(result_load_path, 7)
