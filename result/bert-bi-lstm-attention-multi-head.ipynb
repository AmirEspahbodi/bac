# %%
# %cd /kaggle/working
# !git clone https://github.com/AmirEspahbodi/bac.git
# Out:
# /kaggle/working
# fatal: destination path 'bac' already exists and is not an empty directory.

# %%
# !pip install bitsandbytes

# %%
# %cd /kaggle/working/bac
# !git pull
# !ls
# Out:
# /kaggle/working/bac
# Already up to date.
# datasets     poetry.lock     README.md	src
# inspiration  pyproject.toml  scripts	state.db

# %%
import os
import json
import matplotlib.pyplot as plt


def plot_history(result_load_path, NUM_EPOCHS):
    loss_train_hist = None
    loss_valid_hist = None
    acc_train_hist = None
    acc_valid_hist = None
    test_top_5_acc = None
    test_top_10_acc = None
    test_loss_final = None
    test_acc_top1_final = None
    test_mrr_final = None
        
    # Load the data from the JSON file
    try:
        with open(result_load_path, "r") as f:
            # json.load() reads the file and parses the JSON data into a Python dictionary
            loaded_results = json.load(f)
    
        # Unpack the dictionary values into your variables
        loss_train_hist = loaded_results.get("loss_train_hist")
        loss_valid_hist = loaded_results.get("loss_valid_hist")
        acc_train_hist = loaded_results.get("acc_train_hist")
        acc_valid_hist = loaded_results.get("acc_valid_hist")
        test_top_5_acc = loaded_results.get("test_top_5_acc")
        test_top_10_acc = loaded_results.get("test_top_10_acc")
        test_loss_final = loaded_results.get("test_loss_final")
        test_acc_top1_final = loaded_results.get("test_acc_top1_final")
        test_mrr_final = loaded_results.get("test_mrr_final")
    
    except FileNotFoundError:
        print(f"Error: The file at '{result_load_path}' was not found.")
    except json.JSONDecodeError:
        print(f"Error: The file at '{result_load_path}' is not a valid JSON file.")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")
    
    epochs_range = range(1, NUM_EPOCHS + 1)
    
    plt.figure(figsize=(14, 6))
    
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, loss_train_hist, "bo-", label="Training Loss")
    plt.plot(epochs_range, loss_valid_hist, "ro-", label="Validation Loss")
    plt.title("Training and Validation Loss")
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.legend()
    plt.grid(True)
    
    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, acc_train_hist, "bo-", label="Training Accuracy (Top-1)")
    plt.plot(epochs_range, acc_valid_hist, "ro-", label="Validation Accuracy (Top-1)")
    plt.title("Training and Validation Accuracy (Top-1)")
    plt.xlabel("Epochs")
    plt.ylabel("Accuracy")
    plt.legend()
    plt.grid(True)
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## GCC dataset

# %%
# !python -m src.run_lstm -e bert -d gcc -ne 7 -rsw 0 -a 1 -b 1 -r 0 -hs 256 -l 2 -nah 8 -lam dot
# Out:
# 2025-07-12 13:39:44.889492: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752327584.911743     615 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752327584.918602     615 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Shape after dropping NA assignees: (2103, 6)
# Number of unique assignees (classes): 82
# Warning: Some classes have fewer than 2 samples (min_samples_per_class=1). Stratification for train/test split might not be possible or effective.
# ✅ Loading pre-saved augmented dataset from 'datasets/augmented_train_dataset_2_GCC.csv'.
# Using device: cuda
# Generating Full Embeddings: 100%|█████████████| 276/276 [01:33<00:00,  2.95it/s]
# Generating Full Embeddings: 100%|███████████████| 14/14 [00:04<00:00,  3.06it/s]
# Generating Full Embeddings: 100%|███████████████| 27/27 [00:08<00:00,  3.07it/s]
#
# DataLoaders created successfully!
# Training batches: 276
# Validation batches: 14
# Test batches: 27
# using bert embeddings
#
# ------
# lstm model info:
# {'total_parameters': 5080146, 'trainable_parameters': 5080146, 'model_size_mb': 19.37921905517578, 'config': LSTMConfig(input_size=768, hidden_size=256, num_layers=2, num_classes=82, dropout=0.4, bidirectional=True, use_attention=True, attention_heads=8, attention_dropout=0.1, layer_norm=True, residual_connections=0, gradient_clipping=1.0, luong_attention_method='dot'), 'is_bidirectional': True, 'uses_attention': True, 'attention_heads': 8}
# ------
#
# OPTIMIZER=SGD, LR=0.1
# Epoch 0: 100%|███| 276/276 [00:32<00:00,  8.60batch/s, accuracy=11.5, loss=3.87]
# OPTIMIZER=SGD, LR=0.01
# Epoch 0: 100%|███| 276/276 [00:31<00:00,  8.85batch/s, accuracy=14.3, loss=3.82]
# OPTIMIZER=SGD, LR=0.001
# Epoch 0: 100%|█████| 276/276 [00:30<00:00,  8.94batch/s, accuracy=12, loss=4.06]
# OPTIMIZER=SGD, LR=0.0001
# Epoch 0: 100%|█████| 276/276 [00:30<00:00,  8.93batch/s, accuracy=6.8, loss=4.6]
# OPTIMIZER=Adam, LR=0.1
# Epoch 0: 100%|███| 276/276 [00:31<00:00,  8.70batch/s, accuracy=11.1, loss=25.5]
# OPTIMIZER=Adam, LR=0.01
# Epoch 0: 100%|███| 276/276 [00:31<00:00,  8.70batch/s, accuracy=11.8, loss=3.86]
# OPTIMIZER=Adam, LR=0.001
# Epoch 0: 100%|███| 276/276 [00:31<00:00,  8.69batch/s, accuracy=12.2, loss=3.82]
# OPTIMIZER=Adam, LR=0.0001
# Epoch 0: 100%|███| 276/276 [00:31<00:00,  8.85batch/s, accuracy=22.4, loss=3.62]
# OPTIMIZER=Adamw, LR=0.1
# Epoch 0: 100%|███| 276/276 [00:31<00:00,  8.78batch/s, accuracy=12.7, loss=7.69]
# OPTIMIZER=Adamw, LR=0.01
# Epoch 0: 100%|███| 276/276 [00:31<00:00,  8.77batch/s, accuracy=11.9, loss=3.88]
# OPTIMIZER=Adamw, LR=0.001
# Epoch 0: 100%|█████| 276/276 [00:31<00:00,  8.70batch/s, accuracy=12, loss=3.84]
# OPTIMIZER=Adamw, LR=0.0001
# Epoch 0: 100%|███| 276/276 [00:31<00:00,  8.84batch/s, accuracy=22.3, loss=3.64]
# <class 'torch.optim.adam.Adam'> 0.0001
#
# ✅ Start Training 7 epochs ...
# Epoch 1/7 | Current LR: 0.000100
# Epoch 1: 100%|███| 276/276 [00:31<00:00,  8.89batch/s, accuracy=21.6, loss=3.65]
# 	Train: Loss = 3.6500, Acc = 21.6179
# 	Valid: Loss = 3.2028, Acc = 31.7536
# 	✨ New best validation loss: 3.2028
# ------------------------------------------------------------
# Epoch 2/7 | Current LR: 0.000095
# Epoch 2: 100%|███| 276/276 [00:31<00:00,  8.81batch/s, accuracy=37.7, loss=2.94]
# 	Train: Loss = 2.9359, Acc = 37.6615
# 	Valid: Loss = 2.8876, Acc = 39.3365
# 	✨ New best validation loss: 2.8876
# ------------------------------------------------------------
# Epoch 3/7 | Current LR: 0.000081
# Epoch 3: 100%|█████| 276/276 [00:31<00:00,  8.85batch/s, accuracy=49, loss=2.47]
# 	Train: Loss = 2.4660, Acc = 49.0369
# 	Valid: Loss = 2.7418, Acc = 45.0237
# 	✨ New best validation loss: 2.7418
# ------------------------------------------------------------
# Epoch 4/7 | Current LR: 0.000062
# Epoch 4: 100%|███| 276/276 [00:31<00:00,  8.85batch/s, accuracy=58.5, loss=2.13]
# 	Train: Loss = 2.1288, Acc = 58.5090
# 	Valid: Loss = 2.7066, Acc = 45.0237
# 	✨ New best validation loss: 2.7066
# ------------------------------------------------------------
# Epoch 5/7 | Current LR: 0.000039
# Epoch 5: 100%|███| 276/276 [00:31<00:00,  8.76batch/s, accuracy=67.7, loss=1.82]
# 	Train: Loss = 1.8220, Acc = 67.7317
# 	Valid: Loss = 2.7483, Acc = 43.1280
# 	Validation loss did not improve. Patience: 1/5
# ------------------------------------------------------------
# Epoch 6/7 | Current LR: 0.000020
# Epoch 6: 100%|███| 276/276 [00:31<00:00,  8.78batch/s, accuracy=74.3, loss=1.64]
# 	Train: Loss = 1.6409, Acc = 74.2805
# 	Valid: Loss = 2.6637, Acc = 45.9716
# 	✨ New best validation loss: 2.6637
# ------------------------------------------------------------
# Epoch 7/7 | Current LR: 0.000006
# Epoch 7: 100%|███| 276/276 [00:31<00:00,  8.83batch/s, accuracy=77.8, loss=1.56]
# 	Train: Loss = 1.5564, Acc = 77.7929
# 	Valid: Loss = 2.6799, Acc = 45.4976
# 	Validation loss did not improve. Patience: 1/5
# ------------------------------------------------------------
#
# ✅ Loaded best model based on validation accuracy for final testing. /kaggle/working/bac/.models/lstm_bert_model.pt
# Figure(1400x600)
#
# 🧪 Evaluating on Test Set...
#
# --- Test Set Results (Best Validation Model) ---
# 	Test Loss: 2.6372
# 	Test Accuracy (Top-1): 47.27%
# 	Test MRR: 0.5851
# {'loss_train_hist': [3.6499830933584683, 2.935890102300091, 2.466044267018636, 2.1287845567516657, 1.822024391181227, 1.6408776874127595, 1.5564498067765995], 'loss_valid_hist': [3.2027946369988576, 2.88762697151729, 2.741838114602225, 2.7066369227000644, 2.748308300971985, 2.663723247391837, 2.679916637284415], 'acc_train_hist': [21.617946974847044, 37.661454792658056, 49.036936324495805, 58.50895082710174, 67.73170179016542, 74.28053478359392, 77.79288465896215], 'acc_valid_hist': [31.753554502369667, 39.33649289099526, 45.023696682464454, 45.023696682464454, 43.127962085308056, 45.97156398104266, 45.497630331753555], 'test_top_5_acc': 0.7197149643705463, 'test_top_10_acc': 0.8171021377672208, 'test_loss_final': 2.637200050883823, 'test_acc_top1_final': 47.26840855106888, 'test_mrr_final': 0.5850906328299931}

# %%
result_load_path = f"{os.getcwd()}/.result/lstm_bert_result.json"
plot_history(result_load_path, 7)

# %% [markdown]
# ## JDT dataset

# %%
# !python -m src.run_lstm -e bert -d jdt -ne 7 -rsw 0 -a 1 -b 1 -r 0 -hs 256 -l 2 -nah 8 -lam dot
# Out:
# 2025-07-12 13:51:59.692017: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752328319.714181     866 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752328319.721012     866 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Shape after dropping NA assignees: (1465, 5)
# Number of unique assignees (classes): 69
# Warning: Some classes have fewer than 2 samples (min_samples_per_class=1). Stratification for train/test split might not be possible or effective.
# ✅ Loading pre-saved augmented dataset from 'datasets/augmented_train_dataset_2_JDT.csv'.
# Using device: cuda
# Generating Full Embeddings: 100%|█████████████| 193/193 [01:04<00:00,  2.99it/s]
# Generating Full Embeddings: 100%|███████████████| 10/10 [00:03<00:00,  3.28it/s]
# Generating Full Embeddings: 100%|███████████████| 19/19 [00:06<00:00,  3.07it/s]
#
# DataLoaders created successfully!
# Training batches: 193
# Validation batches: 10
# Test batches: 19
# using bert embeddings
#
# ------
# lstm model info:
# {'total_parameters': 5076805, 'trainable_parameters': 5076805, 'model_size_mb': 19.366474151611328, 'config': LSTMConfig(input_size=768, hidden_size=256, num_layers=2, num_classes=69, dropout=0.4, bidirectional=True, use_attention=True, attention_heads=8, attention_dropout=0.1, layer_norm=True, residual_connections=0, gradient_clipping=1.0, luong_attention_method='dot'), 'is_bidirectional': True, 'uses_attention': True, 'attention_heads': 8}
# ------
#
# OPTIMIZER=SGD, LR=0.1
# Epoch 0: 100%|███| 193/193 [00:22<00:00,  8.67batch/s, accuracy=14.6, loss=3.62]
# OPTIMIZER=SGD, LR=0.01
# Epoch 0: 100%|███| 193/193 [00:21<00:00,  8.83batch/s, accuracy=15.9, loss=3.53]
# OPTIMIZER=SGD, LR=0.001
# Epoch 0: 100%|███| 193/193 [00:21<00:00,  8.88batch/s, accuracy=11.8, loss=3.87]
# OPTIMIZER=SGD, LR=0.0001
# Epoch 0: 100%|███| 193/193 [00:21<00:00,  8.90batch/s, accuracy=2.73, loss=4.82]
# OPTIMIZER=Adam, LR=0.1
# Epoch 0: 100%|███| 193/193 [00:22<00:00,  8.73batch/s, accuracy=13.2, loss=9.16]
# OPTIMIZER=Adam, LR=0.01
# Epoch 0: 100%|███| 193/193 [00:22<00:00,  8.73batch/s, accuracy=13.5, loss=4.14]
# OPTIMIZER=Adam, LR=0.001
# Epoch 0: 100%|███| 193/193 [00:22<00:00,  8.71batch/s, accuracy=14.2, loss=3.52]
# OPTIMIZER=Adam, LR=0.0001
# Epoch 0: 100%|███| 193/193 [00:21<00:00,  8.86batch/s, accuracy=17.5, loss=3.49]
# OPTIMIZER=Adamw, LR=0.1
# Epoch 0: 100%|███| 193/193 [00:21<00:00,  8.79batch/s, accuracy=15.8, loss=16.7]
# OPTIMIZER=Adamw, LR=0.01
# Epoch 0: 100%|███| 193/193 [00:22<00:00,  8.75batch/s, accuracy=15.3, loss=3.67]
# OPTIMIZER=Adamw, LR=0.001
# Epoch 0: 100%|███| 193/193 [00:22<00:00,  8.77batch/s, accuracy=13.9, loss=3.52]
# OPTIMIZER=Adamw, LR=0.0001
# Epoch 0: 100%|███| 193/193 [00:21<00:00,  8.90batch/s, accuracy=16.7, loss=3.48]
# <class 'torch.optim.adam.Adam'> 0.0001
#
# ✅ Start Training 7 epochs ...
# Epoch 1/7 | Current LR: 0.000100
# Epoch 1: 100%|███| 193/193 [00:21<00:00,  8.88batch/s, accuracy=17.9, loss=3.49]
# 	Train: Loss = 3.4868, Acc = 17.8537
# 	Valid: Loss = 3.1799, Acc = 20.4082
# 	✨ New best validation loss: 3.1799
# ------------------------------------------------------------
# Epoch 2/7 | Current LR: 0.000095
# Epoch 2: 100%|███| 193/193 [00:21<00:00,  8.86batch/s, accuracy=28.3, loss=3.06]
# 	Train: Loss = 3.0566, Acc = 28.3252
# 	Valid: Loss = 3.0445, Acc = 25.8503
# 	✨ New best validation loss: 3.0445
# ------------------------------------------------------------
# Epoch 3/7 | Current LR: 0.000081
# Epoch 3: 100%|███| 193/193 [00:21<00:00,  8.87batch/s, accuracy=39.5, loss=2.66]
# 	Train: Loss = 2.6649, Acc = 39.5447
# 	Valid: Loss = 2.8901, Acc = 31.2925
# 	✨ New best validation loss: 2.8901
# ------------------------------------------------------------
# Epoch 4/7 | Current LR: 0.000062
# Epoch 4: 100%|████| 193/193 [00:21<00:00,  8.85batch/s, accuracy=50.1, loss=2.3]
# 	Train: Loss = 2.3041, Acc = 50.1138
# 	Valid: Loss = 2.9237, Acc = 28.5714
# 	Validation loss did not improve. Patience: 1/5
# ------------------------------------------------------------
# Epoch 5/7 | Current LR: 0.000039
# Epoch 5: 100%|███| 193/193 [00:22<00:00,  8.77batch/s, accuracy=58.6, loss=2.01]
# 	Train: Loss = 2.0128, Acc = 58.6016
# 	Valid: Loss = 3.0010, Acc = 34.6939
# 	Validation loss did not improve. Patience: 2/5
# ------------------------------------------------------------
# Epoch 6/7 | Current LR: 0.000020
# Epoch 6: 100%|███| 193/193 [00:21<00:00,  8.82batch/s, accuracy=66.5, loss=1.81]
# 	Train: Loss = 1.8095, Acc = 66.5041
# 	Valid: Loss = 2.9713, Acc = 32.6531
# 	Validation loss did not improve. Patience: 3/5
# ------------------------------------------------------------
# Epoch 7/7 | Current LR: 0.000006
# Epoch 7: 100%|███| 193/193 [00:21<00:00,  8.84batch/s, accuracy=71.2, loss=1.69]
# 	Train: Loss = 1.6938, Acc = 71.1545
# 	Valid: Loss = 3.0127, Acc = 34.6939
# 	Validation loss did not improve. Patience: 4/5
# ------------------------------------------------------------
#
# ✅ Loaded best model based on validation accuracy for final testing. /kaggle/working/bac/.models/lstm_bert_model.pt
# Figure(1400x600)
#
# 🧪 Evaluating on Test Set...
#
# --- Test Set Results (Best Validation Model) ---
# 	Test Loss: 2.9897
# 	Test Accuracy (Top-1): 31.74%
# 	Test MRR: 0.4800
# {'loss_train_hist': [3.486765482265097, 3.05662770468954, 2.664901666072984, 2.3041273133124713, 2.0127604613032366, 1.809455274300254, 1.6938001423919757], 'loss_valid_hist': [3.179878282546997, 3.044511580467224, 2.890097188949585, 2.9237207174301147, 3.0010037660598754, 2.9713420629501344, 3.0127414226531983], 'acc_train_hist': [17.853658536585368, 28.32520325203252, 39.54471544715447, 50.113821138211385, 58.60162601626016, 66.5040650406504, 71.15447154471545], 'acc_valid_hist': [20.408163265306122, 25.85034013605442, 31.292517006802722, 28.571428571428573, 34.69387755102041, 32.6530612244898, 34.69387755102041], 'test_top_5_acc': 0.6791808873720137, 'test_top_10_acc': 0.8293515358361775, 'test_loss_final': 2.9897367201353373, 'test_acc_top1_final': 31.74061433447099, 'test_mrr_final': 0.4799714215987558}

# %%
result_load_path = f"{os.getcwd()}/.result/lstm_bert_result.json"
plot_history(result_load_path, 7)
