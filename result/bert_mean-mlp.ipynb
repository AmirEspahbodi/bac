# %%
# %cd /kaggle/working
# !git clone https://github.com/AmirEspahbodi/bac.git
# Out:
# /kaggle/working
# fatal: destination path 'bac' already exists and is not an empty directory.

# %%
# %cd /kaggle/working/bac
# !git pull
# !ls
# Out:
# /kaggle/working/bac
# Already up to date.
# datasets     poetry.lock     README.md	src
# inspiration  pyproject.toml  scripts	state.db

# %%
import os
import json
import matplotlib.pyplot as plt


def plot_history(result_load_path, NUM_EPOCHS):
    loss_train_hist = None
    loss_valid_hist = None
    acc_train_hist = None
    acc_valid_hist = None
    test_top_5_acc = None
    test_top_10_acc = None
    test_loss_final = None
    test_acc_top1_final = None
    test_mrr_final = None
        
    # Load the data from the JSON file
    try:
        with open(result_load_path, "r") as f:
            # json.load() reads the file and parses the JSON data into a Python dictionary
            loaded_results = json.load(f)
    
        # Unpack the dictionary values into your variables
        loss_train_hist = loaded_results.get("loss_train_hist")
        loss_valid_hist = loaded_results.get("loss_valid_hist")
        acc_train_hist = loaded_results.get("acc_train_hist")
        acc_valid_hist = loaded_results.get("acc_valid_hist")
        test_top_5_acc = loaded_results.get("test_top_5_acc")
        test_top_10_acc = loaded_results.get("test_top_10_acc")
        test_loss_final = loaded_results.get("test_loss_final")
        test_acc_top1_final = loaded_results.get("test_acc_top1_final")
        test_mrr_final = loaded_results.get("test_mrr_final")
    
    except FileNotFoundError:
        print(f"Error: The file at '{result_load_path}' was not found.")
    except json.JSONDecodeError:
        print(f"Error: The file at '{result_load_path}' is not a valid JSON file.")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")
    
    epochs_range = range(1, NUM_EPOCHS + 1)
    
    plt.figure(figsize=(14, 6))
    
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, loss_train_hist, "bo-", label="Training Loss")
    plt.plot(epochs_range, loss_valid_hist, "ro-", label="Validation Loss")
    plt.title("Training and Validation Loss")
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.legend()
    plt.grid(True)
    
    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, acc_train_hist, "bo-", label="Training Accuracy (Top-1)")
    plt.plot(epochs_range, acc_valid_hist, "ro-", label="Validation Accuracy (Top-1)")
    plt.title("Training and Validation Accuracy (Top-1)")
    plt.xlabel("Epochs")
    plt.ylabel("Accuracy")
    plt.legend()
    plt.grid(True)
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## GCC dataset

# %%
# !python -m src.run_mlp -e bert_mean -d gcc -ne 7 -rsw 0
# Out:
# 2025-07-13 20:05:25.170985: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752437125.193291     233 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752437125.201255     233 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Shape after dropping NA assignees: (2103, 6)
# Number of unique assignees (classes): 82
# Warning: Some classes have fewer than 2 samples (min_samples_per_class=1). Stratification for train/test split might not be possible or effective.
# ✅ Loading pre-saved augmented dataset from 'datasets/augmented_train_dataset_2_GCC.csv'.
# Using device: cuda
# Generating Full Embeddings: 100%|█████████████| 276/276 [01:33<00:00,  2.94it/s]
# Generating Full Embeddings: 100%|███████████████| 14/14 [00:04<00:00,  3.08it/s]
# Generating Full Embeddings: 100%|███████████████| 27/27 [00:08<00:00,  3.08it/s]
#
# DataLoaders created successfully!
# Training batches: 276
# Validation batches: 14
# Test batches: 27
# bert_mean
# OPTIMIZER=SGD, LR=0.1
# Epoch 0: 100%|████| 138/138 [00:01<00:00, 137.91batch/s, accuracy=17, loss=3.96]
# OPTIMIZER=SGD, LR=0.01
# Epoch 0: 100%|██| 138/138 [00:00<00:00, 160.48batch/s, accuracy=20.3, loss=3.62]
# OPTIMIZER=SGD, LR=0.001
# Epoch 0: 100%|██| 138/138 [00:00<00:00, 155.76batch/s, accuracy=11.6, loss=4.17]
# OPTIMIZER=SGD, LR=0.0001
# Epoch 0: 100%|███| 138/138 [00:00<00:00, 163.20batch/s, accuracy=2.7, loss=4.88]
# OPTIMIZER=Adam, LR=0.1
# Epoch 0: 100%|██| 138/138 [00:01<00:00, 131.83batch/s, accuracy=6.68, loss=9.99]
# OPTIMIZER=Adam, LR=0.01
# Epoch 0: 100%|██| 138/138 [00:01<00:00, 136.81batch/s, accuracy=11.5, loss=4.48]
# OPTIMIZER=Adam, LR=0.001
# Epoch 0: 100%|██| 138/138 [00:01<00:00, 136.95batch/s, accuracy=21.6, loss=3.66]
# OPTIMIZER=Adam, LR=0.0001
# Epoch 0: 100%|███| 138/138 [00:01<00:00, 136.96batch/s, accuracy=27.7, loss=3.3]
# OPTIMIZER=Adamw, LR=0.1
# Epoch 0: 100%|██| 138/138 [00:00<00:00, 138.76batch/s, accuracy=4.94, loss=13.7]
# OPTIMIZER=Adamw, LR=0.01
# Epoch 0: 100%|██| 138/138 [00:00<00:00, 139.17batch/s, accuracy=11.1, loss=4.47]
# OPTIMIZER=Adamw, LR=0.001
# Epoch 0: 100%|██| 138/138 [00:00<00:00, 138.24batch/s, accuracy=21.5, loss=3.64]
# OPTIMIZER=Adamw, LR=0.0001
# Epoch 0: 100%|██| 138/138 [00:00<00:00, 141.27batch/s, accuracy=27.1, loss=3.31]
# <class 'torch.optim.adam.Adam'> 0.0001
#
# ✅ Start Training 7 epochs ...
# Epoch 1/7 | Current LR: 0.000100
# Epoch 1: 100%|██| 138/138 [00:01<00:00, 133.13batch/s, accuracy=27.1, loss=3.32]
# 	Train: Loss = 3.3172, Acc = 27.1244
# 	Valid: Loss = 3.1244, Acc = 30.8057
# 	✨ New best validation loss: 3.1244
# ------------------------------------------------------------
# Epoch 2/7 | Current LR: 0.000095
# Epoch 2: 100%|██| 138/138 [00:01<00:00, 133.91batch/s, accuracy=49.9, loss=2.36]
# 	Train: Loss = 2.3569, Acc = 49.9433
# 	Valid: Loss = 3.0634, Acc = 38.8626
# 	✨ New best validation loss: 3.0634
# ------------------------------------------------------------
# Epoch 3/7 | Current LR: 0.000081
# Epoch 3: 100%|██| 138/138 [00:01<00:00, 137.58batch/s, accuracy=78.3, loss=1.51]
# 	Train: Loss = 1.5099, Acc = 78.3367
# 	Valid: Loss = 3.1017, Acc = 44.5498
# 	Validation loss did not improve. Patience: 1/5
# ------------------------------------------------------------
# Epoch 4/7 | Current LR: 0.000062
# Epoch 4: 100%|████| 138/138 [00:01<00:00, 134.40batch/s, accuracy=95, loss=1.08]
# 	Train: Loss = 1.0772, Acc = 95.0374
# 	Valid: Loss = 3.2308, Acc = 44.5498
# 	Validation loss did not improve. Patience: 2/5
# ------------------------------------------------------------
# Epoch 5/7 | Current LR: 0.000039
# Epoch 5: 100%|███| 138/138 [00:01<00:00, 137.06batch/s, accuracy=99, loss=0.945]
# 	Train: Loss = 0.9450, Acc = 99.0256
# 	Valid: Loss = 3.2011, Acc = 43.6019
# 	Validation loss did not improve. Patience: 3/5
# ------------------------------------------------------------
# Epoch 6/7 | Current LR: 0.000020
# Epoch 6: 100%|█| 138/138 [00:01<00:00, 137.23batch/s, accuracy=99.5, loss=0.899]
# 	Train: Loss = 0.8986, Acc = 99.5468
# 	Valid: Loss = 3.1701, Acc = 45.9716
# 	Validation loss did not improve. Patience: 4/5
# ------------------------------------------------------------
# Epoch 7/7 | Current LR: 0.000006
# Epoch 7: 100%|█| 138/138 [00:01<00:00, 137.77batch/s, accuracy=99.9, loss=0.879]
# 	Train: Loss = 0.8788, Acc = 99.9320
# 	Valid: Loss = 3.1660, Acc = 42.6540
# 	Validation loss did not improve. Patience: 5/5
#
# 🛑 Early stopping triggered at epoch 7.
#
# ✅ Loaded best model based on validation accuracy for final testing. /kaggle/working/bac/.models/MLP_bert_mean_model.pt
# Figure(1400x600)
#
# 🧪 Evaluating on Test Set...
#
# --- Test Set Results (Best Validation Model) ---
# 	Test Loss: 3.0091
# 	Test Accuracy (Top-1): 40.62%
# 	Test MRR: 0.5249
# {'loss_train_hist': [3.317185991052268, 2.3569346977316816, 1.5098983515863833, 1.0772290264350781, 0.9450472882692365, 0.8985629181067148, 0.8788495599359706], 'loss_valid_hist': [3.124395098005022, 3.0634260177612305, 3.1016928127833774, 3.2308293751307895, 3.2011429582323347, 3.170085600444249, 3.166032075881958], 'acc_train_hist': [27.124405166553366, 49.943349195558575, 78.33673238159982, 95.03738953093134, 99.02560616360752, 99.54679356446862, 99.93201903467029], 'acc_valid_hist': [30.805687203791468, 38.86255924170616, 44.54976303317535, 44.54976303317535, 43.60189573459716, 45.97156398104266, 42.654028436018955], 'test_top_5_acc': 0.6532066508313539, 'test_top_10_acc': 0.7767220902612827, 'test_loss_final': 3.0091144698006764, 'test_acc_top1_final': 40.61757719714964, 'test_mrr_final': 0.5249388287898722}

# %%
result_load_path = f"{os.getcwd()}/.result/MLP_bert_cls_result.json"
plot_history(result_load_path, 6)

# %% [markdown]
# ## JDT dataset

# %%
# !python -m src.run_mlp -e bert_mean -d jdt -ne 6 -rsw 0
# Out:
# 2025-07-13 20:12:18.671880: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752437538.693708     276 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752437538.700765     276 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Shape after dropping NA assignees: (1465, 5)
# Number of unique assignees (classes): 69
# Warning: Some classes have fewer than 2 samples (min_samples_per_class=1). Stratification for train/test split might not be possible or effective.
# ✅ Loading pre-saved augmented dataset from 'datasets/augmented_train_dataset_2_JDT.csv'.
# Using device: cuda
# Generating Full Embeddings: 100%|█████████████| 193/193 [01:03<00:00,  3.02it/s]
# Generating Full Embeddings: 100%|███████████████| 10/10 [00:03<00:00,  3.29it/s]
# Generating Full Embeddings: 100%|███████████████| 19/19 [00:06<00:00,  3.01it/s]
#
# DataLoaders created successfully!
# Training batches: 193
# Validation batches: 10
# Test batches: 19
# bert_mean
# OPTIMIZER=SGD, LR=0.1
# Epoch 0: 100%|█████| 97/97 [00:00<00:00, 127.74batch/s, accuracy=15.8, loss=3.7]
# OPTIMIZER=SGD, LR=0.01
# Epoch 0: 100%|████| 97/97 [00:00<00:00, 157.51batch/s, accuracy=18.1, loss=3.49]
# OPTIMIZER=SGD, LR=0.001
# Epoch 0: 100%|████| 97/97 [00:00<00:00, 158.70batch/s, accuracy=10.4, loss=4.15]
# OPTIMIZER=SGD, LR=0.0001
# Epoch 0: 100%|████| 97/97 [00:00<00:00, 159.49batch/s, accuracy=2.24, loss=5.06]
# OPTIMIZER=Adam, LR=0.1
# Epoch 0: 100%|████| 97/97 [00:00<00:00, 127.12batch/s, accuracy=7.74, loss=12.3]
# OPTIMIZER=Adam, LR=0.01
# Epoch 0: 100%|████| 97/97 [00:00<00:00, 134.92batch/s, accuracy=12.4, loss=4.34]
# OPTIMIZER=Adam, LR=0.001
# Epoch 0: 100%|████| 97/97 [00:00<00:00, 135.60batch/s, accuracy=17.9, loss=3.51]
# OPTIMIZER=Adam, LR=0.0001
# Epoch 0: 100%|████| 97/97 [00:00<00:00, 135.21batch/s, accuracy=23.5, loss=3.23]
# OPTIMIZER=Adamw, LR=0.1
# Epoch 0: 100%|████| 97/97 [00:00<00:00, 136.01batch/s, accuracy=6.54, loss=14.5]
# OPTIMIZER=Adamw, LR=0.01
# Epoch 0: 100%|████| 97/97 [00:00<00:00, 137.07batch/s, accuracy=12.3, loss=4.32]
# OPTIMIZER=Adamw, LR=0.001
# Epoch 0: 100%|████| 97/97 [00:00<00:00, 138.77batch/s, accuracy=17.6, loss=3.49]
# OPTIMIZER=Adamw, LR=0.0001
# Epoch 0: 100%|████| 97/97 [00:00<00:00, 140.06batch/s, accuracy=23.3, loss=3.22]
# <class 'torch.optim.adam.Adam'> 0.0001
#
# ✅ Start Training 6 epochs ...
# Epoch 1/6 | Current LR: 0.000100
# Epoch 1: 100%|████| 97/97 [00:00<00:00, 133.59batch/s, accuracy=22.5, loss=3.24]
# 	Train: Loss = 3.2409, Acc = 22.5041
# 	Valid: Loss = 3.1338, Acc = 25.8503
# 	✨ New best validation loss: 3.1338
# ------------------------------------------------------------
# Epoch 2/6 | Current LR: 0.000093
# Epoch 2: 100%|████| 97/97 [00:00<00:00, 137.26batch/s, accuracy=41.7, loss=2.46]
# 	Train: Loss = 2.4615, Acc = 41.7236
# 	Valid: Loss = 3.2586, Acc = 30.6122
# 	Validation loss did not improve. Patience: 1/5
# ------------------------------------------------------------
# Epoch 3/6 | Current LR: 0.000075
# Epoch 3: 100%|████| 97/97 [00:00<00:00, 133.48batch/s, accuracy=64.8, loss=1.78]
# 	Train: Loss = 1.7803, Acc = 64.8130
# 	Valid: Loss = 3.5592, Acc = 28.5714
# 	Validation loss did not improve. Patience: 2/5
# ------------------------------------------------------------
# Epoch 4/6 | Current LR: 0.000050
# Epoch 4: 100%|██████| 97/97 [00:00<00:00, 135.25batch/s, accuracy=85, loss=1.27]
# 	Train: Loss = 1.2673, Acc = 85.0407
# 	Valid: Loss = 3.6352, Acc = 29.2517
# 	Validation loss did not improve. Patience: 3/5
# ------------------------------------------------------------
# Epoch 5/6 | Current LR: 0.000026
# Epoch 5: 100%|██████| 97/97 [00:00<00:00, 132.88batch/s, accuracy=95, loss=1.04]
# 	Train: Loss = 1.0392, Acc = 94.9919
# 	Valid: Loss = 3.6532, Acc = 29.9320
# 	Validation loss did not improve. Patience: 4/5
# ------------------------------------------------------------
# Epoch 6/6 | Current LR: 0.000008
# Epoch 6: 100%|███| 97/97 [00:00<00:00, 135.09batch/s, accuracy=97.5, loss=0.967]
# 	Train: Loss = 0.9672, Acc = 97.4959
# 	Valid: Loss = 3.6776, Acc = 29.9320
# 	Validation loss did not improve. Patience: 5/5
#
# 🛑 Early stopping triggered at epoch 6.
#
# ✅ Loaded best model based on validation accuracy for final testing. /kaggle/working/bac/.models/MLP_bert_mean_model.pt
# Figure(1400x600)
#
# 🧪 Evaluating on Test Set...
#
# --- Test Set Results (Best Validation Model) ---
# 	Test Loss: 3.1502
# 	Test Accuracy (Top-1): 24.57%
# 	Test MRR: 0.4205
# {'loss_train_hist': [3.2408730344674024, 2.461526911283277, 1.780283866469393, 1.2673028941007005, 1.0391699763917432, 0.9672347221177878], 'loss_valid_hist': [3.1338368892669677, 3.2586250782012938, 3.559209632873535, 3.6351757526397703, 3.653170680999756, 3.6776238918304442], 'acc_train_hist': [22.504065040650406, 41.72357723577236, 64.8130081300813, 85.04065040650407, 94.99186991869918, 97.4959349593496], 'acc_valid_hist': [25.85034013605442, 30.612244897959183, 28.571428571428573, 29.25170068027211, 29.931972789115648, 29.931972789115648], 'test_top_5_acc': 0.6689419795221843, 'test_top_10_acc': 0.8054607508532423, 'test_loss_final': 3.150212860107422, 'test_acc_top1_final': 24.573378839590443, 'test_mrr_final': 0.4205358545679885}

# %%
result_load_path = f"{os.getcwd()}/.result/MLP_bert_cls_result.json"
plot_history(result_load_path, 6)
