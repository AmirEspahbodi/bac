# %%
# %cd /kaggle/working
# !git clone https://github.com/AmirEspahbodi/bac.git
# Out:
# /kaggle/working
# fatal: destination path 'bac' already exists and is not an empty directory.

# %%
# !pip install bitsandbytes

# %%
# %cd /kaggle/working/bac
# !git pull
# !ls
# Out:
# /kaggle/working/bac
# Already up to date.
# datasets     poetry.lock     README.md	src
# inspiration  pyproject.toml  scripts	state.db

# %%
import os
import json
import matplotlib.pyplot as plt


def plot_history(result_load_path, NUM_EPOCHS):
    loss_train_hist = None
    loss_valid_hist = None
    acc_train_hist = None
    acc_valid_hist = None
    test_top_5_acc = None
    test_top_10_acc = None
    test_loss_final = None
    test_acc_top1_final = None
    test_mrr_final = None
        
    # Load the data from the JSON file
    try:
        with open(result_load_path, "r") as f:
            # json.load() reads the file and parses the JSON data into a Python dictionary
            loaded_results = json.load(f)
    
        # Unpack the dictionary values into your variables
        loss_train_hist = loaded_results.get("loss_train_hist")
        loss_valid_hist = loaded_results.get("loss_valid_hist")
        acc_train_hist = loaded_results.get("acc_train_hist")
        acc_valid_hist = loaded_results.get("acc_valid_hist")
        test_top_5_acc = loaded_results.get("test_top_5_acc")
        test_top_10_acc = loaded_results.get("test_top_10_acc")
        test_loss_final = loaded_results.get("test_loss_final")
        test_acc_top1_final = loaded_results.get("test_acc_top1_final")
        test_mrr_final = loaded_results.get("test_mrr_final")
    
    except FileNotFoundError:
        print(f"Error: The file at '{result_load_path}' was not found.")
    except json.JSONDecodeError:
        print(f"Error: The file at '{result_load_path}' is not a valid JSON file.")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")
    
    epochs_range = range(1, NUM_EPOCHS + 1)
    
    plt.figure(figsize=(14, 6))
    
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, loss_train_hist, "bo-", label="Training Loss")
    plt.plot(epochs_range, loss_valid_hist, "ro-", label="Validation Loss")
    plt.title("Training and Validation Loss")
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.legend()
    plt.grid(True)
    
    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, acc_train_hist, "bo-", label="Training Accuracy (Top-1)")
    plt.plot(epochs_range, acc_valid_hist, "ro-", label="Validation Accuracy (Top-1)")
    plt.title("Training and Validation Accuracy (Top-1)")
    plt.xlabel("Epochs")
    plt.ylabel("Accuracy")
    plt.legend()
    plt.grid(True)
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## GCC dataset

# %%
# !python -m src.run_lstm -e bert -d gcc -ne 7 -rsw 0 -a 1 -b 1 -r 1 -hs 256 -l 2 -nah 8 -lam concat
# Out:
# 2025-07-12 13:39:46.830666: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752327586.852907     615 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752327586.860501     615 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Shape after dropping NA assignees: (2103, 6)
# Number of unique assignees (classes): 82
# Warning: Some classes have fewer than 2 samples (min_samples_per_class=1). Stratification for train/test split might not be possible or effective.
# ✅ Loading pre-saved augmented dataset from 'datasets/augmented_train_dataset_2_GCC.csv'.
# Using device: cuda
# Generating Full Embeddings: 100%|█████████████| 276/276 [01:32<00:00,  2.99it/s]
# Generating Full Embeddings: 100%|███████████████| 14/14 [00:04<00:00,  3.15it/s]
# Generating Full Embeddings: 100%|███████████████| 27/27 [00:08<00:00,  3.14it/s]
#
# DataLoaders created successfully!
# Training batches: 276
# Validation batches: 14
# Test batches: 27
# using bert embeddings
#
# ------
# lstm model info:
# {'total_parameters': 5080146, 'trainable_parameters': 5080146, 'model_size_mb': 19.37921905517578, 'config': LSTMConfig(input_size=768, hidden_size=256, num_layers=2, num_classes=82, dropout=0.4, bidirectional=True, use_attention=True, attention_heads=8, attention_dropout=0.1, layer_norm=True, residual_connections=1, gradient_clipping=1.0, luong_attention_method='concat'), 'is_bidirectional': True, 'uses_attention': True, 'attention_heads': 8}
# ------
#
# OPTIMIZER=SGD, LR=0.1
# Epoch 0: 100%|███| 276/276 [00:31<00:00,  8.65batch/s, accuracy=11.3, loss=3.87]
# OPTIMIZER=SGD, LR=0.01
# Epoch 0: 100%|███| 276/276 [00:30<00:00,  8.96batch/s, accuracy=14.7, loss=3.81]
# OPTIMIZER=SGD, LR=0.001
# Epoch 0: 100%|███| 276/276 [00:31<00:00,  8.90batch/s, accuracy=11.3, loss=4.09]
# OPTIMIZER=SGD, LR=0.0001
# Epoch 0: 100%|████| 276/276 [00:30<00:00,  8.90batch/s, accuracy=2.99, loss=4.8]
# OPTIMIZER=Adam, LR=0.1
# Epoch 0: 100%|███| 276/276 [00:31<00:00,  8.71batch/s, accuracy=9.88, loss=16.6]
# OPTIMIZER=Adam, LR=0.01
# Epoch 0: 100%|███| 276/276 [00:31<00:00,  8.70batch/s, accuracy=11.7, loss=3.88]
# OPTIMIZER=Adam, LR=0.001
# Epoch 0: 100%|███| 276/276 [00:32<00:00,  8.56batch/s, accuracy=11.9, loss=3.82]
# OPTIMIZER=Adam, LR=0.0001
# Epoch 0: 100%|███| 276/276 [00:31<00:00,  8.86batch/s, accuracy=22.1, loss=3.63]
# OPTIMIZER=Adamw, LR=0.1
# Epoch 0: 100%|███| 276/276 [00:31<00:00,  8.79batch/s, accuracy=13.1, loss=12.5]
# OPTIMIZER=Adamw, LR=0.01
# Epoch 0: 100%|███| 276/276 [00:31<00:00,  8.74batch/s, accuracy=12.4, loss=3.88]
# OPTIMIZER=Adamw, LR=0.001
# Epoch 0: 100%|███| 276/276 [00:31<00:00,  8.73batch/s, accuracy=11.8, loss=3.82]
# OPTIMIZER=Adamw, LR=0.0001
# Epoch 0: 100%|███| 276/276 [00:31<00:00,  8.84batch/s, accuracy=21.3, loss=3.64]
# <class 'torch.optim.adam.Adam'> 0.0001
#
# ✅ Start Training 7 epochs ...
# Epoch 1/7 | Current LR: 0.000100
# Epoch 1: 100%|███| 276/276 [00:31<00:00,  8.81batch/s, accuracy=22.2, loss=3.62]
# 	Train: Loss = 3.6171, Acc = 22.1845
# 	Valid: Loss = 3.2180, Acc = 30.3318
# 	✨ New best validation loss: 3.2180
# ------------------------------------------------------------
# Epoch 2/7 | Current LR: 0.000095
# Epoch 2: 100%|███| 276/276 [00:31<00:00,  8.82batch/s, accuracy=37.1, loss=2.98]
# 	Train: Loss = 2.9827, Acc = 37.0949
# 	Valid: Loss = 3.0434, Acc = 39.3365
# 	✨ New best validation loss: 3.0434
# ------------------------------------------------------------
# Epoch 3/7 | Current LR: 0.000081
# Epoch 3: 100%|███| 276/276 [00:31<00:00,  8.85batch/s, accuracy=48.3, loss=2.54]
# 	Train: Loss = 2.5382, Acc = 48.2665
# 	Valid: Loss = 2.9314, Acc = 41.2322
# 	✨ New best validation loss: 2.9314
# ------------------------------------------------------------
# Epoch 4/7 | Current LR: 0.000062
# Epoch 4: 100%|███| 276/276 [00:31<00:00,  8.84batch/s, accuracy=57.8, loss=2.18]
# 	Train: Loss = 2.1769, Acc = 57.8291
# 	Valid: Loss = 2.8245, Acc = 43.1280
# 	✨ New best validation loss: 2.8245
# ------------------------------------------------------------
# Epoch 5/7 | Current LR: 0.000039
# Epoch 5: 100%|███| 276/276 [00:31<00:00,  8.81batch/s, accuracy=66.4, loss=1.89]
# 	Train: Loss = 1.8884, Acc = 66.4174
# 	Valid: Loss = 2.7580, Acc = 45.0237
# 	✨ New best validation loss: 2.7580
# ------------------------------------------------------------
# Epoch 6/7 | Current LR: 0.000020
# Epoch 6: 100%|████| 276/276 [00:31<00:00,  8.79batch/s, accuracy=72.3, loss=1.7]
# 	Train: Loss = 1.7018, Acc = 72.3091
# 	Valid: Loss = 2.7866, Acc = 43.6019
# 	Validation loss did not improve. Patience: 1/5
# ------------------------------------------------------------
# Epoch 7/7 | Current LR: 0.000006
# Epoch 7: 100%|████| 276/276 [00:31<00:00,  8.80batch/s, accuracy=76.8, loss=1.6]
# 	Train: Loss = 1.6001, Acc = 76.7958
# 	Valid: Loss = 2.7396, Acc = 45.4976
# 	✨ New best validation loss: 2.7396
# ------------------------------------------------------------
#
# ✅ Loaded best model based on validation accuracy for final testing. /kaggle/working/bac/.models/lstm_bert_model.pt
# Figure(1400x600)
#
# 🧪 Evaluating on Test Set...
#
# --- Test Set Results (Best Validation Model) ---
# 	Test Loss: 2.6314
# 	Test Accuracy (Top-1): 48.93%
# 	Test MRR: 0.5986
# {'loss_train_hist': [3.6170658996139746, 2.982667751070382, 2.538247121417004, 2.176884853753491, 1.8883919314197872, 1.701825142338656, 1.6000712077686752], 'loss_valid_hist': [3.2179850169590543, 3.043433257511684, 2.9313505377088274, 2.824494276727949, 2.7579887083598544, 2.7865703276225497, 2.7396292175565446], 'acc_train_hist': [22.184455019261275, 37.09494674824383, 48.266485384092455, 57.829141173804665, 66.4174031271244, 72.3090867890324, 76.79583050079312], 'acc_valid_hist': [30.33175355450237, 39.33649289099526, 41.23222748815166, 43.127962085308056, 45.023696682464454, 43.60189573459716, 45.497630331753555], 'test_top_5_acc': 0.7125890736342043, 'test_top_10_acc': 0.8076009501187649, 'test_loss_final': 2.6314003511711404, 'test_acc_top1_final': 48.93111638954869, 'test_mrr_final': 0.5986312707141836}

# %%
result_load_path = f"{os.getcwd()}/.result/lstm_bert_result.json"
plot_history(result_load_path, 7)

# %% [markdown]
# ## JDT dataset

# %%
# !python -m src.run_lstm -e bert -d jdt -ne 7 -rsw 0 -a 1 -b 1 -r 1 -hs 256 -l 2 -nah 8 -lam concat
# Out:
# 2025-07-12 13:52:00.643999: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752328320.666348     864 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752328320.673172     864 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Shape after dropping NA assignees: (1465, 5)
# Number of unique assignees (classes): 69
# Warning: Some classes have fewer than 2 samples (min_samples_per_class=1). Stratification for train/test split might not be possible or effective.
# ✅ Loading pre-saved augmented dataset from 'datasets/augmented_train_dataset_2_JDT.csv'.
# Using device: cuda
# Generating Full Embeddings: 100%|█████████████| 193/193 [01:03<00:00,  3.05it/s]
# Generating Full Embeddings: 100%|███████████████| 10/10 [00:02<00:00,  3.34it/s]
# Generating Full Embeddings: 100%|███████████████| 19/19 [00:06<00:00,  3.14it/s]
#
# DataLoaders created successfully!
# Training batches: 193
# Validation batches: 10
# Test batches: 19
# using bert embeddings
#
# ------
# lstm model info:
# {'total_parameters': 5076805, 'trainable_parameters': 5076805, 'model_size_mb': 19.366474151611328, 'config': LSTMConfig(input_size=768, hidden_size=256, num_layers=2, num_classes=69, dropout=0.4, bidirectional=True, use_attention=True, attention_heads=8, attention_dropout=0.1, layer_norm=True, residual_connections=1, gradient_clipping=1.0, luong_attention_method='concat'), 'is_bidirectional': True, 'uses_attention': True, 'attention_heads': 8}
# ------
#
# OPTIMIZER=SGD, LR=0.1
# Epoch 0: 100%|███| 193/193 [00:22<00:00,  8.67batch/s, accuracy=14.5, loss=3.66]
# OPTIMIZER=SGD, LR=0.01
# Epoch 0: 100%|█████| 193/193 [00:21<00:00,  8.88batch/s, accuracy=15, loss=3.58]
# OPTIMIZER=SGD, LR=0.001
# Epoch 0: 100%|███| 193/193 [00:21<00:00,  8.89batch/s, accuracy=11.6, loss=3.96]
# OPTIMIZER=SGD, LR=0.0001
# Epoch 0: 100%|███| 193/193 [00:21<00:00,  8.94batch/s, accuracy=3.87, loss=4.86]
# OPTIMIZER=Adam, LR=0.1
# Epoch 0: 100%|███| 193/193 [00:22<00:00,  8.64batch/s, accuracy=13.6, loss=28.7]
# OPTIMIZER=Adam, LR=0.01
# Epoch 0: 100%|███| 193/193 [00:22<00:00,  8.67batch/s, accuracy=14.5, loss=3.65]
# OPTIMIZER=Adam, LR=0.001
# Epoch 0: 100%|███| 193/193 [00:22<00:00,  8.72batch/s, accuracy=12.7, loss=3.52]
# OPTIMIZER=Adam, LR=0.0001
# Epoch 0: 100%|███| 193/193 [00:21<00:00,  8.88batch/s, accuracy=18.4, loss=3.52]
# OPTIMIZER=Adamw, LR=0.1
# Epoch 0: 100%|███| 193/193 [00:22<00:00,  8.71batch/s, accuracy=15.4, loss=12.7]
# OPTIMIZER=Adamw, LR=0.01
# Epoch 0: 100%|████| 193/193 [00:21<00:00,  8.78batch/s, accuracy=13.8, loss=3.7]
# OPTIMIZER=Adamw, LR=0.001
# Epoch 0: 100%|███| 193/193 [00:22<00:00,  8.77batch/s, accuracy=13.6, loss=3.56]
# OPTIMIZER=Adamw, LR=0.0001
# Epoch 0: 100%|████| 193/193 [00:21<00:00,  8.87batch/s, accuracy=18.3, loss=3.5]
# <class 'torch.optim.adam.Adam'> 0.0001
#
# ✅ Start Training 7 epochs ...
# Epoch 1/7 | Current LR: 0.000100
# Epoch 1: 100%|███| 193/193 [00:21<00:00,  8.82batch/s, accuracy=18.2, loss=3.53]
# 	Train: Loss = 3.5287, Acc = 18.2114
# 	Valid: Loss = 3.1236, Acc = 23.1293
# 	✨ New best validation loss: 3.1236
# ------------------------------------------------------------
# Epoch 2/7 | Current LR: 0.000095
# Epoch 2: 100%|███| 193/193 [00:21<00:00,  8.91batch/s, accuracy=29.5, loss=3.04]
# 	Train: Loss = 3.0406, Acc = 29.4634
# 	Valid: Loss = 2.9647, Acc = 27.2109
# 	✨ New best validation loss: 2.9647
# ------------------------------------------------------------
# Epoch 3/7 | Current LR: 0.000081
# Epoch 3: 100%|███| 193/193 [00:21<00:00,  8.80batch/s, accuracy=41.1, loss=2.64]
# 	Train: Loss = 2.6383, Acc = 41.0732
# 	Valid: Loss = 2.9466, Acc = 27.8912
# 	✨ New best validation loss: 2.9466
# ------------------------------------------------------------
# Epoch 4/7 | Current LR: 0.000062
# Epoch 4: 100%|███| 193/193 [00:21<00:00,  8.89batch/s, accuracy=50.8, loss=2.29]
# 	Train: Loss = 2.2876, Acc = 50.8293
# 	Valid: Loss = 3.0026, Acc = 29.9320
# 	Validation loss did not improve. Patience: 1/5
# ------------------------------------------------------------
# Epoch 5/7 | Current LR: 0.000039
# Epoch 5: 100%|███| 193/193 [00:21<00:00,  8.90batch/s, accuracy=59.8, loss=2.02]
# 	Train: Loss = 2.0201, Acc = 59.7724
# 	Valid: Loss = 2.9824, Acc = 32.6531
# 	Validation loss did not improve. Patience: 2/5
# ------------------------------------------------------------
# Epoch 6/7 | Current LR: 0.000020
# Epoch 6: 100%|████| 193/193 [00:21<00:00,  8.86batch/s, accuracy=67.1, loss=1.8]
# 	Train: Loss = 1.8012, Acc = 67.0894
# 	Valid: Loss = 2.9838, Acc = 34.6939
# 	Validation loss did not improve. Patience: 3/5
# ------------------------------------------------------------
# Epoch 7/7 | Current LR: 0.000006
# Epoch 7: 100%|████| 193/193 [00:21<00:00,  8.90batch/s, accuracy=70.4, loss=1.7]
# 	Train: Loss = 1.6994, Acc = 70.4065
# 	Valid: Loss = 3.0086, Acc = 35.3741
# 	Validation loss did not improve. Patience: 4/5
# ------------------------------------------------------------
#
# ✅ Loaded best model based on validation accuracy for final testing. /kaggle/working/bac/.models/lstm_bert_model.pt
# Figure(1400x600)
#
# 🧪 Evaluating on Test Set...
#
# --- Test Set Results (Best Validation Model) ---
# 	Test Loss: 3.0423
# 	Test Accuracy (Top-1): 25.94%
# 	Test MRR: 0.4314
# {'loss_train_hist': [3.528653421550217, 3.04060514726787, 2.638296518918764, 2.287572070106941, 2.020099358237469, 1.8012306968165186, 1.6993559864518557], 'loss_valid_hist': [3.1235831022262572, 2.964654326438904, 2.9465832710266113, 3.0026387929916383, 2.9824404239654543, 2.9838351011276245, 3.0086246490478517], 'acc_train_hist': [18.211382113821138, 29.463414634146343, 41.073170731707314, 50.829268292682926, 59.77235772357724, 67.08943089430895, 70.40650406504065], 'acc_valid_hist': [23.12925170068027, 27.210884353741495, 27.891156462585034, 29.931972789115648, 32.6530612244898, 34.69387755102041, 35.374149659863946], 'test_top_5_acc': 0.6655290102389079, 'test_top_10_acc': 0.8191126279863481, 'test_loss_final': 3.042277775312725, 'test_acc_top1_final': 25.938566552901023, 'test_mrr_final': 0.4314483240581081}

# %%
result_load_path = f"{os.getcwd()}/.result/lstm_bert_result.json"
plot_history(result_load_path, 7)
